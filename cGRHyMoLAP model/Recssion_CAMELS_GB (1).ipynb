# %% [markdown]
# # IMPORT LIBRARIES

# %%
# !pip install git+https://github.com/kratzert/RRMPG.git
# Out:
# Collecting git+https://github.com/kratzert/RRMPG.git
#   Cloning https://github.com/kratzert/RRMPG.git to /tmp/pip-req-build-2rvidvvx
#   Running command git clone --filter=blob:none --quiet https://github.com/kratzert/RRMPG.git /tmp/pip-req-build-2rvidvvx
#   Resolved https://github.com/kratzert/RRMPG.git to commit 7de78c25acc1c255d2acaf739d65e9ce7bbd60c3
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rrmpg==0.1.1) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from rrmpg==0.1.1) (3.10.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from rrmpg==0.1.1) (0.60.0)
# Collecting jupyter (from rrmpg==0.1.1)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from rrmpg==0.1.1) (7.34.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from rrmpg==0.1.1) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from rrmpg==0.1.1) (1.16.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (75.2.0)
# Collecting jedi>=0.16 (from ipython->rrmpg==0.1.1)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->rrmpg==0.1.1) (4.9.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter->rrmpg==0.1.1) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter->rrmpg==0.1.1) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter->rrmpg==0.1.1) (7.17.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter->rrmpg==0.1.1) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter->rrmpg==0.1.1) (7.7.1)
# Collecting jupyterlab (from jupyter->rrmpg==0.1.1)
#   Downloading jupyterlab-4.6.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->rrmpg==0.1.1) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->rrmpg==0.1.1) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->rrmpg==0.1.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->rrmpg==0.1.1) (2026.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->rrmpg==0.1.1) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->rrmpg==0.1.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->rrmpg==0.1.1) (0.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->rrmpg==0.1.1) (1.17.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->rrmpg==0.1.1) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->rrmpg==0.1.1) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->rrmpg==0.1.1) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->rrmpg==0.1.1) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->rrmpg==0.1.1) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->rrmpg==0.1.1) (6.5.7)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->rrmpg==0.1.1) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->rrmpg==0.1.1) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->rrmpg==0.1.1) (3.0.16)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter->rrmpg==0.1.1) (5.9.1)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->rrmpg==0.1.1)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->rrmpg==0.1.1) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->rrmpg==0.1.1) (3.1.6)
# Collecting jupyter-builder>=1.0.2 (from jupyterlab->jupyter->rrmpg==0.1.1)
#   Downloading jupyter_builder-1.2.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->rrmpg==0.1.1)
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->rrmpg==0.1.1) (2.20.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->jupyter->rrmpg==0.1.1)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->rrmpg==0.1.1) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->rrmpg==0.1.1) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (3.3.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->rrmpg==0.1.1) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->rrmpg==0.1.1) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->rrmpg==0.1.1) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->rrmpg==0.1.1) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->rrmpg==0.1.1) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->rrmpg==0.1.1) (1.3.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->rrmpg==0.1.1) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->rrmpg==0.1.1) (1.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->rrmpg==0.1.1) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->rrmpg==0.1.1) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->rrmpg==0.1.1) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->rrmpg==0.1.1) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->rrmpg==0.1.1) (0.16.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->rrmpg==0.1.1) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->rrmpg==0.1.1) (4.10.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter->rrmpg==0.1.1) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1)
#   Downloading json5-0.15.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (2.32.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->jupyter->rrmpg==0.1.1) (2.21.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter->rrmpg==0.1.1) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter->rrmpg==0.1.1) (4.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (0.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->rrmpg==0.1.1) (2.5.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->rrmpg==0.1.1) (2.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->rrmpg==0.1.1) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->rrmpg==0.1.1) (1.4.0)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 36.7 MB/s eta 0:00:00
# Downloading jupyterlab-4.6.2-py3-none-any.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 47.7 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading jupyter_builder-1.2.1-py3-none-any.whl (915 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.1/915.1 kB 30.9 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 3.5 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 2.8 MB/s eta 0:00:00
# Downloading json5-0.15.0-py3-none-any.whl (36 kB)
# Building wheels for collected packages: rrmpg
#   Building wheel for rrmpg (setup.py) ... done
#   Created wheel for rrmpg: filename=rrmpg-0.1.1-py3-none-any.whl size=609986 sha256=a6f45d66f31d57f920b85c40ffff7a3cbc079d79bbe8beb2e1ef858736289467
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wll5v10d/wheels/7d/ec/25/408ea8f9d8a1aff931ffd2c082074611b43cc13f5ec46e46b3
# Successfully built rrmpg
# Installing collected packages: json5, jedi, async-lru, jupyter-builder, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, rrmpg
# Successfully installed async-lru-2.3.0 jedi-0.20.0 json5-0.15.0 jupyter-1.1.1 jupyter-builder-1.2.1 jupyter-lsp-2.3.1 jupyterlab-4.6.2 jupyterlab-server-2.28.0 rrmpg-0.1.1

# %%
from rrmpg.models import GR4J

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
from matplotlib.dates import DateFormatter
from scipy.optimize import minimize # USE IN THE MODEL CALIBRATION

from google.colab import files
import zipfile
import os

from numba import njit
import warnings
warnings.filterwarnings('ignore')

import time

# %% [markdown]
# ##CAMELS-DATA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = "/content/drive/MyDrive/CAMELS_GB/"
start_date, end_date = '1990-01-01', '2014-12-31'

print("Loading, filtering, and aligning CSV files...\n")

# 1. Fast Load & Filter
df_pcp = pd.read_csv(f"{data_dir}pcp_mm.csv", index_col=0).loc[start_date:end_date]
df_pet = pd.read_csv(f"{data_dir}pet_mm.csv", index_col=0).loc[start_date:end_date]
df_q   = pd.read_csv(f"{data_dir}q_mmd_obs.csv", index_col=0).loc[start_date:end_date]

# 2. Fast Alignment
common_stations = sorted(list(set(df_pcp.columns) & set(df_pet.columns) & set(df_q.columns)))
df_pcp = df_pcp[common_stations]
df_pet = df_pet[common_stations]
df_q   = df_q[common_stations]

print(f"✅ Data aligned. Total common stations: {len(common_stations)}")

# ============================================
# Memory-Optimized Wrapper Classes
# ============================================
class SimpleArray:
    __slots__ = ['array']  # Prevents massive RAM bloat
    def __init__(self, array):
        self.array = array
    def to_numpy(self):
        return self.array

class StationData:
    __slots__ = ['data']
    def __init__(self, data_dict):
        self.data = data_dict
    def sel(self, dynamic_features=None):
        return SimpleArray(self.data[dynamic_features])

# ============================================
# Ultra-Fast Dictionary Construction
# ============================================
print("Building ds_recent dictionary...\n")

# Convert DataFrames to 2D NumPy matrices once (orders of magnitude faster than column iteration)
pcp_arr = df_pcp.to_numpy()
pet_arr = df_pet.to_numpy()
q_arr   = df_q.to_numpy()
date_arr = pd.to_datetime(df_pcp.index).to_numpy()

# Build the dictionary using fast index slicing
ds_recent = {
    st: StationData({
        'pcp_mm': pcp_arr[:, i],
        'pet_mm': pet_arr[:, i],
        'q_mmd_obs': q_arr[:, i],
        'date': date_arr
    })
    for i, st in enumerate(common_stations)
}

print(f"✅ Dictionary built successfully!")

# ============================================
# Validation Test
# ============================================
test_station = common_stations[0]
print(f"\nTesting data access for station: {test_station}")

Q_obs = ds_recent[test_station].sel(dynamic_features="q_mmd_obs").to_numpy()
P     = ds_recent[test_station].sel(dynamic_features="pcp_mm").to_numpy()
PET   = ds_recent[test_station].sel(dynamic_features="pet_mm").to_numpy()

print(f"✅ Extraction works correctly!")
print(f"   Q_obs shape: {Q_obs.shape}")
print(f"   Q_obs - min: {np.nanmin(Q_obs):.2f}, max: {np.nanmax(Q_obs):.2f}, mean: {np.nanmean(Q_obs):.2f}")
print(f"   Q_obs Missing: {np.sum(np.isnan(Q_obs))} ({np.sum(np.isnan(Q_obs))/len(Q_obs)*100:.1f}%)")
# Out:
# Loading, filtering, and aligning CSV files...
#
# ✅ Data aligned. Total common stations: 671
# Building ds_recent dictionary...
#
# ✅ Dictionary built successfully!
#
# Testing data access for station: 10002
# ✅ Extraction works correctly!
#    Q_obs shape: (9131,)
#    Q_obs - min: 0.21, max: 25.04, mean: 1.37
#    Q_obs Missing: 0 (0.0%)

# %% [markdown]
# ##Metrics

# %%
@njit
def NSE(obs, sim):

    n = len(obs)

    mean_obs = 0.0
    count = 0

    for i in range(n):

        if not np.isnan(obs[i]) and not np.isnan(sim[i]):
            mean_obs += obs[i]
            count += 1

    if count == 0:
        return np.nan

    mean_obs /= count

    num = 0.0
    den = 0.0

    for i in range(n):

        if not np.isnan(obs[i]) and not np.isnan(sim[i]):
            num += (sim[i] - obs[i])**2
            den += (obs[i] - mean_obs)**2

    if den == 0:
        return np.nan

    return 1.0 - num / den

import numpy as np
from numba import njit


@njit
def RMSE(obs, sim):

    n = len(obs)

    mse = 0.0
    count = 0

    for i in range(n):

        if not np.isnan(obs[i]) and not np.isnan(sim[i]):
            diff = sim[i] - obs[i]
            mse += diff * diff
            count += 1

    if count == 0:
        return np.nan

    return np.sqrt(mse / count)


@njit
def FHV(obs, sim, top_fraction=0.02):

    mask = ~np.isnan(obs) & ~np.isnan(sim)

    obs = obs[mask]
    sim = sim[mask]

    if len(obs) == 0:
        return np.nan

    n_top = int(len(obs) * top_fraction)

    if n_top == 0:
        return np.nan

    idx = np.argsort(obs)[-n_top:]

    return np.sum(sim[idx] - obs[idx]) / np.sum(obs[idx])


@njit
def FLV(obs, sim, bottom_fraction=0.3):
    epsilon = 1e-6
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    obs = obs[mask]
    sim = sim[mask]
    if len(obs) == 0:
        return np.nan
    n_bot = int(len(obs) * bottom_fraction)
    if n_bot == 0:
        return np.nan
    idx = np.argsort(obs)[:n_bot]
    obs_bot = obs[idx]
    sim_bot = sim[idx]
    return  np.sum(sim_bot - obs_bot) / (np.sum(obs_bot) + epsilon)


def KGE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    obs = obs[mask]
    sim = sim[mask]

    r = np.corrcoef(obs, sim)[0, 1]
    alpha = np.std(sim) / np.std(obs)
    beta = np.mean(sim) / np.mean(obs)

    return 1 - np.sqrt((r - 1)**2 + (alpha - 1)**2 + (beta - 1)**2), r, alpha, beta

# %%
## General Parameters of the code
b1_ratio = 0.7
max_missing_ratio = 0.1

stations = list(ds_recent.keys())

# %% [markdown]
# ## cGRHyMoLAP

# %% [markdown]
# #Q(t+1) from t+1 imputs

# %%
start_time = time.perf_counter()

# ============================================
# TIME DISCRETIZATION
# ============================================
dt = 0.5
nsub = int(1.0 / dt)

# ============================================
# COUPLED STORAGE + RUNOFF (S AND Q TOGETHER)
# ============================================

@njit
def cGRHyMoLAP_Model(params, Q0, Pn, En):

    MU, LAMBDA, X1, GAMMA = params

    n = len(Pn)

    Q = np.zeros(n)
    S = np.zeros(n)

    Q[0] = Q0
    S[0] = X1 / 2.0

    ratio = 4.0 / 9.0
    c = (1.0 / (4.0 * X1**4)) * ratio**4

    for t in range(n-1):

        Q_day = Q[t]
        S_day = S[t]

        for k in range(nsub):
            # choose forcing
            if k == nsub - 1:
                P_n = Pn[t + 1]
                E_n = En[t + 1]
            else:
                P_n = Pn[t]
                E_n = En[t]

            temp = S_day / X1

            Ps = P_n * (1.0 - temp**2)
            Es = E_n * (2.0 * temp - temp**2)

            perc = c * S_day**5

            # update S (first ODE)
            S_day = S_day + dt * (Ps - Es - perc)
            if S_day < 0:
                S_day = 0.0

            dQ = (
                -(MU / LAMBDA) * Q_day**(2 * MU - 1)
                + GAMMA * (c * S_day**5) * P_n
            )

            Q_day = Q_day + dt * dQ
            if Q_day < 0:
                Q_day = 0.0

        S[t + 1] = S_day
        Q[t + 1] = Q_day

    return Q, S


# ============================================
# MAIN LOOP (UNCHANGED STRUCTURE)
# ============================================

results_cGRH_semi_exp = {}

for i, station_id in enumerate(stations):

    print(f"\n=== Station {station_id} ===, Number = {i+1}")

    Q_obs = ds_recent[station_id].sel(
        dynamic_features="q_mmd_obs"
    ).to_numpy()

    P = ds_recent[station_id].sel(
        dynamic_features="pcp_mm"
    ).to_numpy()

    PET = ds_recent[station_id].sel(
        dynamic_features="pet_mm"
    ).to_numpy()

    Pn = np.maximum(0, P - PET)
    En = np.maximum(0, PET - P)

    N = len(Q_obs)

    if N == 0 or np.all(np.isnan(Q_obs)):
        continue

    if np.sum(np.isnan(Q_obs)) / N > max_missing_ratio:
        continue

    b1 = int(N * b1_ratio)
    Q0 = Q_obs[0]

    if np.isnan(Q0):
       Q0 = 0

    # ============================================
    # OPTIMIZATION
    # ============================================
    grhymolap_param_bound = [(0.5, 3.5), (1e-3, 300.0), (1e-3, 5000.0), (1e-3, 20.0)]

    initial_guesses = [
    [0.5, 1.0, 80, 0.05],
    [0.7, 2.0, 120, 0.1],
    [1.0, 5.0, 150, 0.2],
    [1.2, 8.0, 250, 0.3],
    [1.5, 10.0, 300, 0.5],
    [2.0, 15.0, 400, 0.8],
    [2.5, 20.0, 600, 1.0],
    [0.8, 3.0, 800, 0.2],
    [1.0, 6.0, 1000, 0.4],
    [3.0, 25.0, 200, 0.1],
    [1.0, 12.0, 1500, 0.6]
]

    best_res = None
    best_val = float("inf")

    for guess in initial_guesses:

        res = minimize(
            lambda p: RMSE(
                Q_obs[:b1],
                cGRHyMoLAP_Model(p, Q0, Pn[:b1], En[:b1])[0]
            ),
            guess,
            method="Nelder-Mead",
            bounds = grhymolap_param_bound,
            options={'maxiter': 2500, 'disp': False}
        )

        if res.fun < best_val:
            best_val = res.fun
            best_res = res

    # ============================================
    # SIMULATION
    # ============================================

    Qsim, S = cGRHyMoLAP_Model(best_res.x, Q0, Pn, En)

    NSE_cal = NSE(Q_obs[:b1], Qsim[:b1])
    RMSE_cal = RMSE(Q_obs[:b1], Qsim[:b1])

    NSE_val = NSE(Q_obs[b1:], Qsim[b1:])
    RMSE_val = RMSE(Q_obs[b1:], Qsim[b1:])

    FHV_val = FHV(Q_obs[b1:], Qsim[b1:])
    FLV_val = FLV(Q_obs[b1:], Qsim[b1:])

    KGE_val, KGE_1, KGE_2, KGE_3  = KGE(Q_obs[b1:], Qsim[b1:])

    results_cGRH_semi_exp[station_id] = {

        "params": best_res.x,
        "Qsim": Qsim[b1:],
        "Q_obs": Q_obs[b1:],

        "NSE_cal": NSE_cal,
        "NSE_val": NSE_val,
        "RMSE_cal": RMSE_cal,
        "RMSE_val": RMSE_val,

        "FHV_val": FHV_val,
        "FLV_val": FLV_val,
        "KGE_val": KGE_val,
        "KGE_1": KGE_1,
        "KGE_2": KGE_2,
        "KGE_3": KGE_3,

    }

    print(f"   NSE cal: {NSE_cal:.4f}")
    print(f"   NSE val: {NSE_val:.4f}")

print(f"\n✅ Simulation completed for {len(results_cGRH_semi_exp)} basins.")

end_time = time.perf_counter()

total_time = end_time - start_time

print(f"Total time: {total_time:.2f} s")
print(f"Total time: {total_time/60:.2f} min")
print(f"Total time: {total_time/3600:.2f} h")
# Out:
# === Station 10002 ===, Number = 1
#    NSE cal: 0.7389
#    NSE val: 0.5976
#
# === Station 10003 ===, Number = 2
#    NSE cal: 0.8359
#    NSE val: 0.7533
#
# === Station 1001 ===, Number = 3
#
# === Station 101002 ===, Number = 4
#    NSE cal: 0.7208
#    NSE val: 0.7376
#
# === Station 101005 ===, Number = 5
#    NSE cal: 0.7396
#    NSE val: 0.7604
#
# === Station 102001 ===, Number = 6
#    NSE cal: 0.7694
#    NSE val: 0.7743
#
# === Station 106001 ===, Number = 7
#
# === Station 107001 ===, Number = 8
#
# === Station 11001 ===, Number = 9
#    NSE cal: 0.7828
#    NSE val: 0.6295
#
# === Station 11003 ===, Number = 10
#    NSE cal: 0.6261
#    NSE val: 0.4177
#
# === Station 11004 ===, Number = 11
#    NSE cal: 0.7748
#    NSE val: 0.6552
#
# === Station 12001 ===, Number = 12
#    NSE cal: 0.5818
#    NSE val: 0.4310
#
# === Station 12002 ===, Number = 13
#    NSE cal: 0.6481
#    NSE val: 0.5186
#
# === Station 12005 ===, Number = 14
#    NSE cal: 0.6121
#    NSE val: 0.5331
#
# === Station 12006 ===, Number = 15
#    NSE cal: 0.4992
#    NSE val: 0.3245
#
# === Station 12007 ===, Number = 16
#    NSE cal: 0.4578
#    NSE val: 0.3644
#
# === Station 12008 ===, Number = 17
#    NSE cal: 0.7133
#    NSE val: 0.7066
#
# === Station 12009 ===, Number = 18
#    NSE cal: 0.6618
#    NSE val: 0.7040
#
# === Station 13001 ===, Number = 19
#    NSE cal: 0.8060
#    NSE val: 0.7896
#
# === Station 13004 ===, Number = 20
#    NSE cal: 0.6882
#    NSE val: 0.6468
#
# === Station 13005 ===, Number = 21
#    NSE cal: 0.8431
#    NSE val: 0.0097
#
# === Station 13007 ===, Number = 22
#    NSE cal: 0.7269
#    NSE val: 0.6582
#
# === Station 13008 ===, Number = 23
#    NSE cal: 0.7375
#    NSE val: 0.6945
#
# === Station 14001 ===, Number = 24
#    NSE cal: 0.8354
#    NSE val: 0.7813
#
# === Station 14002 ===, Number = 25
#    NSE cal: 0.8155
#    NSE val: 0.1662
#
# === Station 14005 ===, Number = 26
#    NSE cal: 0.8376
#    NSE val: 0.7653
#
# === Station 15006 ===, Number = 27
#    NSE cal: 0.8555
#    NSE val: 0.8213
#
# === Station 15007 ===, Number = 28
#    NSE cal: 0.8869
#    NSE val: 0.8629
#
# === Station 15010 ===, Number = 29
#    NSE cal: 0.7302
#    NSE val: 0.7021
#
# === Station 15011 ===, Number = 30
#    NSE cal: 0.6546
#    NSE val: 0.5621
#
# === Station 15012 ===, Number = 31
#    NSE cal: 0.8151
#    NSE val: 0.7505
#
# === Station 15013 ===, Number = 32
#    NSE cal: 0.6905
#    NSE val: 0.6496
#
# === Station 15014 ===, Number = 33
#    NSE cal: 0.6343
#    NSE val: 0.5907
#
# === Station 15016 ===, Number = 34
#    NSE cal: 0.9147
#    NSE val: 0.8999
#
# === Station 15021 ===, Number = 35
#    NSE cal: 0.8511
#    NSE val: 0.8302
#
# === Station 15023 ===, Number = 36
#    NSE cal: 0.7889
#    NSE val: 0.7163
#
# === Station 15024 ===, Number = 37
#    NSE cal: 0.8100
#    NSE val: 0.7954
#
# === Station 15025 ===, Number = 38
#    NSE cal: 0.6908
#    NSE val: 0.6476
#
# === Station 15030 ===, Number = 39
#    NSE cal: 0.8467
#    NSE val: 0.7531
#
# === Station 15039 ===, Number = 40
#    NSE cal: 0.4804
#    NSE val: 0.4092
#
# === Station 16001 ===, Number = 41
#    NSE cal: 0.8499
#    NSE val: 0.8105
#
# === Station 16003 ===, Number = 42
#    NSE cal: 0.7879
#    NSE val: 0.7260
#
# === Station 16004 ===, Number = 43
#    NSE cal: 0.8686
#    NSE val: 0.8220
#
# === Station 17001 ===, Number = 44
#    NSE cal: 0.7604
#    NSE val: 0.7521
#
# === Station 17003 ===, Number = 45
#    NSE cal: 0.7803
#    NSE val: 0.6975
#
# === Station 17004 ===, Number = 46
#    NSE cal: 0.8499
#    NSE val: 0.7951
#
# === Station 17005 ===, Number = 47
#    NSE cal: 0.8139
#    NSE val: 0.8320
#
# === Station 17015 ===, Number = 48
#    NSE cal: 0.7330
#    NSE val: 0.6818
#
# === Station 17018 ===, Number = 49
#
# === Station 18001 ===, Number = 50
#    NSE cal: 0.7775
#    NSE val: 0.7102
#
# === Station 18002 ===, Number = 51
#    NSE cal: 0.7776
#    NSE val: 0.6898
#
# === Station 18003 ===, Number = 52
#    NSE cal: 0.8839
#    NSE val: 0.8669
#
# === Station 18008 ===, Number = 53
#    NSE cal: 0.8529
#    NSE val: 0.8505
#
# === Station 18010 ===, Number = 54
#
# === Station 18011 ===, Number = 55
#    NSE cal: 0.8560
#    NSE val: 0.8849
#
# === Station 18014 ===, Number = 56
#    NSE cal: 0.7998
#    NSE val: 0.7248
#
# === Station 18017 ===, Number = 57
#
# === Station 18018 ===, Number = 58
#
# === Station 19001 ===, Number = 59
#    NSE cal: 0.8190
#    NSE val: 0.8090
#
# === Station 19006 ===, Number = 60
#    NSE cal: 0.7431
#    NSE val: 0.7549
#
# === Station 19010 ===, Number = 61
#
# === Station 19017 ===, Number = 62
#    NSE cal: 0.7885
#    NSE val: 0.6735
#
# === Station 19020 ===, Number = 63
#    NSE cal: 0.7988
#    NSE val: 0.7358
#
# === Station 20002 ===, Number = 64
#    NSE cal: 0.8026
#    NSE val: 0.5539
#
# === Station 20003 ===, Number = 65
#    NSE cal: 0.7475
#    NSE val: 0.5935
#
# === Station 20007 ===, Number = 66
#    NSE cal: 0.6938
#    NSE val: 0.5188
#
# === Station 2001 ===, Number = 67
#    NSE cal: 0.6667
#    NSE val: 0.6365
#
# === Station 2002 ===, Number = 68
#
# === Station 21003 ===, Number = 69
#    NSE cal: 0.8493
#    NSE val: 0.8312
#
# === Station 21006 ===, Number = 70
#    NSE cal: 0.8233
#    NSE val: 0.8095
#
# === Station 21008 ===, Number = 71
#    NSE cal: 0.7719
#    NSE val: 0.7583
#
# === Station 21009 ===, Number = 72
#    NSE cal: 0.8047
#    NSE val: 0.7829
#
# === Station 21011 ===, Number = 73
#    NSE cal: 0.8118
#    NSE val: 0.7918
#
# === Station 21012 ===, Number = 74
#    NSE cal: 0.8064
#    NSE val: 0.7763
#
# === Station 21013 ===, Number = 75
#    NSE cal: 0.7750
#    NSE val: 0.6839
#
# === Station 21015 ===, Number = 76
#
# === Station 21016 ===, Number = 77
#    NSE cal: 0.6771
#    NSE val: 0.7109
#
# === Station 21017 ===, Number = 78
#
# === Station 21018 ===, Number = 79
#    NSE cal: 0.8028
#    NSE val: 0.6958
#
# === Station 21022 ===, Number = 80
#    NSE cal: 0.7318
#    NSE val: 0.5806
#
# === Station 21023 ===, Number = 81
#    NSE cal: 0.5320
#    NSE val: 0.4812
#
# === Station 21024 ===, Number = 82
#    NSE cal: 0.6929
#    NSE val: 0.6899
#
# === Station 21026 ===, Number = 83
#    NSE cal: 0.7277
#    NSE val: 0.7054
#
# === Station 21027 ===, Number = 84
#    NSE cal: 0.6938
#    NSE val: 0.5656
#
# === Station 22001 ===, Number = 85
#    NSE cal: 0.7708
#    NSE val: 0.7099
#
# === Station 22006 ===, Number = 86
#    NSE cal: 0.8208
#    NSE val: 0.7084
#
# === Station 22007 ===, Number = 87
#    NSE cal: 0.7734
#    NSE val: 0.6824
#
# === Station 22009 ===, Number = 88
#    NSE cal: 0.7161
#    NSE val: 0.6673
#
# === Station 23001 ===, Number = 89
#    NSE cal: 0.7810
#    NSE val: 0.7522
#
# === Station 23004 ===, Number = 90
#    NSE cal: 0.7711
#    NSE val: 0.7736
#
# === Station 23006 ===, Number = 91
#    NSE cal: 0.7883
#    NSE val: 0.8017
#
# === Station 23007 ===, Number = 92
#    NSE cal: 0.6648
#    NSE val: 0.6401
#
# === Station 23008 ===, Number = 93
#    NSE cal: 0.7453
#    NSE val: 0.7014
#
# === Station 23011 ===, Number = 94
#    NSE cal: 0.7061
#    NSE val: 0.7111
#
# === Station 23016 ===, Number = 95
#    NSE cal: 0.7836
#    NSE val: 0.7628
#
# === Station 24001 ===, Number = 96
#    NSE cal: 0.7719
#    NSE val: 0.7192
#
# === Station 24003 ===, Number = 97
#    NSE cal: 0.7381
#    NSE val: 0.7410
#
# === Station 24004 ===, Number = 98
#    NSE cal: 0.7473
#    NSE val: 0.6986
#
# === Station 24005 ===, Number = 99
#    NSE cal: 0.7576
#    NSE val: 0.6870
#
# === Station 25001 ===, Number = 100
#    NSE cal: 0.7456
#    NSE val: 0.7129
#
# === Station 25003 ===, Number = 101
#    NSE cal: 0.6083
#    NSE val: 0.5616
#
# === Station 25006 ===, Number = 102
#    NSE cal: 0.7924
#    NSE val: 0.7468
#
# === Station 25012 ===, Number = 103
#    NSE cal: 0.7499
#    NSE val: 0.7637
#
# === Station 25020 ===, Number = 104
#    NSE cal: 0.7960
#    NSE val: 0.7486
#
# === Station 25021 ===, Number = 105
#    NSE cal: 0.7552
#    NSE val: 0.6947
#
# === Station 25029 ===, Number = 106
#
# === Station 26003 ===, Number = 107
#    NSE cal: 0.9045
#    NSE val: 0.8501
#
# === Station 26005 ===, Number = 108
#    NSE cal: 0.8869
#    NSE val: 0.7268
#
# === Station 26006 ===, Number = 109
#    NSE cal: 0.8582
#    NSE val: 0.8012
#
# === Station 26008 ===, Number = 110
#    NSE cal: 0.8080
#    NSE val: 0.8263
#
# === Station 26009 ===, Number = 111
#    NSE cal: 0.8835
#    NSE val: 0.7282
#
# === Station 27001 ===, Number = 112
#    NSE cal: 0.8100
#    NSE val: 0.7711
#
# === Station 27002 ===, Number = 113
#    NSE cal: 0.7942
#    NSE val: 0.7280
#
# === Station 27003 ===, Number = 114
#    NSE cal: 0.8401
#    NSE val: 0.8246
#
# === Station 27006 ===, Number = 115
#    NSE cal: 0.7679
#    NSE val: 0.7545
#
# === Station 27007 ===, Number = 116
#    NSE cal: 0.7933
#    NSE val: 0.7692
#
# === Station 27009 ===, Number = 117
#    NSE cal: 0.8245
#    NSE val: 0.7901
#
# === Station 27021 ===, Number = 118
#    NSE cal: 0.8025
#    NSE val: 0.7636
#
# === Station 27023 ===, Number = 119
#    NSE cal: 0.6780
#    NSE val: 0.7131
#
# === Station 27025 ===, Number = 120
#    NSE cal: 0.7473
#    NSE val: 0.6517
#
# === Station 27026 ===, Number = 121
#    NSE cal: 0.7724
#    NSE val: 0.7307
#
# === Station 27029 ===, Number = 122
#    NSE cal: 0.8418
#    NSE val: 0.8161
#
# === Station 27030 ===, Number = 123
#    NSE cal: 0.7868
#    NSE val: 0.7416
#
# === Station 27032 ===, Number = 124
#    NSE cal: 0.8072
#    NSE val: 0.7788
#
# === Station 27034 ===, Number = 125
#    NSE cal: 0.8266
#    NSE val: 0.8043
#
# === Station 27035 ===, Number = 126
#    NSE cal: 0.9053
#    NSE val: 0.8799
#
# === Station 27038 ===, Number = 127
#    NSE cal: 0.4485
#    NSE val: 0.2021
#
# === Station 27041 ===, Number = 128
#    NSE cal: 0.8829
#    NSE val: 0.8530
#
# === Station 27042 ===, Number = 129
#    NSE cal: 0.7707
#    NSE val: 0.7410
#
# === Station 27043 ===, Number = 130
#    NSE cal: 0.8225
#    NSE val: 0.8131
#
# === Station 27047 ===, Number = 131
#    NSE cal: 0.8647
#    NSE val: 0.8727
#
# === Station 27049 ===, Number = 132
#    NSE cal: 0.7601
#    NSE val: 0.7370
#
# === Station 27051 ===, Number = 133
#    NSE cal: 0.8074
#    NSE val: 0.7905
#
# === Station 27062 ===, Number = 134
#    NSE cal: 0.8454
#    NSE val: 0.8442
#
# === Station 27064 ===, Number = 135
#    NSE cal: 0.7705
#    NSE val: 0.7062
#
# === Station 27065 ===, Number = 136
#    NSE cal: 0.8235
#    NSE val: 0.8123
#
# === Station 27071 ===, Number = 137
#    NSE cal: 0.7947
#    NSE val: 0.7431
#
# === Station 27073 ===, Number = 138
#    NSE cal: 0.8597
#    NSE val: 0.8764
#
# === Station 27077 ===, Number = 139
#    NSE cal: 0.7196
#    NSE val: 0.7359
#
# === Station 27079 ===, Number = 140
#    NSE cal: 0.8099
#    NSE val: 0.8021
#
# === Station 27080 ===, Number = 141
#    NSE cal: 0.8410
#    NSE val: 0.8356
#
# === Station 27084 ===, Number = 142
#    NSE cal: 0.8431
#    NSE val: 0.8307
#
# === Station 27087 ===, Number = 143
#    NSE cal: 0.8710
#    NSE val: 0.8453
#
# === Station 27089 ===, Number = 144
#    NSE cal: 0.8069
#    NSE val: 0.8011
#
# === Station 27090 ===, Number = 145
#
# === Station 28001 ===, Number = 146
#    NSE cal: 0.5660
#    NSE val: 0.4960
#
# === Station 28003 ===, Number = 147
#
# === Station 28008 ===, Number = 148
#    NSE cal: 0.8431
#    NSE val: 0.7887
#
# === Station 28009 ===, Number = 149
#    NSE cal: 0.8562
#    NSE val: 0.8534
#
# === Station 28012 ===, Number = 150
#
# === Station 28015 ===, Number = 151
#    NSE cal: 0.7700
#    NSE val: 0.7354
#
# === Station 28018 ===, Number = 152
#    NSE cal: 0.8209
#    NSE val: 0.8013
#
# === Station 28022 ===, Number = 153
#    NSE cal: 0.8335
#    NSE val: 0.8409
#
# === Station 28023 ===, Number = 154
#
# === Station 28024 ===, Number = 155
#    NSE cal: 0.8359
#    NSE val: 0.8268
#
# === Station 28026 ===, Number = 156
#    NSE cal: 0.7616
#    NSE val: 0.7724
#
# === Station 28031 ===, Number = 157
#    NSE cal: 0.8107
#    NSE val: 0.7738
#
# === Station 28033 ===, Number = 158
#
# === Station 28039 ===, Number = 159
#    NSE cal: 0.7631
#    NSE val: 0.6772
#
# === Station 28040 ===, Number = 160
#    NSE cal: 0.7733
#    NSE val: 0.7502
#
# === Station 28043 ===, Number = 161
#    NSE cal: 0.8051
#    NSE val: 0.7856
#
# === Station 28044 ===, Number = 162
#    NSE cal: 0.7984
#    NSE val: 0.5690
#
# === Station 28046 ===, Number = 163
#    NSE cal: 0.8856
#    NSE val: 0.8331
#
# === Station 28048 ===, Number = 164
#    NSE cal: 0.7318
#    NSE val: 0.6702
#
# === Station 28050 ===, Number = 165
#    NSE cal: 0.7410
#    NSE val: 0.6900
#
# === Station 28052 ===, Number = 166
#    NSE cal: 0.7236
#    NSE val: 0.7119
#
# === Station 28055 ===, Number = 167
#    NSE cal: 0.8175
#    NSE val: 0.7436
#
# === Station 28056 ===, Number = 168
#    NSE cal: 0.7855
#    NSE val: 0.7847
#
# === Station 28060 ===, Number = 169
#    NSE cal: 0.6109
#    NSE val: 0.5535
#
# === Station 28066 ===, Number = 170
#    NSE cal: 0.7086
#    NSE val: 0.6551
#
# === Station 28067 ===, Number = 171
#    NSE cal: 0.8369
#    NSE val: 0.8059
#
# === Station 28072 ===, Number = 172
#    NSE cal: 0.7119
#    NSE val: 0.6298
#
# === Station 28074 ===, Number = 173
#    NSE cal: 0.8263
#    NSE val: 0.8363
#
# === Station 28080 ===, Number = 174
#    NSE cal: 0.6945
#    NSE val: 0.6732
#
# === Station 28081 ===, Number = 175
#    NSE cal: 0.6563
#    NSE val: 0.6646
#
# === Station 28082 ===, Number = 176
#    NSE cal: 0.8347
#    NSE val: 0.8428
#
# === Station 28085 ===, Number = 177
#    NSE cal: 0.8779
#    NSE val: 0.8491
#
# === Station 28091 ===, Number = 178
#    NSE cal: 0.7737
#    NSE val: 0.6730
#
# === Station 28093 ===, Number = 179
#    NSE cal: 0.8264
#    NSE val: 0.8112
#
# === Station 28115 ===, Number = 180
#    NSE cal: 0.6911
#    NSE val: 0.6299
#
# === Station 28116 ===, Number = 181
#
# === Station 28117 ===, Number = 182
#
# === Station 29002 ===, Number = 183
#    NSE cal: 0.8299
#    NSE val: 0.7745
#
# === Station 29003 ===, Number = 184
#    NSE cal: 0.8362
#    NSE val: 0.7901
#
# === Station 29005 ===, Number = 185
#    NSE cal: 0.6922
#    NSE val: 0.6320
#
# === Station 29009 ===, Number = 186
#    NSE cal: 0.8228
#    NSE val: 0.8553
#
# === Station 30001 ===, Number = 187
#    NSE cal: 0.8346
#    NSE val: 0.8137
#
# === Station 30004 ===, Number = 188
#    NSE cal: 0.7669
#    NSE val: 0.7369
#
# === Station 30005 ===, Number = 189
#
# === Station 30011 ===, Number = 190
#    NSE cal: 0.8316
#    NSE val: 0.8151
#
# === Station 30012 ===, Number = 191
#    NSE cal: 0.7546
#    NSE val: 0.7308
#
# === Station 30014 ===, Number = 192
#    NSE cal: 0.7132
#    NSE val: 0.6810
#
# === Station 30015 ===, Number = 193
#    NSE cal: 0.8796
#    NSE val: 0.8802
#
# === Station 3003 ===, Number = 194
#    NSE cal: 0.7922
#    NSE val: 0.7632
#
# === Station 31002 ===, Number = 195
#    NSE cal: 0.8246
#    NSE val: 0.7108
#
# === Station 31006 ===, Number = 196
#    NSE cal: 0.8772
#    NSE val: 0.8225
#
# === Station 31010 ===, Number = 197
#    NSE cal: 0.8024
#    NSE val: 0.7008
#
# === Station 31021 ===, Number = 198
#    NSE cal: 0.8122
#    NSE val: 0.7523
#
# === Station 31023 ===, Number = 199
#    NSE cal: 0.6824
#    NSE val: 0.6420
#
# === Station 31025 ===, Number = 200
#    NSE cal: 0.7605
#    NSE val: 0.6986
#
# === Station 32003 ===, Number = 201
#    NSE cal: 0.7305
#    NSE val: 0.6613
#
# === Station 32004 ===, Number = 202
#    NSE cal: 0.8127
#    NSE val: 0.7454
#
# === Station 32006 ===, Number = 203
#    NSE cal: 0.8253
#    NSE val: 0.8283
#
# === Station 32008 ===, Number = 204
#    NSE cal: 0.8224
#    NSE val: 0.8163
#
# === Station 33006 ===, Number = 205
#    NSE cal: 0.8765
#    NSE val: 0.7583
#
# === Station 33007 ===, Number = 206
#    NSE cal: 0.8685
#    NSE val: 0.8236
#
# === Station 33012 ===, Number = 207
#    NSE cal: 0.7917
#    NSE val: 0.7241
#
# === Station 33013 ===, Number = 208
#    NSE cal: 0.8458
#    NSE val: 0.7838
#
# === Station 33014 ===, Number = 209
#    NSE cal: 0.8042
#    NSE val: 0.7570
#
# === Station 33018 ===, Number = 210
#    NSE cal: 0.8039
#    NSE val: 0.7371
#
# === Station 33019 ===, Number = 211
#    NSE cal: 0.9113
#    NSE val: 0.8667
#
# === Station 33020 ===, Number = 212
#
# === Station 33021 ===, Number = 213
#    NSE cal: 0.8344
#    NSE val: 0.7618
#
# === Station 33022 ===, Number = 214
#    NSE cal: 0.8224
#    NSE val: 0.7742
#
# === Station 33023 ===, Number = 215
#    NSE cal: 0.7417
#    NSE val: 0.6820
#
# === Station 33024 ===, Number = 216
#    NSE cal: 0.7853
#    NSE val: 0.7236
#
# === Station 33026 ===, Number = 217
#    NSE cal: 0.8811
#    NSE val: 0.8519
#
# === Station 33028 ===, Number = 218
#    NSE cal: 0.6799
#    NSE val: 0.6449
#
# === Station 33029 ===, Number = 219
#    NSE cal: 0.8894
#    NSE val: 0.8619
#
# === Station 33031 ===, Number = 220
#    NSE cal: 0.7255
#    NSE val: 0.6031
#
# === Station 33032 ===, Number = 221
#    NSE cal: 0.9103
#    NSE val: 0.8869
#
# === Station 33033 ===, Number = 222
#    NSE cal: 0.7330
#    NSE val: 0.6293
#
# === Station 33034 ===, Number = 223
#    NSE cal: 0.8907
#    NSE val: 0.8594
#
# === Station 33035 ===, Number = 224
#    NSE cal: 0.8274
#    NSE val: 0.8060
#
# === Station 33039 ===, Number = 225
#    NSE cal: 0.8576
#    NSE val: 0.8361
#
# === Station 33053 ===, Number = 226
#
# === Station 33054 ===, Number = 227
#    NSE cal: 0.9068
#    NSE val: 0.8241
#
# === Station 33058 ===, Number = 228
#    NSE cal: 0.7674
#    NSE val: 0.6876
#
# === Station 34002 ===, Number = 229
#    NSE cal: 0.7983
#    NSE val: 0.8022
#
# === Station 34003 ===, Number = 230
#    NSE cal: 0.7913
#    NSE val: 0.7607
#
# === Station 34004 ===, Number = 231
#    NSE cal: 0.7583
#    NSE val: 0.8123
#
# === Station 34005 ===, Number = 232
#    NSE cal: 0.7066
#    NSE val: 0.7012
#
# === Station 34006 ===, Number = 233
#    NSE cal: 0.8097
#    NSE val: 0.8317
#
# === Station 34007 ===, Number = 234
#    NSE cal: 0.7468
#    NSE val: 0.7417
#
# === Station 34008 ===, Number = 235
#    NSE cal: 0.6983
#    NSE val: 0.5569
#
# === Station 34010 ===, Number = 236
#    NSE cal: 0.8216
#    NSE val: 0.7380
#
# === Station 34011 ===, Number = 237
#    NSE cal: 0.7994
#    NSE val: 0.7569
#
# === Station 34012 ===, Number = 238
#    NSE cal: 0.9218
#    NSE val: 0.8787
#
# === Station 35003 ===, Number = 239
#    NSE cal: 0.6051
#    NSE val: 0.4694
#
# === Station 35008 ===, Number = 240
#    NSE cal: 0.7900
#    NSE val: 0.7891
#
# === Station 36003 ===, Number = 241
#    NSE cal: 0.7584
#    NSE val: 0.7486
#
# === Station 36006 ===, Number = 242
#    NSE cal: 0.7797
#    NSE val: 0.7734
#
# === Station 36009 ===, Number = 243
#    NSE cal: 0.7754
#    NSE val: 0.7221
#
# === Station 36010 ===, Number = 244
#    NSE cal: 0.7078
#    NSE val: 0.7503
#
# === Station 36011 ===, Number = 245
#    NSE cal: 0.7604
#    NSE val: 0.6935
#
# === Station 36012 ===, Number = 246
#    NSE cal: 0.0730
#    NSE val: 0.0403
#
# === Station 37001 ===, Number = 247
#    NSE cal: 0.8663
#    NSE val: 0.8647
#
# === Station 37003 ===, Number = 248
#    NSE cal: 0.8053
#    NSE val: 0.7202
#
# === Station 37005 ===, Number = 249
#    NSE cal: 0.8124
#    NSE val: 0.8185
#
# === Station 37008 ===, Number = 250
#    NSE cal: 0.7936
#    NSE val: 0.7904
#
# === Station 37009 ===, Number = 251
#    NSE cal: 0.6460
#    NSE val: 0.6864
#
# === Station 37010 ===, Number = 252
#    NSE cal: 0.6648
#    NSE val: 0.7236
#
# === Station 37011 ===, Number = 253
#    NSE cal: 0.7706
#    NSE val: 0.7817
#
# === Station 37018 ===, Number = 254
#    NSE cal: 0.6937
#    NSE val: 0.6753
#
# === Station 37019 ===, Number = 255
#    NSE cal: 0.6833
#    NSE val: 0.7172
#
# === Station 37020 ===, Number = 256
#    NSE cal: 0.7982
#    NSE val: 0.7240
#
# === Station 37031 ===, Number = 257
#    NSE cal: 0.6206
#    NSE val: 0.6373
#
# === Station 37033 ===, Number = 258
#    NSE cal: 0.6631
#    NSE val: 0.7307
#
# === Station 38001 ===, Number = 259
#    NSE cal: 0.8062
#    NSE val: 0.7909
#
# === Station 38003 ===, Number = 260
#    NSE cal: 0.8712
#    NSE val: 0.8063
#
# === Station 38004 ===, Number = 261
#    NSE cal: 0.7212
#    NSE val: 0.7054
#
# === Station 38007 ===, Number = 262
#    NSE cal: 0.7180
#    NSE val: 0.7054
#
# === Station 38012 ===, Number = 263
#    NSE cal: 0.5906
#    NSE val: 0.7603
#
# === Station 38014 ===, Number = 264
#    NSE cal: 0.7587
#    NSE val: 0.7319
#
# === Station 38017 ===, Number = 265
#    NSE cal: 0.9042
#    NSE val: 0.8617
#
# === Station 38018 ===, Number = 266
#    NSE cal: 0.7711
#    NSE val: 0.7404
#
# === Station 38021 ===, Number = 267
#    NSE cal: 0.7675
#    NSE val: 0.7848
#
# === Station 38026 ===, Number = 268
#    NSE cal: 0.8487
#    NSE val: 0.8145
#
# === Station 38029 ===, Number = 269
#    NSE cal: 0.6596
#    NSE val: 0.7254
#
# === Station 38030 ===, Number = 270
#    NSE cal: 0.6203
#    NSE val: 0.5696
#
# === Station 39001 ===, Number = 271
#    NSE cal: 0.9245
#    NSE val: 0.9221
#
# === Station 39002 ===, Number = 272
#    NSE cal: 0.9222
#    NSE val: 0.9176
#
# === Station 39004 ===, Number = 273
#    NSE cal: 0.6815
#    NSE val: 0.6009
#
# === Station 39005 ===, Number = 274
#    NSE cal: 0.6338
#    NSE val: 0.5419
#
# === Station 39006 ===, Number = 275
#    NSE cal: 0.9500
#    NSE val: 0.9303
#
# === Station 39007 ===, Number = 276
#    NSE cal: 0.8299
#    NSE val: 0.7923
#
# === Station 39008 ===, Number = 277
#    NSE cal: 0.9385
#    NSE val: 0.9165
#
# === Station 39010 ===, Number = 278
#    NSE cal: 0.8617
#    NSE val: 0.7436
#
# === Station 39011 ===, Number = 279
#    NSE cal: 0.7702
#    NSE val: 0.7630
#
# === Station 39012 ===, Number = 280
#    NSE cal: 0.6257
#    NSE val: 0.6240
#
# === Station 39014 ===, Number = 281
#    NSE cal: 0.8611
#    NSE val: 0.8321
#
# === Station 39015 ===, Number = 282
#    NSE cal: 0.9053
#    NSE val: 0.8221
#
# === Station 39016 ===, Number = 283
#    NSE cal: 0.8959
#    NSE val: 0.8739
#
# === Station 39017 ===, Number = 284
#    NSE cal: 0.7109
#    NSE val: 0.6246
#
# === Station 39019 ===, Number = 285
#    NSE cal: 0.9420
#    NSE val: 0.9279
#
# === Station 39020 ===, Number = 286
#    NSE cal: 0.9545
#    NSE val: 0.9561
#
# === Station 39021 ===, Number = 287
#    NSE cal: 0.8821
#    NSE val: 0.8516
#
# === Station 39022 ===, Number = 288
#    NSE cal: 0.8042
#    NSE val: 0.7606
#
# === Station 39023 ===, Number = 289
#    NSE cal: 0.9172
#    NSE val: 0.1589
#
# === Station 39025 ===, Number = 290
#    NSE cal: 0.8339
#    NSE val: 0.8410
#
# === Station 39027 ===, Number = 291
#    NSE cal: 0.7756
#    NSE val: 0.7098
#
# === Station 39028 ===, Number = 292
#    NSE cal: 0.9105
#    NSE val: 0.9403
#
# === Station 39029 ===, Number = 293
#    NSE cal: 0.6729
#    NSE val: 0.6508
#
# === Station 39034 ===, Number = 294
#    NSE cal: 0.9343
#    NSE val: 0.8881
#
# === Station 39035 ===, Number = 295
#    NSE cal: 0.9300
#    NSE val: 0.5627
#
# === Station 39036 ===, Number = 296
#    NSE cal: 0.4318
#    NSE val: 0.4065
#
# === Station 39037 ===, Number = 297
#    NSE cal: 0.8904
#    NSE val: 0.8626
#
# === Station 39042 ===, Number = 298
#    NSE cal: 0.9055
#    NSE val: 0.7741
#
# === Station 39049 ===, Number = 299
#    NSE cal: 0.7542
#    NSE val: 0.7784
#
# === Station 39052 ===, Number = 300
#    NSE cal: 0.7320
#    NSE val: 0.7485
#
# === Station 39054 ===, Number = 301
#
# === Station 39056 ===, Number = 302
#    NSE cal: 0.7163
#    NSE val: 0.7462
#
# === Station 39061 ===, Number = 303
#    NSE cal: 0.8765
#    NSE val: 0.8467
#
# === Station 39065 ===, Number = 304
#    NSE cal: 0.8822
#    NSE val: 0.8284
#
# === Station 39069 ===, Number = 305
#    NSE cal: 0.7763
#    NSE val: 0.7908
#
# === Station 39072 ===, Number = 306
#    NSE cal: 0.9094
#    NSE val: 0.9147
#
# === Station 39078 ===, Number = 307
#    NSE cal: 0.7464
#    NSE val: 0.7670
#
# === Station 39081 ===, Number = 308
#    NSE cal: 0.9001
#    NSE val: 0.8773
#
# === Station 39087 ===, Number = 309
#    NSE cal: 0.7860
#    NSE val: 0.7601
#
# === Station 39088 ===, Number = 310
#    NSE cal: 0.9028
#    NSE val: 0.8149
#
# === Station 39095 ===, Number = 311
#    NSE cal: 0.7183
#    NSE val: 0.7535
#
# === Station 39099 ===, Number = 312
#    NSE cal: 0.9198
#    NSE val: 0.7394
#
# === Station 39101 ===, Number = 313
#    NSE cal: 0.8827
#    NSE val: 0.5490
#
# === Station 39105 ===, Number = 314
#    NSE cal: 0.8717
#    NSE val: 0.8579
#
# === Station 39108 ===, Number = 315
#    NSE cal: 0.9147
#    NSE val: 0.8697
#
# === Station 39114 ===, Number = 316
#    NSE cal: 0.8129
#    NSE val: 0.8276
#
# === Station 39120 ===, Number = 317
#    NSE cal: 0.7471
#    NSE val: 0.7341
#
# === Station 39125 ===, Number = 318
#
# === Station 39127 ===, Number = 319
#
# === Station 39141 ===, Number = 320
#
# === Station 39142 ===, Number = 321
#
# === Station 39143 ===, Number = 322
#
# === Station 39144 ===, Number = 323
#
# === Station 40003 ===, Number = 324
#    NSE cal: 0.8532
#    NSE val: 0.8291
#
# === Station 40004 ===, Number = 325
#    NSE cal: 0.8394
#    NSE val: 0.8159
#
# === Station 40005 ===, Number = 326
#    NSE cal: 0.8058
#    NSE val: 0.7596
#
# === Station 40006 ===, Number = 327
#    NSE cal: 0.6232
#    NSE val: -1.6466
#
# === Station 40007 ===, Number = 328
#    NSE cal: 0.8112
#    NSE val: 0.8247
#
# === Station 40009 ===, Number = 329
#    NSE cal: 0.7032
#    NSE val: 0.7435
#
# === Station 4001 ===, Number = 330
#    NSE cal: 0.8133
#    NSE val: 0.7980
#
# === Station 40010 ===, Number = 331
#    NSE cal: 0.7905
#    NSE val: 0.8092
#
# === Station 40011 ===, Number = 332
#    NSE cal: 0.8635
#    NSE val: 0.8719
#
# === Station 40012 ===, Number = 333
#    NSE cal: 0.8302
#    NSE val: 0.8633
#
# === Station 40013 ===, Number = 334
#    NSE cal: 0.7245
#    NSE val: 0.6268
#
# === Station 40016 ===, Number = 335
#    NSE cal: 0.5332
#    NSE val: 0.3968
#
# === Station 40017 ===, Number = 336
#    NSE cal: 0.7899
#    NSE val: 0.6715
#
# === Station 40018 ===, Number = 337
#    NSE cal: 0.7900
#    NSE val: 0.8493
#
# === Station 40020 ===, Number = 338
#    NSE cal: 0.7571
#    NSE val: 0.7444
#
# === Station 40021 ===, Number = 339
#    NSE cal: 0.7895
#    NSE val: 0.7626
#
# === Station 40022 ===, Number = 340
#
# === Station 4003 ===, Number = 341
#    NSE cal: 0.6268
#    NSE val: 0.5909
#
# === Station 40033 ===, Number = 342
#    NSE cal: 0.8542
#    NSE val: 0.8721
#
# === Station 4005 ===, Number = 343
#    NSE cal: 0.7312
#    NSE val: 0.7459
#
# === Station 4006 ===, Number = 344
#    NSE cal: 0.8452
#    NSE val: 0.8449
#
# === Station 41001 ===, Number = 345
#    NSE cal: 0.7332
#    NSE val: 0.6342
#
# === Station 41003 ===, Number = 346
#    NSE cal: 0.8070
#    NSE val: 0.7762
#
# === Station 41004 ===, Number = 347
#
# === Station 41005 ===, Number = 348
#    NSE cal: 0.8193
#    NSE val: 0.8028
#
# === Station 41006 ===, Number = 349
#    NSE cal: 0.7715
#    NSE val: 0.7232
#
# === Station 41009 ===, Number = 350
#    NSE cal: 0.8467
#    NSE val: 0.8191
#
# === Station 41011 ===, Number = 351
#    NSE cal: 0.7682
#    NSE val: 0.7175
#
# === Station 41012 ===, Number = 352
#    NSE cal: 0.8206
#    NSE val: 0.7630
#
# === Station 41013 ===, Number = 353
#    NSE cal: 0.7870
#    NSE val: 0.7566
#
# === Station 41014 ===, Number = 354
#    NSE cal: 0.8210
#    NSE val: 0.5017
#
# === Station 41016 ===, Number = 355
#    NSE cal: 0.7831
#    NSE val: 0.7742
#
# === Station 41019 ===, Number = 356
#    NSE cal: 0.6855
#    NSE val: 0.7605
#
# === Station 41020 ===, Number = 357
#    NSE cal: 0.7981
#    NSE val: 0.7700
#
# === Station 41022 ===, Number = 358
#    NSE cal: 0.8036
#    NSE val: 0.7595
#
# === Station 41023 ===, Number = 359
#    NSE cal: 0.8392
#    NSE val: 0.7163
#
# === Station 41025 ===, Number = 360
#    NSE cal: 0.7955
#    NSE val: 0.6980
#
# === Station 41027 ===, Number = 361
#    NSE cal: 0.7094
#    NSE val: 0.7034
#
# === Station 41028 ===, Number = 362
#    NSE cal: 0.7086
#    NSE val: 0.7165
#
# === Station 41029 ===, Number = 363
#    NSE cal: 0.7998
#    NSE val: 0.7853
#
# === Station 42001 ===, Number = 364
#    NSE cal: 0.8124
#    NSE val: 0.7697
#
# === Station 42003 ===, Number = 365
#    NSE cal: 0.7733
#    NSE val: 0.7473
#
# === Station 42004 ===, Number = 366
#    NSE cal: 0.9219
#    NSE val: 0.8632
#
# === Station 42006 ===, Number = 367
#    NSE cal: 0.9312
#    NSE val: 0.9402
#
# === Station 42008 ===, Number = 368
#    NSE cal: 0.9166
#    NSE val: 0.9449
#
# === Station 42010 ===, Number = 369
#    NSE cal: 0.9376
#    NSE val: 0.9223
#
# === Station 42011 ===, Number = 370
#    NSE cal: 0.7265
#    NSE val: 0.7307
#
# === Station 42016 ===, Number = 371
#    NSE cal: 0.9362
#    NSE val: 0.9017
#
# === Station 42017 ===, Number = 372
#    NSE cal: 0.7250
#    NSE val: 0.7532
#
# === Station 42024 ===, Number = 373
#    NSE cal: 0.9387
#    NSE val: 0.9419
#
# === Station 42026 ===, Number = 374
#
# === Station 42027 ===, Number = 375
#
# === Station 43005 ===, Number = 376
#    NSE cal: 0.9367
#    NSE val: 0.9356
#
# === Station 43006 ===, Number = 377
#    NSE cal: 0.8661
#    NSE val: 0.8666
#
# === Station 43007 ===, Number = 378
#    NSE cal: 0.8782
#    NSE val: 0.8769
#
# === Station 43008 ===, Number = 379
#    NSE cal: 0.9133
#    NSE val: 0.9275
#
# === Station 43009 ===, Number = 380
#    NSE cal: 0.8380
#    NSE val: 0.8416
#
# === Station 43014 ===, Number = 381
#    NSE cal: 0.8036
#    NSE val: 0.7490
#
# === Station 43017 ===, Number = 382
#    NSE cal: 0.9017
#    NSE val: 0.9103
#
# === Station 43018 ===, Number = 383
#    NSE cal: 0.9324
#    NSE val: 0.9158
#
# === Station 43021 ===, Number = 384
#    NSE cal: 0.8913
#    NSE val: 0.7858
#
# === Station 44001 ===, Number = 385
#    NSE cal: 0.9051
#    NSE val: 0.9247
#
# === Station 44002 ===, Number = 386
#    NSE cal: 0.9351
#    NSE val: 0.9375
#
# === Station 44006 ===, Number = 387
#    NSE cal: 0.9290
#    NSE val: 0.9261
#
# === Station 44009 ===, Number = 388
#    NSE cal: 0.9402
#    NSE val: 0.9201
#
# === Station 44011 ===, Number = 389
#
# === Station 45001 ===, Number = 390
#    NSE cal: 0.9125
#    NSE val: 0.8847
#
# === Station 45003 ===, Number = 391
#    NSE cal: 0.7905
#    NSE val: 0.7222
#
# === Station 45004 ===, Number = 392
#    NSE cal: 0.7703
#    NSE val: 0.7366
#
# === Station 45005 ===, Number = 393
#    NSE cal: 0.7651
#    NSE val: 0.6984
#
# === Station 45009 ===, Number = 394
#    NSE cal: 0.9018
#    NSE val: 0.8622
#
# === Station 45012 ===, Number = 395
#    NSE cal: 0.8506
#    NSE val: 0.7992
#
# === Station 46003 ===, Number = 396
#    NSE cal: 0.8595
#    NSE val: 0.8238
#
# === Station 46005 ===, Number = 397
#    NSE cal: 0.8354
#    NSE val: 0.7863
#
# === Station 46008 ===, Number = 398
#    NSE cal: 0.8749
#    NSE val: 0.8204
#
# === Station 46014 ===, Number = 399
#
# === Station 47001 ===, Number = 400
#    NSE cal: 0.9092
#    NSE val: 0.8888
#
# === Station 47004 ===, Number = 401
#    NSE cal: 0.9157
#    NSE val: 0.8851
#
# === Station 47005 ===, Number = 402
#    NSE cal: 0.8549
#    NSE val: 0.8047
#
# === Station 47008 ===, Number = 403
#    NSE cal: 0.8463
#    NSE val: 0.8345
#
# === Station 47009 ===, Number = 404
#    NSE cal: 0.9382
#    NSE val: 0.9240
#
# === Station 47011 ===, Number = 405
#
# === Station 47014 ===, Number = 406
#    NSE cal: 0.8102
#    NSE val: 0.7501
#
# === Station 47018 ===, Number = 407
#    NSE cal: 0.8602
#    NSE val: 0.8370
#
# === Station 48003 ===, Number = 408
#    NSE cal: 0.8725
#    NSE val: 0.9085
#
# === Station 48004 ===, Number = 409
#    NSE cal: 0.8441
#    NSE val: 0.7940
#
# === Station 48005 ===, Number = 410
#    NSE cal: 0.8788
#    NSE val: 0.8779
#
# === Station 48011 ===, Number = 411
#    NSE cal: 0.8957
#    NSE val: 0.8600
#
# === Station 49001 ===, Number = 412
#    NSE cal: 0.8874
#    NSE val: 0.8645
#
# === Station 49002 ===, Number = 413
#    NSE cal: 0.9264
#    NSE val: 0.9322
#
# === Station 49004 ===, Number = 414
#    NSE cal: 0.8471
#    NSE val: 0.8009
#
# === Station 50001 ===, Number = 415
#    NSE cal: 0.9151
#    NSE val: 0.8889
#
# === Station 50002 ===, Number = 416
#    NSE cal: 0.8850
#    NSE val: 0.8511
#
# === Station 50006 ===, Number = 417
#    NSE cal: 0.9035
#    NSE val: 0.8938
#
# === Station 50007 ===, Number = 418
#    NSE cal: 0.8669
#    NSE val: 0.8144
#
# === Station 50008 ===, Number = 419
#    NSE cal: 0.8647
#    NSE val: 0.8446
#
# === Station 50011 ===, Number = 420
#    NSE cal: 0.8517
#    NSE val: 0.8145
#
# === Station 5003 ===, Number = 421
#    NSE cal: 0.7105
#    NSE val: 0.7000
#
# === Station 51001 ===, Number = 422
#    NSE cal: 0.8666
#    NSE val: 0.8345
#
# === Station 52004 ===, Number = 423
#    NSE cal: 0.7778
#    NSE val: 0.7845
#
# === Station 52005 ===, Number = 424
#    NSE cal: 0.8476
#    NSE val: 0.8223
#
# === Station 52006 ===, Number = 425
#    NSE cal: 0.8214
#    NSE val: 0.8118
#
# === Station 52007 ===, Number = 426
#    NSE cal: 0.7986
#    NSE val: 0.8188
#
# === Station 52009 ===, Number = 427
#    NSE cal: 0.8737
#    NSE val: 0.8372
#
# === Station 52010 ===, Number = 428
#    NSE cal: 0.8359
#    NSE val: 0.7956
#
# === Station 52011 ===, Number = 429
#    NSE cal: 0.8427
#    NSE val: 0.7749
#
# === Station 52015 ===, Number = 430
#    NSE cal: 0.8237
#    NSE val: 0.5326
#
# === Station 52016 ===, Number = 431
#    NSE cal: 0.8551
#    NSE val: 0.8518
#
# === Station 53005 ===, Number = 432
#    NSE cal: 0.8879
#    NSE val: 0.8604
#
# === Station 53006 ===, Number = 433
#    NSE cal: 0.8711
#    NSE val: 0.8654
#
# === Station 53007 ===, Number = 434
#    NSE cal: 0.8631
#    NSE val: 0.8287
#
# === Station 53008 ===, Number = 435
#    NSE cal: 0.9117
#    NSE val: 0.8705
#
# === Station 53009 ===, Number = 436
#    NSE cal: 0.9178
#    NSE val: 0.9039
#
# === Station 53013 ===, Number = 437
#    NSE cal: 0.8424
#    NSE val: 0.7686
#
# === Station 53017 ===, Number = 438
#    NSE cal: 0.8583
#    NSE val: 0.8143
#
# === Station 53018 ===, Number = 439
#    NSE cal: 0.9289
#    NSE val: 0.9176
#
# === Station 53022 ===, Number = 440
#
# === Station 53023 ===, Number = 441
#    NSE cal: 0.9482
#    NSE val: 0.9320
#
# === Station 53028 ===, Number = 442
#    NSE cal: 0.9316
#    NSE val: 0.9284
#
# === Station 54001 ===, Number = 443
#    NSE cal: 0.8708
#    NSE val: 0.8651
#
# === Station 54002 ===, Number = 444
#    NSE cal: 0.8440
#    NSE val: 0.8402
#
# === Station 54003 ===, Number = 445
#    NSE cal: 0.5896
#    NSE val: 0.5397
#
# === Station 54004 ===, Number = 446
#    NSE cal: 0.7220
#    NSE val: 0.7028
#
# === Station 54005 ===, Number = 447
#    NSE cal: 0.9083
#    NSE val: 0.8963
#
# === Station 54007 ===, Number = 448
#    NSE cal: 0.7070
#    NSE val: 0.6166
#
# === Station 54008 ===, Number = 449
#    NSE cal: 0.9094
#    NSE val: 0.9102
#
# === Station 54011 ===, Number = 450
#
# === Station 54012 ===, Number = 451
#    NSE cal: 0.8445
#    NSE val: 0.8609
#
# === Station 54015 ===, Number = 452
#    NSE cal: 0.7123
#    NSE val: 0.5588
#
# === Station 54016 ===, Number = 453
#    NSE cal: 0.9117
#    NSE val: 0.8847
#
# === Station 54017 ===, Number = 454
#    NSE cal: 0.8123
#    NSE val: 0.6561
#
# === Station 54018 ===, Number = 455
#    NSE cal: 0.8681
#    NSE val: 0.8626
#
# === Station 54019 ===, Number = 456
#    NSE cal: 0.7927
#    NSE val: 0.7861
#
# === Station 54020 ===, Number = 457
#    NSE cal: 0.8935
#    NSE val: 0.8992
#
# === Station 54022 ===, Number = 458
#
# === Station 54024 ===, Number = 459
#    NSE cal: 0.8327
#    NSE val: 0.8231
#
# === Station 54025 ===, Number = 460
#    NSE cal: 0.9047
#    NSE val: 0.8941
#
# === Station 54027 ===, Number = 461
#    NSE cal: 0.9248
#    NSE val: 0.8981
#
# === Station 54028 ===, Number = 462
#    NSE cal: 0.8730
#    NSE val: 0.8713
#
# === Station 54029 ===, Number = 463
#    NSE cal: 0.8923
#    NSE val: 0.8901
#
# === Station 54032 ===, Number = 464
#    NSE cal: 0.8821
#    NSE val: 0.8799
#
# === Station 54034 ===, Number = 465
#    NSE cal: 0.7562
#    NSE val: 0.7528
#
# === Station 54036 ===, Number = 466
#    NSE cal: 0.7592
#    NSE val: 0.7750
#
# === Station 54038 ===, Number = 467
#    NSE cal: 0.9117
#    NSE val: 0.9020
#
# === Station 54044 ===, Number = 468
#    NSE cal: 0.7212
#    NSE val: 0.6810
#
# === Station 54048 ===, Number = 469
#    NSE cal: 0.7417
#    NSE val: 0.6495
#
# === Station 54049 ===, Number = 470
#    NSE cal: 0.7747
#    NSE val: 0.7912
#
# === Station 54052 ===, Number = 471
#    NSE cal: 0.6398
#    NSE val: 0.7825
#
# === Station 54057 ===, Number = 472
#    NSE cal: 0.8750
#    NSE val: 0.8645
#
# === Station 54060 ===, Number = 473
#    NSE cal: 0.5969
#    NSE val: 0.5923
#
# === Station 54063 ===, Number = 474
#
# === Station 54080 ===, Number = 475
#    NSE cal: 0.7616
#    NSE val: 0.8219
#
# === Station 54095 ===, Number = 476
#    NSE cal: 0.8770
#    NSE val: 0.8669
#
# === Station 54096 ===, Number = 477
#    NSE cal: 0.7672
#    NSE val: 0.7412
#
# === Station 55002 ===, Number = 478
#    NSE cal: 0.8849
#    NSE val: 0.8603
#
# === Station 55007 ===, Number = 479
#    NSE cal: 0.8798
#    NSE val: 0.8771
#
# === Station 55008 ===, Number = 480
#
# === Station 55013 ===, Number = 481
#    NSE cal: 0.8739
#    NSE val: 0.8764
#
# === Station 55014 ===, Number = 482
#    NSE cal: 0.9056
#    NSE val: 0.9016
#
# === Station 55016 ===, Number = 483
#    NSE cal: 0.8659
#    NSE val: 0.8599
#
# === Station 55018 ===, Number = 484
#    NSE cal: 0.8004
#    NSE val: 0.7580
#
# === Station 55021 ===, Number = 485
#    NSE cal: 0.8951
#    NSE val: 0.8605
#
# === Station 55023 ===, Number = 486
#    NSE cal: 0.8857
#    NSE val: 0.9014
#
# === Station 55025 ===, Number = 487
#    NSE cal: 0.8403
#    NSE val: 0.8437
#
# === Station 55026 ===, Number = 488
#    NSE cal: 0.8628
#    NSE val: 0.8409
#
# === Station 55029 ===, Number = 489
#    NSE cal: 0.7995
#    NSE val: 0.7818
#
# === Station 55032 ===, Number = 490
#    NSE cal: 0.7036
#    NSE val: 0.7086
#
# === Station 56001 ===, Number = 491
#    NSE cal: 0.8917
#    NSE val: 0.8702
#
# === Station 56002 ===, Number = 492
#    NSE cal: 0.8875
#    NSE val: 0.8553
#
# === Station 56007 ===, Number = 493
#    NSE cal: 0.8707
#    NSE val: 0.8610
#
# === Station 56012 ===, Number = 494
#    NSE cal: 0.8919
#    NSE val: 0.8629
#
# === Station 56013 ===, Number = 495
#    NSE cal: 0.8916
#    NSE val: 0.8662
#
# === Station 57004 ===, Number = 496
#    NSE cal: 0.8841
#    NSE val: 0.8572
#
# === Station 57005 ===, Number = 497
#    NSE cal: 0.8872
#    NSE val: 0.8708
#
# === Station 57006 ===, Number = 498
#    NSE cal: 0.8812
#    NSE val: 0.8456
#
# === Station 57007 ===, Number = 499
#    NSE cal: 0.8591
#    NSE val: 0.8280
#
# === Station 57008 ===, Number = 500
#    NSE cal: 0.8655
#    NSE val: 0.8631
#
# === Station 57009 ===, Number = 501
#    NSE cal: 0.8486
#    NSE val: 0.8413
#
# === Station 58001 ===, Number = 502
#    NSE cal: 0.8325
#    NSE val: 0.7896
#
# === Station 58002 ===, Number = 503
#    NSE cal: 0.8747
#    NSE val: 0.8501
#
# === Station 58006 ===, Number = 504
#    NSE cal: 0.8984
#    NSE val: 0.8724
#
# === Station 58008 ===, Number = 505
#    NSE cal: 0.8550
#    NSE val: 0.8457
#
# === Station 58009 ===, Number = 506
#    NSE cal: 0.7475
#    NSE val: 0.7959
#
# === Station 58010 ===, Number = 507
#
# === Station 58012 ===, Number = 508
#    NSE cal: 0.8429
#    NSE val: 0.8147
#
# === Station 59001 ===, Number = 509
#    NSE cal: 0.8369
#    NSE val: 0.8282
#
# === Station 60002 ===, Number = 510
#    NSE cal: 0.8655
#    NSE val: 0.8626
#
# === Station 60003 ===, Number = 511
#    NSE cal: 0.8838
#    NSE val: 0.8184
#
# === Station 60005 ===, Number = 512
#    NSE cal: 0.8417
#    NSE val: 0.7571
#
# === Station 60006 ===, Number = 513
#    NSE cal: 0.8584
#    NSE val: 0.8604
#
# === Station 60010 ===, Number = 514
#    NSE cal: 0.9158
#    NSE val: 0.9064
#
# === Station 60012 ===, Number = 515
#    NSE cal: 0.8467
#    NSE val: 0.7904
#
# === Station 6007 ===, Number = 516
#    NSE cal: 0.8596
#    NSE val: 0.8493
#
# === Station 6008 ===, Number = 517
#    NSE cal: 0.7671
#    NSE val: 0.7513
#
# === Station 61001 ===, Number = 518
#    NSE cal: 0.8513
#    NSE val: 0.7515
#
# === Station 61002 ===, Number = 519
#    NSE cal: 0.8294
#    NSE val: 0.8146
#
# === Station 62001 ===, Number = 520
#    NSE cal: 0.9361
#    NSE val: 0.9237
#
# === Station 63001 ===, Number = 521
#    NSE cal: 0.8819
#    NSE val: 0.8385
#
# === Station 63004 ===, Number = 522
#    NSE cal: 0.8304
#    NSE val: 0.8478
#
# === Station 64001 ===, Number = 523
#    NSE cal: 0.8944
#    NSE val: 0.8794
#
# === Station 64002 ===, Number = 524
#    NSE cal: 0.8355
#    NSE val: 0.7774
#
# === Station 64006 ===, Number = 525
#    NSE cal: 0.8860
#    NSE val: 0.8484
#
# === Station 65001 ===, Number = 526
#    NSE cal: 0.8161
#    NSE val: 0.8420
#
# === Station 65004 ===, Number = 527
#
# === Station 65005 ===, Number = 528
#    NSE cal: 0.6044
#    NSE val: 0.7476
#
# === Station 65006 ===, Number = 529
#    NSE cal: 0.8639
#    NSE val: 0.8694
#
# === Station 65007 ===, Number = 530
#    NSE cal: 0.8263
#    NSE val: 0.8254
#
# === Station 65008 ===, Number = 531
#    NSE cal: 0.7997
#    NSE val: 0.7901
#
# === Station 66001 ===, Number = 532
#    NSE cal: 0.9156
#    NSE val: 0.8794
#
# === Station 66004 ===, Number = 533
#    NSE cal: 0.9026
#    NSE val: 0.8551
#
# === Station 66006 ===, Number = 534
#    NSE cal: 0.8731
#    NSE val: 0.8406
#
# === Station 66011 ===, Number = 535
#    NSE cal: 0.8376
#    NSE val: 0.8336
#
# === Station 67001 ===, Number = 536
#    NSE cal: 0.8457
#    NSE val: 0.8752
#
# === Station 67005 ===, Number = 537
#    NSE cal: 0.8872
#    NSE val: 0.8595
#
# === Station 67006 ===, Number = 538
#    NSE cal: 0.8772
#    NSE val: 0.8402
#
# === Station 67008 ===, Number = 539
#    NSE cal: 0.8777
#    NSE val: 0.7923
#
# === Station 67010 ===, Number = 540
#    NSE cal: 0.8237
#    NSE val: 0.8567
#
# === Station 67015 ===, Number = 541
#    NSE cal: 0.9149
#    NSE val: 0.8991
#
# === Station 67018 ===, Number = 542
#    NSE cal: 0.8489
#    NSE val: 0.8648
#
# === Station 67025 ===, Number = 543
#    NSE cal: 0.7749
#    NSE val: 0.7569
#
# === Station 67033 ===, Number = 544
#
# === Station 68001 ===, Number = 545
#    NSE cal: 0.8419
#    NSE val: 0.8349
#
# === Station 68003 ===, Number = 546
#    NSE cal: 0.8229
#    NSE val: 0.7704
#
# === Station 68004 ===, Number = 547
#    NSE cal: 0.6986
#    NSE val: 0.7576
#
# === Station 68005 ===, Number = 548
#    NSE cal: 0.8888
#    NSE val: 0.8159
#
# === Station 68020 ===, Number = 549
#    NSE cal: 0.7135
#    NSE val: 0.6809
#
# === Station 69002 ===, Number = 550
#    NSE cal: 0.7812
#    NSE val: 0.7940
#
# === Station 69007 ===, Number = 551
#    NSE cal: 0.8183
#    NSE val: 0.8042
#
# === Station 69012 ===, Number = 552
#    NSE cal: 0.7907
#    NSE val: 0.7563
#
# === Station 69015 ===, Number = 553
#    NSE cal: 0.7858
#    NSE val: 0.7596
#
# === Station 69017 ===, Number = 554
#    NSE cal: 0.8644
#    NSE val: 0.8266
#
# === Station 69023 ===, Number = 555
#    NSE cal: 0.8163
#    NSE val: 0.7830
#
# === Station 69027 ===, Number = 556
#    NSE cal: 0.7786
#    NSE val: 0.7896
#
# === Station 69030 ===, Number = 557
#    NSE cal: 0.7508
#    NSE val: 0.7404
#
# === Station 69032 ===, Number = 558
#    NSE cal: 0.7628
#    NSE val: 0.7645
#
# === Station 69043 ===, Number = 559
#
# === Station 70002 ===, Number = 560
#    NSE cal: 0.7896
#    NSE val: 0.8180
#
# === Station 7001 ===, Number = 561
#    NSE cal: 0.4591
#    NSE val: 0.3248
#
# === Station 7002 ===, Number = 562
#    NSE cal: 0.5558
#    NSE val: 0.3856
#
# === Station 7003 ===, Number = 563
#    NSE cal: 0.7410
#    NSE val: 0.5069
#
# === Station 7005 ===, Number = 564
#    NSE cal: 0.7161
#    NSE val: 0.4656
#
# === Station 7006 ===, Number = 565
#    NSE cal: 0.6081
#    NSE val: 0.3197
#
# === Station 71001 ===, Number = 566
#    NSE cal: 0.8321
#    NSE val: 0.8457
#
# === Station 71004 ===, Number = 567
#    NSE cal: 0.8266
#    NSE val: 0.8366
#
# === Station 71006 ===, Number = 568
#    NSE cal: 0.8609
#    NSE val: 0.8549
#
# === Station 71008 ===, Number = 569
#    NSE cal: 0.8371
#    NSE val: 0.8403
#
# === Station 71014 ===, Number = 570
#    NSE cal: 0.7810
#    NSE val: 0.7825
#
# === Station 72002 ===, Number = 571
#    NSE cal: 0.8341
#    NSE val: 0.7995
#
# === Station 72004 ===, Number = 572
#    NSE cal: 0.8514
#    NSE val: 0.8354
#
# === Station 72005 ===, Number = 573
#    NSE cal: 0.8661
#    NSE val: 0.8523
#
# === Station 72007 ===, Number = 574
#    NSE cal: 0.8139
#    NSE val: 0.7965
#
# === Station 72009 ===, Number = 575
#    NSE cal: 0.8296
#    NSE val: 0.8363
#
# === Station 72014 ===, Number = 576
#    NSE cal: 0.8351
#    NSE val: 0.8097
#
# === Station 72015 ===, Number = 577
#    NSE cal: 0.8756
#    NSE val: 0.8668
#
# === Station 73005 ===, Number = 578
#    NSE cal: 0.8626
#    NSE val: 0.8434
#
# === Station 73009 ===, Number = 579
#    NSE cal: 0.8513
#    NSE val: 0.8390
#
# === Station 73010 ===, Number = 580
#    NSE cal: 0.9367
#    NSE val: 0.9283
#
# === Station 73011 ===, Number = 581
#    NSE cal: 0.8763
#    NSE val: 0.8630
#
# === Station 73014 ===, Number = 582
#    NSE cal: 0.8038
#    NSE val: 0.7888
#
# === Station 73015 ===, Number = 583
#    NSE cal: 0.8039
#    NSE val: 0.7874
#
# === Station 74001 ===, Number = 584
#    NSE cal: 0.8403
#    NSE val: 0.8173
#
# === Station 74005 ===, Number = 585
#    NSE cal: 0.8480
#    NSE val: 0.8645
#
# === Station 74006 ===, Number = 586
#    NSE cal: 0.7880
#    NSE val: 0.7769
#
# === Station 74007 ===, Number = 587
#    NSE cal: 0.7880
#    NSE val: 0.8165
#
# === Station 75003 ===, Number = 588
#    NSE cal: 0.9286
#    NSE val: 0.9153
#
# === Station 75004 ===, Number = 589
#    NSE cal: 0.9163
#    NSE val: 0.8718
#
# === Station 75017 ===, Number = 590
#    NSE cal: 0.8640
#    NSE val: 0.8142
#
# === Station 76003 ===, Number = 591
#    NSE cal: 0.8873
#    NSE val: 0.8674
#
# === Station 76005 ===, Number = 592
#    NSE cal: 0.8333
#    NSE val: 0.7972
#
# === Station 76007 ===, Number = 593
#    NSE cal: 0.8629
#    NSE val: 0.8436
#
# === Station 76008 ===, Number = 594
#    NSE cal: 0.7556
#    NSE val: 0.7316
#
# === Station 76011 ===, Number = 595
#    NSE cal: 0.7683
#    NSE val: 0.7837
#
# === Station 76014 ===, Number = 596
#    NSE cal: 0.8567
#    NSE val: 0.8016
#
# === Station 77002 ===, Number = 597
#    NSE cal: 0.8441
#    NSE val: 0.8325
#
# === Station 77003 ===, Number = 598
#    NSE cal: 0.7818
#    NSE val: 0.7700
#
# === Station 77004 ===, Number = 599
#    NSE cal: 0.8403
#    NSE val: 0.8144
#
# === Station 78003 ===, Number = 600
#    NSE cal: 0.8777
#    NSE val: 0.8497
#
# === Station 78004 ===, Number = 601
#    NSE cal: 0.8100
#    NSE val: 0.7666
#
# === Station 78006 ===, Number = 602
#    NSE cal: 0.8572
#    NSE val: 0.8132
#
# === Station 79002 ===, Number = 603
#    NSE cal: 0.8556
#    NSE val: 0.8238
#
# === Station 79003 ===, Number = 604
#    NSE cal: 0.8406
#    NSE val: 0.8026
#
# === Station 79004 ===, Number = 605
#    NSE cal: 0.8459
#    NSE val: 0.8263
#
# === Station 79005 ===, Number = 606
#    NSE cal: 0.8648
#    NSE val: 0.8300
#
# === Station 79006 ===, Number = 607
#    NSE cal: 0.8543
#    NSE val: 0.8256
#
# === Station 80001 ===, Number = 608
#    NSE cal: 0.8683
#    NSE val: 0.8260
#
# === Station 80002 ===, Number = 609
#    NSE cal: 0.8793
#    NSE val: 0.8744
#
# === Station 80003 ===, Number = 610
#    NSE cal: 0.8111
#    NSE val: 0.7738
#
# === Station 80004 ===, Number = 611
#    NSE cal: 0.8125
#    NSE val: 0.7485
#
# === Station 80005 ===, Number = 612
#    NSE cal: 0.8050
#    NSE val: 0.7598
#
# === Station 80006 ===, Number = 613
#    NSE cal: 0.9217
#    NSE val: 0.9260
#
# === Station 8004 ===, Number = 614
#    NSE cal: 0.4558
#    NSE val: 0.2983
#
# === Station 8005 ===, Number = 615
#    NSE cal: 0.6845
#    NSE val: 0.6280
#
# === Station 8006 ===, Number = 616
#    NSE cal: 0.6456
#    NSE val: 0.4901
#
# === Station 8009 ===, Number = 617
#    NSE cal: 0.5323
#    NSE val: 0.4345
#
# === Station 8011 ===, Number = 618
#    NSE cal: 0.5204
#    NSE val: 0.3296
#
# === Station 8013 ===, Number = 619
#
# === Station 81002 ===, Number = 620
#    NSE cal: 0.8212
#    NSE val: 0.8040
#
# === Station 81003 ===, Number = 621
#    NSE cal: 0.7871
#    NSE val: 0.8102
#
# === Station 81004 ===, Number = 622
#    NSE cal: 0.8496
#    NSE val: 0.8448
#
# === Station 81006 ===, Number = 623
#    NSE cal: 0.7894
#    NSE val: 0.7640
#
# === Station 81007 ===, Number = 624
#    NSE cal: 0.7817
#    NSE val: 0.7884
#
# === Station 82001 ===, Number = 625
#    NSE cal: 0.8262
#    NSE val: 0.7982
#
# === Station 82003 ===, Number = 626
#    NSE cal: 0.8104
#    NSE val: 0.8053
#
# === Station 83003 ===, Number = 627
#    NSE cal: 0.7527
#    NSE val: 0.7102
#
# === Station 83004 ===, Number = 628
#    NSE cal: 0.7996
#    NSE val: 0.7292
#
# === Station 83006 ===, Number = 629
#    NSE cal: 0.8005
#    NSE val: 0.7300
#
# === Station 83007 ===, Number = 630
#    NSE cal: 0.8528
#    NSE val: 0.8014
#
# === Station 83009 ===, Number = 631
#    NSE cal: 0.7739
#    NSE val: 0.7192
#
# === Station 83010 ===, Number = 632
#    NSE cal: 0.8437
#    NSE val: 0.8282
#
# === Station 83013 ===, Number = 633
#    NSE cal: 0.7983
#    NSE val: 0.7823
#
# === Station 84001 ===, Number = 634
#    NSE cal: 0.8494
#    NSE val: 0.8439
#
# === Station 84004 ===, Number = 635
#    NSE cal: 0.8364
#    NSE val: 0.8209
#
# === Station 84005 ===, Number = 636
#    NSE cal: 0.8733
#    NSE val: 0.8485
#
# === Station 84008 ===, Number = 637
#    NSE cal: 0.8013
#    NSE val: 0.7728
#
# === Station 84009 ===, Number = 638
#    NSE cal: 0.8074
#    NSE val: 0.7635
#
# === Station 84012 ===, Number = 639
#    NSE cal: 0.8546
#    NSE val: 0.8007
#
# === Station 84013 ===, Number = 640
#    NSE cal: 0.8564
#    NSE val: 0.8522
#
# === Station 84014 ===, Number = 641
#    NSE cal: 0.8267
#    NSE val: 0.7964
#
# === Station 84016 ===, Number = 642
#    NSE cal: 0.7491
#    NSE val: 0.7476
#
# === Station 84017 ===, Number = 643
#    NSE cal: 0.8976
#    NSE val: 0.8676
#
# === Station 84018 ===, Number = 644
#    NSE cal: 0.8291
#    NSE val: 0.7845
#
# === Station 84019 ===, Number = 645
#    NSE cal: 0.7601
#    NSE val: 0.7559
#
# === Station 84020 ===, Number = 646
#    NSE cal: 0.8012
#    NSE val: 0.7484
#
# === Station 84022 ===, Number = 647
#    NSE cal: 0.7386
#    NSE val: 0.7577
#
# === Station 84026 ===, Number = 648
#    NSE cal: 0.8292
#    NSE val: 0.7395
#
# === Station 84030 ===, Number = 649
#    NSE cal: 0.8530
#    NSE val: 0.8068
#
# === Station 85001 ===, Number = 650
#    NSE cal: 0.9261
#    NSE val: 0.9128
#
# === Station 85002 ===, Number = 651
#    NSE cal: 0.8276
#    NSE val: 0.7111
#
# === Station 85003 ===, Number = 652
#    NSE cal: 0.8079
#    NSE val: 0.7318
#
# === Station 85004 ===, Number = 653
#    NSE cal: 0.7845
#    NSE val: 0.7623
#
# === Station 88001 ===, Number = 654
#
# === Station 89002 ===, Number = 655
#    NSE cal: 0.7474
#    NSE val: 0.7101
#
# === Station 89003 ===, Number = 656
#    NSE cal: 0.7917
#    NSE val: 0.7569
#
# === Station 89005 ===, Number = 657
#    NSE cal: 0.6475
#    NSE val: 0.6119
#
# === Station 89007 ===, Number = 658
#    NSE cal: 0.6780
#    NSE val: 0.6397
#
# === Station 90003 ===, Number = 659
#    NSE cal: 0.7624
#    NSE val: 0.7366
#
# === Station 9002 ===, Number = 660
#    NSE cal: 0.7162
#    NSE val: 0.5314
#
# === Station 9003 ===, Number = 661
#    NSE cal: 0.7244
#    NSE val: 0.5914
#
# === Station 9004 ===, Number = 662
#    NSE cal: 0.7209
#    NSE val: 0.5423
#
# === Station 9005 ===, Number = 663
#    NSE cal: 0.5386
#    NSE val: 0.3895
#
# === Station 92001 ===, Number = 664
#
# === Station 93001 ===, Number = 665
#    NSE cal: 0.7878
#    NSE val: 0.7812
#
# === Station 94001 ===, Number = 666
#    NSE cal: 0.9332
#    NSE val: 0.9360
#
# === Station 95001 ===, Number = 667
#    NSE cal: 0.8673
#    NSE val: 0.8354
#
# === Station 96001 ===, Number = 668
#    NSE cal: 0.7144
#    NSE val: 0.6243
#
# === Station 96002 ===, Number = 669
#    NSE cal: 0.8440
#    NSE val: 0.7817
#
# === Station 96004 ===, Number = 670
#    NSE cal: 0.7581
#    NSE val: 0.6773
#
# === Station 97002 ===, Number = 671
#    NSE cal: 0.7211
#    NSE val: 0.6088
#
# ✅ Simulation completed for 623 basins.
# Total time: 2250.28 s
# Total time: 37.50 min
# Total time: 0.63 h

# %%
# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — CALIBRATION
# =============================================================
nse_cal = [res['NSE_cal'] for res in results_cGRH_semi_exp.values() if not np.isnan(res['NSE_cal'])]
rmse_cal = [res['RMSE_cal'] for res in results_cGRH_semi_exp.values() if not np.isnan(res['RMSE_cal'])]

print("\n================= CALIBRATION =================\n")

# ----- NSE -----
if nse_cal:
    print(f"NSE Calibration -> Median: {np.percentile(nse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_cal, 95):.4f}")
    print("MEAN NSE_CAL:", np.mean(nse_cal))
    print("MIN NSE_CAL:", np.min(nse_cal))
    print("MAX NSE_CAL:", np.max(nse_cal))
else:
    print("No NSE available for the calibration.")

# ----- RMSE -----
print("\n--- RMSE Calibration ---")
if rmse_cal:
    print(f"RMSE Calibration -> Median: {np.percentile(rmse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_cal, 95):.4f}")
    print("MEAN RMSE_CAL:", np.mean(rmse_cal))
    print("MIN RMSE_CAL:", np.min(rmse_cal))
    print("MAX RMSE_CAL:", np.max(rmse_cal))
else:
    print("No RMSE available for the calibration.")


# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — VALIDATION
# =============================================================
print("\n\n================= VALIDATION =================\n")

nse_val = [res['NSE_val'] for res in results_cGRH_semi_exp.values() if not np.isnan(res['NSE_val'])]
rmse_val = [res['RMSE_val'] for res in results_cGRH_semi_exp.values() if not np.isnan(res['RMSE_val'])]

# ----- NSE -----
if nse_val:
    print(f"NSE Validation -> Median: {np.percentile(nse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_val, 95):.4f}")
    print("MEAN NSE_VAL:", np.mean(nse_val))
    print("MIN NSE_VAL:", np.min(nse_val))
    print("MAX NSE_VAL:", np.max(nse_val))
else:
    print("No valid station for NSE in validation.")

# ----- RMSE -----
print("\n--- RMSE Validation ---")
if rmse_val:
    print(f"RMSE Validation -> Median: {np.percentile(rmse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_val, 95):.4f}")
    print("MEAN RMSE_VAL:", np.mean(rmse_val))
    print("MIN RMSE_VAL:", np.min(rmse_val))
    print("MAX RMSE_VAL:", np.max(rmse_val))
else:
    print("No valid station for RMSE in validation.")
# Out:
# ================= CALIBRATION =================
#
# NSE Calibration -> Median: 0.816, 5th percentile: 0.6339, 95th percentile: 0.9196
# MEAN NSE_CAL: 0.8027562153567339
# MIN NSE_CAL: 0.0729768934549112
# MAX NSE_CAL: 0.9544865469433179
#
# --- RMSE Calibration ---
# RMSE Calibration -> Median: 0.781, 5th percentile: 0.1444, 95th percentile: 2.7130
# MEAN RMSE_CAL: 1.0622916588005762
# MIN RMSE_CAL: 0.047190860584618306
# MAX RMSE_CAL: 10.223686620144784
#
#
# ================= VALIDATION =================
#
# NSE Validation -> Median: 0.786, 5th percentile: 0.5338, 95th percentile: 0.9100
# MEAN NSE_VAL: 0.7600383432354919
# MIN NSE_VAL: -1.646626692073669
# MAX NSE_VAL: 0.9561095821977753
#
# --- RMSE Validation ---
# RMSE Validation -> Median: 0.941, 5th percentile: 0.1630, 95th percentile: 3.0530
# MEAN RMSE_VAL: 1.1945957890033891
# MIN RMSE_VAL: 0.03941320076171775
# MAX RMSE_VAL: 9.997008130116887

# %% [markdown]
# #GRHyMoLAP

# %%
start_time = time.perf_counter()

# ============================================
# NUMBA FUNCTIONS
# ============================================

@njit
def Percolation(Pn, En, X1):
    n = len(Pn)
    S = np.zeros(n)
    Perc = np.zeros(n)

    S[0] = X1 / 2.0
    ratio = (4.0 / 9.0) * (S[0] / X1)
    Perc[0] = S[0] * (1 - (1 + ratio**4) ** (-0.25))

    for i in range(1, n):
        temp = (S[i-1] / X1) ** 2

        frac = Pn[i] / X1
        Ps = X1 * (1 - temp) * np.tanh(frac) / (1 + (S[i-1] / X1) * np.tanh(frac))

        frac = En[i] / X1
        Es = S[i-1] * (2 - S[i-1]/X1) * np.tanh(frac) / (1 + (1 - S[i-1]/X1) * np.tanh(frac))

        S[i] = S[i-1] + Ps - Es

        ratio = (4.0 / 9.0) * (S[i] / X1)
        Perc[i] = S[i] * (1 - (1 + ratio**4) ** (-0.25))

        S[i] -= Perc[i]

    return Perc, S


@njit
def GRHyMoLAP_Model(params, Q0, Pn, En):
    MU, LAMBDA, X1, GAMMA = params
    N = len(Pn)

    Q = np.zeros(N)
    Q[0] = Q0

    Perc, S = Percolation(Pn, En, X1)

    for t in range(N-1):
        Q[t+1] = max(
            0.0,
            Q[t]
            - (MU / LAMBDA) * (Q[t])**(2*MU - 1)
            + GAMMA * Perc[t+1] * Pn[t+1]
        )

    return Q

# ============================================
# SETTINGS
# ============================================

results_GRH_semi_exp = {}

# ============================================
# MAIN LOOP
# ============================================

for i, station_id in enumerate(stations):

    print(f"\n=== Station {station_id} ===, Number = {i+1}")

    Q_obs = ds_recent[station_id].sel(dynamic_features="q_mmd_obs").to_numpy()
    P     = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    PET   = ds_recent[station_id].sel(dynamic_features="pet_mm").to_numpy()

    Pn = np.maximum(0, P - PET)
    En = np.maximum(0, PET - P)

    N = len(Q_obs)
    if N == 0 or np.all(np.isnan(Q_obs)):
        print("⚠️ Station skipped (no valid data).")
        continue

    missing_ratio = np.sum(np.isnan(Q_obs)) / N
    if missing_ratio > max_missing_ratio:
        print(f"⚠️ Too many missing values ({missing_ratio*100:.1f}%)")
        continue

    b1 = int(N * b1_ratio)
    Q0 = Q_obs[0]

    if np.isnan(Q0):
       Q0 = 0

    # ============================================
    # OPTIMIZATION
    # ============================================
    grhymolap_param_bound = [(0.5, 3.5), (1e-3, 300.0), (1e-3, 5000.0), (1e-3, 20.0)]

    initial_guesses = [
    [0.5, 1.0, 80, 0.05],
    [0.7, 2.0, 120, 0.1],
    [1.0, 5.0, 150, 0.2],
    [1.2, 8.0, 250, 0.3],
    [1.5, 10.0, 300, 0.5],
    [2.0, 15.0, 400, 0.8],
    [2.5, 20.0, 600, 1.0],
    [0.8, 3.0, 800, 0.2],
    [1.0, 6.0, 1000, 0.4],
    [3.0, 25.0, 200, 0.1],
    [1.0, 12.0, 1500, 0.6]
]

    best_res = None
    best_val = float("inf")

    for guess in initial_guesses:
        res = minimize(
            lambda p: RMSE(
                Q_obs[:b1],
                GRHyMoLAP_Model(p, Q0, Pn[:b1], En[:b1])
            ),
            guess,
            method="Nelder-Mead",
            bounds = grhymolap_param_bound,
            options={'maxiter': 2500, 'disp': False}
        )

        if res.fun < best_val:
            best_val = res.fun
            best_res = res

    MU, LAMBDA, X1, GAMMA = best_res.x

    # ============================================
    # SIMULATION
    # ============================================

    Qsim = GRHyMoLAP_Model(best_res.x, Q0, Pn, En)

    NSE_cal = NSE(Q_obs[:b1], Qsim[:b1])
    NSE_val = NSE(Q_obs[b1:], Qsim[b1:])
    RMSE_cal = RMSE(Q_obs[:b1], Qsim[:b1])
    RMSE_val = RMSE(Q_obs[b1:], Qsim[b1:])

    FHV_val = FHV(Q_obs[b1:], Qsim[b1:])
    FLV_val = FLV(Q_obs[b1:], Qsim[b1:])
    KGE_val, KGE_1, KGE_2, KGE_3  = KGE(Q_obs[b1:], Qsim[b1:])

    S = Percolation(Pn, En, X1)[1]

    # ============================================
    # STORE RESULTS (FULL PRESERVED)
    # ============================================

    results_GRH_semi_exp[station_id] = {
        "params": [MU, LAMBDA, X1, GAMMA],
        "Qsim": Qsim[b1:],
        "Q_obs": Q_obs[b1:],

        "NSE_cal": NSE_cal,
        "NSE_val": NSE_val,
        "RMSE_cal": RMSE_cal,
        "RMSE_val": RMSE_val,

        "FHV_val": FHV_val,
        "FLV_val": FLV_val,
        "KGE_val": KGE_val,
        "KGE_1": KGE_1,
        "KGE_2": KGE_2,
        "KGE_3": KGE_3,

    }

    print(f" NSE cal: {NSE_cal:.4f}")
    print(f" NSE val: {NSE_val:.4f}")

print(f"\n✅ Simulation completed for {len(results_GRH_semi_exp)} valid basins.")

end_time = time.perf_counter()

total_time = end_time - start_time

print(f"Total time: {total_time:.2f} s")
print(f"Total time: {total_time/60:.2f} min")
print(f"Total time: {total_time/3600:.2f} h")
# Out:
# === Station 10002 ===, Number = 1
#  NSE cal: 0.6854
#  NSE val: 0.5358
#
# === Station 10003 ===, Number = 2
#  NSE cal: 0.8382
#  NSE val: 0.7503
#
# === Station 1001 ===, Number = 3
# ⚠️ Too many missing values (23.4%)
#
# === Station 101002 ===, Number = 4
#  NSE cal: 0.7321
#  NSE val: 0.7423
#
# === Station 101005 ===, Number = 5
#  NSE cal: 0.7511
#  NSE val: 0.7790
#
# === Station 102001 ===, Number = 6
#  NSE cal: 0.7238
#  NSE val: 0.7415
#
# === Station 106001 ===, Number = 7
# ⚠️ Too many missing values (28.0%)
#
# === Station 107001 ===, Number = 8
# ⚠️ Too many missing values (38.4%)
#
# === Station 11001 ===, Number = 9
#  NSE cal: 0.7615
#  NSE val: 0.5962
#
# === Station 11003 ===, Number = 10
#  NSE cal: 0.6508
#  NSE val: 0.4247
#
# === Station 11004 ===, Number = 11
#  NSE cal: 0.8031
#  NSE val: 0.6859
#
# === Station 12001 ===, Number = 12
#  NSE cal: 0.5688
#  NSE val: 0.4072
#
# === Station 12002 ===, Number = 13
#  NSE cal: 0.6314
#  NSE val: 0.4927
#
# === Station 12005 ===, Number = 14
#  NSE cal: 0.6272
#  NSE val: 0.5267
#
# === Station 12006 ===, Number = 15
#  NSE cal: 0.5151
#  NSE val: 0.3328
#
# === Station 12007 ===, Number = 16
#  NSE cal: 0.4594
#  NSE val: 0.3770
#
# === Station 12008 ===, Number = 17
#  NSE cal: 0.7182
#  NSE val: 0.7101
#
# === Station 12009 ===, Number = 18
#  NSE cal: 0.6724
#  NSE val: 0.7077
#
# === Station 13001 ===, Number = 19
#  NSE cal: 0.8016
#  NSE val: 0.7746
#
# === Station 13004 ===, Number = 20
#  NSE cal: 0.7193
#  NSE val: 0.6737
#
# === Station 13005 ===, Number = 21
#  NSE cal: 0.8358
#  NSE val: -0.2094
#
# === Station 13007 ===, Number = 22
#  NSE cal: 0.7336
#  NSE val: 0.6592
#
# === Station 13008 ===, Number = 23
#  NSE cal: 0.7213
#  NSE val: 0.6684
#
# === Station 14001 ===, Number = 24
#  NSE cal: 0.8214
#  NSE val: 0.7671
#
# === Station 14002 ===, Number = 25
#  NSE cal: 0.8183
#  NSE val: -0.0122
#
# === Station 14005 ===, Number = 26
#  NSE cal: 0.7890
#  NSE val: 0.6943
#
# === Station 15006 ===, Number = 27
#  NSE cal: 0.8351
#  NSE val: 0.7962
#
# === Station 15007 ===, Number = 28
#  NSE cal: 0.8765
#  NSE val: 0.8490
#
# === Station 15010 ===, Number = 29
#  NSE cal: 0.7330
#  NSE val: 0.7036
#
# === Station 15011 ===, Number = 30
#  NSE cal: 0.6537
#  NSE val: 0.5538
#
# === Station 15012 ===, Number = 31
#  NSE cal: 0.8131
#  NSE val: 0.7451
#
# === Station 15013 ===, Number = 32
#  NSE cal: 0.6971
#  NSE val: 0.6368
#
# === Station 15014 ===, Number = 33
#  NSE cal: 0.6383
#  NSE val: 0.5876
#
# === Station 15016 ===, Number = 34
#  NSE cal: 0.8926
#  NSE val: 0.8771
#
# === Station 15021 ===, Number = 35
#  NSE cal: 0.8213
#  NSE val: 0.8024
#
# === Station 15023 ===, Number = 36
#  NSE cal: 0.7947
#  NSE val: 0.7048
#
# === Station 15024 ===, Number = 37
#  NSE cal: 0.7765
#  NSE val: 0.7504
#
# === Station 15025 ===, Number = 38
#  NSE cal: 0.6870
#  NSE val: 0.6381
#
# === Station 15030 ===, Number = 39
#  NSE cal: 0.8209
#  NSE val: 0.7050
#
# === Station 15039 ===, Number = 40
#  NSE cal: 0.4829
#  NSE val: 0.4136
#
# === Station 16001 ===, Number = 41
#  NSE cal: 0.8503
#  NSE val: 0.8005
#
# === Station 16003 ===, Number = 42
#  NSE cal: 0.7874
#  NSE val: 0.7226
#
# === Station 16004 ===, Number = 43
#  NSE cal: 0.8457
#  NSE val: 0.7875
#
# === Station 17001 ===, Number = 44
#  NSE cal: 0.7496
#  NSE val: 0.7427
#
# === Station 17003 ===, Number = 45
#  NSE cal: 0.7764
#  NSE val: 0.6948
#
# === Station 17004 ===, Number = 46
#  NSE cal: 0.8175
#  NSE val: 0.7557
#
# === Station 17005 ===, Number = 47
#  NSE cal: 0.7852
#  NSE val: 0.7882
#
# === Station 17015 ===, Number = 48
#  NSE cal: 0.7360
#  NSE val: 0.6803
#
# === Station 17018 ===, Number = 49
# ⚠️ Too many missing values (18.6%)
#
# === Station 18001 ===, Number = 50
#  NSE cal: 0.7608
#  NSE val: 0.6897
#
# === Station 18002 ===, Number = 51
#  NSE cal: 0.7296
#  NSE val: 0.6334
#
# === Station 18003 ===, Number = 52
#  NSE cal: 0.8512
#  NSE val: 0.8317
#
# === Station 18008 ===, Number = 53
#  NSE cal: 0.7935
#  NSE val: 0.7819
#
# === Station 18010 ===, Number = 54
# ⚠️ Too many missing values (12.0%)
#
# === Station 18011 ===, Number = 55
#  NSE cal: 0.8042
#  NSE val: 0.8265
#
# === Station 18014 ===, Number = 56
#  NSE cal: 0.8024
#  NSE val: 0.7258
#
# === Station 18017 ===, Number = 57
# ⚠️ Too many missing values (72.0%)
#
# === Station 18018 ===, Number = 58
# ⚠️ Too many missing values (72.0%)
#
# === Station 19001 ===, Number = 59
#  NSE cal: 0.7781
#  NSE val: 0.7496
#
# === Station 19006 ===, Number = 60
#  NSE cal: 0.7512
#  NSE val: 0.7572
#
# === Station 19010 ===, Number = 61
# ⚠️ Too many missing values (20.0%)
#
# === Station 19017 ===, Number = 62
#  NSE cal: 0.7670
#  NSE val: 0.6478
#
# === Station 19020 ===, Number = 63
#  NSE cal: 0.7846
#  NSE val: 0.7036
#
# === Station 20002 ===, Number = 64
#  NSE cal: 0.7747
#  NSE val: 0.5167
#
# === Station 20003 ===, Number = 65
#  NSE cal: 0.7504
#  NSE val: 0.5809
#
# === Station 20007 ===, Number = 66
#  NSE cal: 0.7221
#  NSE val: 0.5144
#
# === Station 2001 ===, Number = 67
#  NSE cal: 0.6553
#  NSE val: 0.6103
#
# === Station 2002 ===, Number = 68
# ⚠️ Too many missing values (13.3%)
#
# === Station 21003 ===, Number = 69
#  NSE cal: 0.8359
#  NSE val: 0.8112
#
# === Station 21006 ===, Number = 70
#  NSE cal: 0.7921
#  NSE val: 0.7786
#
# === Station 21008 ===, Number = 71
#  NSE cal: 0.7370
#  NSE val: 0.7239
#
# === Station 21009 ===, Number = 72
#  NSE cal: 0.7421
#  NSE val: 0.7165
#
# === Station 21011 ===, Number = 73
#  NSE cal: 0.7775
#  NSE val: 0.7611
#
# === Station 21012 ===, Number = 74
#  NSE cal: 0.8033
#  NSE val: 0.7784
#
# === Station 21013 ===, Number = 75
#  NSE cal: 0.7560
#  NSE val: 0.6647
#
# === Station 21015 ===, Number = 76
# ⚠️ Too many missing values (11.0%)
#
# === Station 21016 ===, Number = 77
#  NSE cal: 0.6528
#  NSE val: 0.6923
#
# === Station 21017 ===, Number = 78
# ⚠️ Too many missing values (15.2%)
#
# === Station 21018 ===, Number = 79
#  NSE cal: 0.7840
#  NSE val: 0.6670
#
# === Station 21022 ===, Number = 80
#  NSE cal: 0.6992
#  NSE val: 0.5595
#
# === Station 21023 ===, Number = 81
#  NSE cal: 0.4797
#  NSE val: 0.4294
#
# === Station 21024 ===, Number = 82
#  NSE cal: 0.6748
#  NSE val: 0.6776
#
# === Station 21026 ===, Number = 83
#  NSE cal: 0.7211
#  NSE val: 0.7024
#
# === Station 21027 ===, Number = 84
#  NSE cal: 0.6516
#  NSE val: 0.5305
#
# === Station 22001 ===, Number = 85
#  NSE cal: 0.7286
#  NSE val: 0.6509
#
# === Station 22006 ===, Number = 86
#  NSE cal: 0.7654
#  NSE val: 0.6616
#
# === Station 22007 ===, Number = 87
#  NSE cal: 0.7477
#  NSE val: 0.6612
#
# === Station 22009 ===, Number = 88
#  NSE cal: 0.6916
#  NSE val: 0.6263
#
# === Station 23001 ===, Number = 89
#  NSE cal: 0.7385
#  NSE val: 0.7052
#
# === Station 23004 ===, Number = 90
#  NSE cal: 0.7506
#  NSE val: 0.7475
#
# === Station 23006 ===, Number = 91
#  NSE cal: 0.7763
#  NSE val: 0.7827
#
# === Station 23007 ===, Number = 92
#  NSE cal: 0.6754
#  NSE val: 0.6580
#
# === Station 23008 ===, Number = 93
#  NSE cal: 0.7042
#  NSE val: 0.6585
#
# === Station 23011 ===, Number = 94
#  NSE cal: 0.7061
#  NSE val: 0.7029
#
# === Station 23016 ===, Number = 95
#  NSE cal: 0.7856
#  NSE val: 0.7846
#
# === Station 24001 ===, Number = 96
#  NSE cal: 0.7390
#  NSE val: 0.6915
#
# === Station 24003 ===, Number = 97
#  NSE cal: 0.7358
#  NSE val: 0.7392
#
# === Station 24004 ===, Number = 98
#  NSE cal: 0.7543
#  NSE val: 0.6979
#
# === Station 24005 ===, Number = 99
#  NSE cal: 0.7516
#  NSE val: 0.7065
#
# === Station 25001 ===, Number = 100
#  NSE cal: 0.7177
#  NSE val: 0.6755
#
# === Station 25003 ===, Number = 101
#  NSE cal: 0.6171
#  NSE val: 0.6045
#
# === Station 25006 ===, Number = 102
#  NSE cal: 0.7774
#  NSE val: 0.7312
#
# === Station 25012 ===, Number = 103
#  NSE cal: 0.7471
#  NSE val: 0.7638
#
# === Station 25020 ===, Number = 104
#  NSE cal: 0.7311
#  NSE val: 0.6953
#
# === Station 25021 ===, Number = 105
#  NSE cal: 0.6816
#  NSE val: 0.5915
#
# === Station 25029 ===, Number = 106
# ⚠️ Too many missing values (68.0%)
#
# === Station 26003 ===, Number = 107
#  NSE cal: 0.9017
#  NSE val: 0.8472
#
# === Station 26005 ===, Number = 108
#  NSE cal: 0.7432
#  NSE val: 0.5779
#
# === Station 26006 ===, Number = 109
#  NSE cal: 0.8485
#  NSE val: 0.7969
#
# === Station 26008 ===, Number = 110
#  NSE cal: 0.8309
#  NSE val: 0.8380
#
# === Station 26009 ===, Number = 111
#  NSE cal: 0.8768
#  NSE val: 0.7263
#
# === Station 27001 ===, Number = 112
#  NSE cal: 0.7580
#  NSE val: 0.7071
#
# === Station 27002 ===, Number = 113
#  NSE cal: 0.7168
#  NSE val: 0.6467
#
# === Station 27003 ===, Number = 114
#  NSE cal: 0.7800
#  NSE val: 0.7562
#
# === Station 27006 ===, Number = 115
#  NSE cal: 0.7586
#  NSE val: 0.7470
#
# === Station 27007 ===, Number = 116
#  NSE cal: 0.7161
#  NSE val: 0.6741
#
# === Station 27009 ===, Number = 117
#  NSE cal: 0.7590
#  NSE val: 0.7193
#
# === Station 27021 ===, Number = 118
#  NSE cal: 0.7464
#  NSE val: 0.7053
#
# === Station 27023 ===, Number = 119
#  NSE cal: 0.6280
#  NSE val: 0.7165
#
# === Station 27025 ===, Number = 120
#  NSE cal: 0.6923
#  NSE val: 0.6131
#
# === Station 27026 ===, Number = 121
#  NSE cal: 0.7580
#  NSE val: 0.7322
#
# === Station 27029 ===, Number = 122
#  NSE cal: 0.8319
#  NSE val: 0.8071
#
# === Station 27030 ===, Number = 123
#  NSE cal: 0.7394
#  NSE val: 0.7046
#
# === Station 27032 ===, Number = 124
#  NSE cal: 0.8026
#  NSE val: 0.7716
#
# === Station 27034 ===, Number = 125
#  NSE cal: 0.7875
#  NSE val: 0.7592
#
# === Station 27035 ===, Number = 126
#  NSE cal: 0.8573
#  NSE val: 0.8332
#
# === Station 27038 ===, Number = 127
#  NSE cal: 0.4614
#  NSE val: 0.2013
#
# === Station 27041 ===, Number = 128
#  NSE cal: 0.8524
#  NSE val: 0.8237
#
# === Station 27042 ===, Number = 129
#  NSE cal: 0.7732
#  NSE val: 0.7296
#
# === Station 27043 ===, Number = 130
#  NSE cal: 0.7863
#  NSE val: 0.7742
#
# === Station 27047 ===, Number = 131
#  NSE cal: 0.8629
#  NSE val: 0.8739
#
# === Station 27049 ===, Number = 132
#  NSE cal: 0.7446
#  NSE val: 0.7193
#
# === Station 27051 ===, Number = 133
#  NSE cal: 0.8098
#  NSE val: 0.8054
#
# === Station 27062 ===, Number = 134
#  NSE cal: 0.7760
#  NSE val: 0.7596
#
# === Station 27064 ===, Number = 135
#  NSE cal: 0.6851
#  NSE val: 0.6240
#
# === Station 27065 ===, Number = 136
#  NSE cal: 0.8226
#  NSE val: 0.8100
#
# === Station 27071 ===, Number = 137
#  NSE cal: 0.7206
#  NSE val: 0.6670
#
# === Station 27073 ===, Number = 138
#  NSE cal: 0.8528
#  NSE val: 0.8703
#
# === Station 27077 ===, Number = 139
#  NSE cal: 0.7602
#  NSE val: 0.7809
#
# === Station 27079 ===, Number = 140
#  NSE cal: 0.7587
#  NSE val: 0.7506
#
# === Station 27080 ===, Number = 141
#  NSE cal: 0.7974
#  NSE val: 0.7888
#
# === Station 27084 ===, Number = 142
#  NSE cal: 0.8445
#  NSE val: 0.8296
#
# === Station 27087 ===, Number = 143
#  NSE cal: 0.8584
#  NSE val: 0.8395
#
# === Station 27089 ===, Number = 144
#  NSE cal: 0.7188
#  NSE val: 0.7049
#
# === Station 27090 ===, Number = 145
# ⚠️ Too many missing values (11.8%)
#
# === Station 28001 ===, Number = 146
#  NSE cal: 0.5717
#  NSE val: 0.4923
#
# === Station 28003 ===, Number = 147
# ⚠️ Too many missing values (12.3%)
#
# === Station 28008 ===, Number = 148
#  NSE cal: 0.8205
#  NSE val: 0.7678
#
# === Station 28009 ===, Number = 149
#  NSE cal: 0.7953
#  NSE val: 0.7998
#
# === Station 28012 ===, Number = 150
# ⚠️ Too many missing values (11.3%)
#
# === Station 28015 ===, Number = 151
#  NSE cal: 0.7355
#  NSE val: 0.6905
#
# === Station 28018 ===, Number = 152
#  NSE cal: 0.7450
#  NSE val: 0.7256
#
# === Station 28022 ===, Number = 153
#  NSE cal: 0.7777
#  NSE val: 0.7895
#
# === Station 28023 ===, Number = 154
# ⚠️ Too many missing values (16.6%)
#
# === Station 28024 ===, Number = 155
#  NSE cal: 0.7355
#  NSE val: 0.7445
#
# === Station 28026 ===, Number = 156
#  NSE cal: 0.6535
#  NSE val: 0.6532
#
# === Station 28031 ===, Number = 157
#  NSE cal: 0.8056
#  NSE val: 0.7655
#
# === Station 28033 ===, Number = 158
# ⚠️ Too many missing values (27.2%)
#
# === Station 28039 ===, Number = 159
#  NSE cal: 0.7823
#  NSE val: 0.6921
#
# === Station 28040 ===, Number = 160
#  NSE cal: 0.7614
#  NSE val: 0.7127
#
# === Station 28043 ===, Number = 161
#  NSE cal: 0.7924
#  NSE val: 0.7648
#
# === Station 28044 ===, Number = 162
#  NSE cal: 0.8027
#  NSE val: 0.5787
#
# === Station 28046 ===, Number = 163
#  NSE cal: 0.8866
#  NSE val: 0.8440
#
# === Station 28048 ===, Number = 164
#  NSE cal: 0.6986
#  NSE val: 0.6498
#
# === Station 28050 ===, Number = 165
#  NSE cal: 0.7191
#  NSE val: 0.6589
#
# === Station 28052 ===, Number = 166
#  NSE cal: 0.6761
#  NSE val: 0.6475
#
# === Station 28055 ===, Number = 167
#  NSE cal: 0.8114
#  NSE val: 0.7556
#
# === Station 28056 ===, Number = 168
#  NSE cal: 0.7124
#  NSE val: 0.6861
#
# === Station 28060 ===, Number = 169
#  NSE cal: 0.6297
#  NSE val: 0.5915
#
# === Station 28066 ===, Number = 170
#  NSE cal: 0.7133
#  NSE val: 0.6526
#
# === Station 28067 ===, Number = 171
#  NSE cal: 0.7874
#  NSE val: 0.7564
#
# === Station 28072 ===, Number = 172
#  NSE cal: 0.6935
#  NSE val: 0.6203
#
# === Station 28074 ===, Number = 173
#  NSE cal: 0.7439
#  NSE val: 0.7647
#
# === Station 28080 ===, Number = 174
#  NSE cal: 0.6823
#  NSE val: 0.6548
#
# === Station 28081 ===, Number = 175
#  NSE cal: 0.7110
#  NSE val: 0.7091
#
# === Station 28082 ===, Number = 176
#  NSE cal: 0.7464
#  NSE val: 0.7406
#
# === Station 28085 ===, Number = 177
#  NSE cal: 0.8444
#  NSE val: 0.8178
#
# === Station 28091 ===, Number = 178
#  NSE cal: 0.7512
#  NSE val: 0.6486
#
# === Station 28093 ===, Number = 179
#  NSE cal: 0.7366
#  NSE val: 0.7343
#
# === Station 28115 ===, Number = 180
#  NSE cal: 0.7244
#  NSE val: 0.6899
#
# === Station 28116 ===, Number = 181
# ⚠️ Too many missing values (28.2%)
#
# === Station 28117 ===, Number = 182
# ⚠️ Too many missing values (28.0%)
#
# === Station 29002 ===, Number = 183
#  NSE cal: 0.8416
#  NSE val: 0.7827
#
# === Station 29003 ===, Number = 184
#  NSE cal: 0.8500
#  NSE val: 0.8144
#
# === Station 29005 ===, Number = 185
#  NSE cal: 0.6540
#  NSE val: 0.5748
#
# === Station 29009 ===, Number = 186
#  NSE cal: 0.8200
#  NSE val: 0.8439
#
# === Station 30001 ===, Number = 187
#  NSE cal: 0.8038
#  NSE val: 0.7824
#
# === Station 30004 ===, Number = 188
#  NSE cal: 0.7394
#  NSE val: 0.7035
#
# === Station 30005 ===, Number = 189
# ⚠️ Too many missing values (24.0%)
#
# === Station 30011 ===, Number = 190
#  NSE cal: 0.8385
#  NSE val: 0.8100
#
# === Station 30012 ===, Number = 191
#  NSE cal: 0.7199
#  NSE val: 0.6661
#
# === Station 30014 ===, Number = 192
#  NSE cal: 0.6951
#  NSE val: 0.6585
#
# === Station 30015 ===, Number = 193
#  NSE cal: 0.8812
#  NSE val: 0.8792
#
# === Station 3003 ===, Number = 194
#  NSE cal: 0.7780
#  NSE val: 0.7656
#
# === Station 31002 ===, Number = 195
#  NSE cal: 0.7664
#  NSE val: 0.6631
#
# === Station 31006 ===, Number = 196
#  NSE cal: 0.8751
#  NSE val: 0.8185
#
# === Station 31010 ===, Number = 197
#  NSE cal: 0.7320
#  NSE val: 0.6499
#
# === Station 31021 ===, Number = 198
#  NSE cal: 0.7208
#  NSE val: 0.6632
#
# === Station 31023 ===, Number = 199
#  NSE cal: 0.7074
#  NSE val: 0.6468
#
# === Station 31025 ===, Number = 200
#  NSE cal: 0.7339
#  NSE val: 0.6604
#
# === Station 32003 ===, Number = 201
#  NSE cal: 0.6996
#  NSE val: 0.5927
#
# === Station 32004 ===, Number = 202
#  NSE cal: 0.7473
#  NSE val: 0.6879
#
# === Station 32006 ===, Number = 203
#  NSE cal: 0.7675
#  NSE val: 0.7772
#
# === Station 32008 ===, Number = 204
#  NSE cal: 0.7749
#  NSE val: 0.7796
#
# === Station 33006 ===, Number = 205
#  NSE cal: 0.8655
#  NSE val: 0.7417
#
# === Station 33007 ===, Number = 206
#  NSE cal: 0.8687
#  NSE val: 0.8241
#
# === Station 33012 ===, Number = 207
#  NSE cal: 0.6922
#  NSE val: 0.6144
#
# === Station 33013 ===, Number = 208
#  NSE cal: 0.8039
#  NSE val: 0.7514
#
# === Station 33014 ===, Number = 209
#  NSE cal: 0.7772
#  NSE val: 0.7145
#
# === Station 33018 ===, Number = 210
#  NSE cal: 0.7733
#  NSE val: 0.7002
#
# === Station 33019 ===, Number = 211
#  NSE cal: 0.8928
#  NSE val: 0.8531
#
# === Station 33020 ===, Number = 212
# ⚠️ Too many missing values (17.1%)
#
# === Station 33021 ===, Number = 213
#  NSE cal: 0.8110
#  NSE val: 0.7284
#
# === Station 33022 ===, Number = 214
#  NSE cal: 0.7844
#  NSE val: 0.7235
#
# === Station 33023 ===, Number = 215
#  NSE cal: 0.7280
#  NSE val: 0.6354
#
# === Station 33024 ===, Number = 216
#  NSE cal: 0.7492
#  NSE val: 0.6711
#
# === Station 33026 ===, Number = 217
#  NSE cal: 0.8342
#  NSE val: 0.7999
#
# === Station 33028 ===, Number = 218
#  NSE cal: 0.6409
#  NSE val: 0.5896
#
# === Station 33029 ===, Number = 219
#  NSE cal: 0.8926
#  NSE val: 0.8618
#
# === Station 33031 ===, Number = 220
#  NSE cal: 0.6449
#  NSE val: 0.5238
#
# === Station 33032 ===, Number = 221
#  NSE cal: 0.9073
#  NSE val: 0.8843
#
# === Station 33033 ===, Number = 222
#  NSE cal: 0.7457
#  NSE val: 0.6297
#
# === Station 33034 ===, Number = 223
#  NSE cal: 0.8796
#  NSE val: 0.8445
#
# === Station 33035 ===, Number = 224
#  NSE cal: 0.8079
#  NSE val: 0.7764
#
# === Station 33039 ===, Number = 225
#  NSE cal: 0.8125
#  NSE val: 0.7894
#
# === Station 33053 ===, Number = 226
# ⚠️ Too many missing values (16.0%)
#
# === Station 33054 ===, Number = 227
#  NSE cal: 0.9070
#  NSE val: 0.8263
#
# === Station 33058 ===, Number = 228
#  NSE cal: 0.7088
#  NSE val: 0.6132
#
# === Station 34002 ===, Number = 229
#  NSE cal: 0.7344
#  NSE val: 0.7439
#
# === Station 34003 ===, Number = 230
#  NSE cal: 0.7605
#  NSE val: 0.7261
#
# === Station 34004 ===, Number = 231
#  NSE cal: 0.7360
#  NSE val: 0.7837
#
# === Station 34005 ===, Number = 232
#  NSE cal: 0.6491
#  NSE val: 0.6392
#
# === Station 34006 ===, Number = 233
#  NSE cal: 0.7256
#  NSE val: 0.7423
#
# === Station 34007 ===, Number = 234
#  NSE cal: 0.6549
#  NSE val: 0.6278
#
# === Station 34008 ===, Number = 235
#  NSE cal: 0.6726
#  NSE val: 0.5356
#
# === Station 34010 ===, Number = 236
#  NSE cal: 0.7510
#  NSE val: 0.6616
#
# === Station 34011 ===, Number = 237
#  NSE cal: 0.7853
#  NSE val: 0.7493
#
# === Station 34012 ===, Number = 238
#  NSE cal: 0.9203
#  NSE val: 0.8769
#
# === Station 35003 ===, Number = 239
#  NSE cal: 0.5012
#  NSE val: 0.3597
#
# === Station 35008 ===, Number = 240
#  NSE cal: 0.7296
#  NSE val: 0.6965
#
# === Station 36003 ===, Number = 241
#  NSE cal: 0.7102
#  NSE val: 0.6775
#
# === Station 36006 ===, Number = 242
#  NSE cal: 0.7110
#  NSE val: 0.7102
#
# === Station 36009 ===, Number = 243
#  NSE cal: 0.7353
#  NSE val: 0.6629
#
# === Station 36010 ===, Number = 244
#  NSE cal: 0.6983
#  NSE val: 0.7225
#
# === Station 36011 ===, Number = 245
#  NSE cal: 0.7539
#  NSE val: 0.6640
#
# === Station 36012 ===, Number = 246
#  NSE cal: 0.0589
#  NSE val: -0.0055
#
# === Station 37001 ===, Number = 247
#  NSE cal: 0.7852
#  NSE val: 0.7947
#
# === Station 37003 ===, Number = 248
#  NSE cal: 0.7333
#  NSE val: 0.6478
#
# === Station 37005 ===, Number = 249
#  NSE cal: 0.7280
#  NSE val: 0.7365
#
# === Station 37008 ===, Number = 250
#  NSE cal: 0.7058
#  NSE val: 0.7006
#
# === Station 37009 ===, Number = 251
#  NSE cal: 0.6011
#  NSE val: 0.6130
#
# === Station 37010 ===, Number = 252
#  NSE cal: 0.5945
#  NSE val: 0.6455
#
# === Station 37011 ===, Number = 253
#  NSE cal: 0.7016
#  NSE val: 0.6808
#
# === Station 37018 ===, Number = 254
#  NSE cal: 0.6742
#  NSE val: 0.6387
#
# === Station 37019 ===, Number = 255
#  NSE cal: 0.7014
#  NSE val: 0.7204
#
# === Station 37020 ===, Number = 256
#  NSE cal: 0.7263
#  NSE val: 0.6325
#
# === Station 37031 ===, Number = 257
#  NSE cal: 0.6026
#  NSE val: 0.5981
#
# === Station 37033 ===, Number = 258
#  NSE cal: 0.7064
#  NSE val: 0.7440
#
# === Station 38001 ===, Number = 259
#  NSE cal: 0.7651
#  NSE val: 0.7269
#
# === Station 38003 ===, Number = 260
#  NSE cal: 0.8753
#  NSE val: 0.8150
#
# === Station 38004 ===, Number = 261
#  NSE cal: 0.6584
#  NSE val: 0.5998
#
# === Station 38007 ===, Number = 262
#  NSE cal: 0.7320
#  NSE val: 0.7132
#
# === Station 38012 ===, Number = 263
#  NSE cal: 0.6379
#  NSE val: 0.7644
#
# === Station 38014 ===, Number = 264
#  NSE cal: 0.7669
#  NSE val: 0.7196
#
# === Station 38017 ===, Number = 265
#  NSE cal: 0.9041
#  NSE val: 0.8597
#
# === Station 38018 ===, Number = 266
#  NSE cal: 0.7891
#  NSE val: 0.7538
#
# === Station 38021 ===, Number = 267
#  NSE cal: 0.7478
#  NSE val: 0.7425
#
# === Station 38026 ===, Number = 268
#  NSE cal: 0.7907
#  NSE val: 0.7412
#
# === Station 38029 ===, Number = 269
#  NSE cal: 0.6125
#  NSE val: 0.6483
#
# === Station 38030 ===, Number = 270
#  NSE cal: 0.5963
#  NSE val: 0.5185
#
# === Station 39001 ===, Number = 271
#  NSE cal: 0.9079
#  NSE val: 0.9023
#
# === Station 39002 ===, Number = 272
#  NSE cal: 0.9035
#  NSE val: 0.8955
#
# === Station 39004 ===, Number = 273
#  NSE cal: 0.6941
#  NSE val: 0.6192
#
# === Station 39005 ===, Number = 274
#  NSE cal: 0.6485
#  NSE val: 0.5366
#
# === Station 39006 ===, Number = 275
#  NSE cal: 0.9440
#  NSE val: 0.9184
#
# === Station 39007 ===, Number = 276
#  NSE cal: 0.7889
#  NSE val: 0.7397
#
# === Station 39008 ===, Number = 277
#  NSE cal: 0.9238
#  NSE val: 0.8977
#
# === Station 39010 ===, Number = 278
#  NSE cal: 0.8654
#  NSE val: 0.7470
#
# === Station 39011 ===, Number = 279
#  NSE cal: 0.7383
#  NSE val: 0.7200
#
# === Station 39012 ===, Number = 280
#  NSE cal: 0.6598
#  NSE val: 0.6623
#
# === Station 39014 ===, Number = 281
#  NSE cal: 0.8627
#  NSE val: 0.8349
#
# === Station 39015 ===, Number = 282
#  NSE cal: 0.9093
#  NSE val: 0.8251
#
# === Station 39016 ===, Number = 283
#  NSE cal: 0.8983
#  NSE val: 0.8779
#
# === Station 39017 ===, Number = 284
#  NSE cal: 0.6429
#  NSE val: 0.5829
#
# === Station 39019 ===, Number = 285
#  NSE cal: 0.9402
#  NSE val: 0.9261
#
# === Station 39020 ===, Number = 286
#  NSE cal: 0.9506
#  NSE val: 0.9507
#
# === Station 39021 ===, Number = 287
#  NSE cal: 0.8542
#  NSE val: 0.8149
#
# === Station 39022 ===, Number = 288
#  NSE cal: 0.7785
#  NSE val: 0.7207
#
# === Station 39023 ===, Number = 289
#  NSE cal: 0.9199
#  NSE val: 0.1630
#
# === Station 39025 ===, Number = 290
#  NSE cal: 0.7948
#  NSE val: 0.8072
#
# === Station 39027 ===, Number = 291
#  NSE cal: 0.7766
#  NSE val: 0.7112
#
# === Station 39028 ===, Number = 292
#  NSE cal: 0.9121
#  NSE val: 0.9421
#
# === Station 39029 ===, Number = 293
#  NSE cal: 0.6883
#  NSE val: 0.6577
#
# === Station 39034 ===, Number = 294
#  NSE cal: 0.9142
#  NSE val: 0.8562
#
# === Station 39035 ===, Number = 295
#  NSE cal: 0.9278
#  NSE val: 0.5568
#
# === Station 39036 ===, Number = 296
#  NSE cal: 0.4839
#  NSE val: 0.1684
#
# === Station 39037 ===, Number = 297
#  NSE cal: 0.8882
#  NSE val: 0.8606
#
# === Station 39042 ===, Number = 298
#  NSE cal: 0.8968
#  NSE val: 0.7627
#
# === Station 39049 ===, Number = 299
#  NSE cal: 0.7737
#  NSE val: 0.7968
#
# === Station 39052 ===, Number = 300
#  NSE cal: 0.7445
#  NSE val: 0.7448
#
# === Station 39054 ===, Number = 301
# ⚠️ Too many missing values (16.3%)
#
# === Station 39056 ===, Number = 302
#  NSE cal: 0.7529
#  NSE val: 0.7743
#
# === Station 39061 ===, Number = 303
#  NSE cal: 0.8707
#  NSE val: 0.8421
#
# === Station 39065 ===, Number = 304
#  NSE cal: 0.8792
#  NSE val: 0.8251
#
# === Station 39069 ===, Number = 305
#  NSE cal: 0.7008
#  NSE val: 0.7069
#
# === Station 39072 ===, Number = 306
#  NSE cal: 0.8949
#  NSE val: 0.8964
#
# === Station 39078 ===, Number = 307
#  NSE cal: 0.7436
#  NSE val: 0.7628
#
# === Station 39081 ===, Number = 308
#  NSE cal: 0.8673
#  NSE val: 0.8279
#
# === Station 39087 ===, Number = 309
#  NSE cal: 0.7460
#  NSE val: 0.7126
#
# === Station 39088 ===, Number = 310
#  NSE cal: 0.9032
#  NSE val: 0.8187
#
# === Station 39095 ===, Number = 311
#  NSE cal: 0.7458
#  NSE val: 0.7684
#
# === Station 39099 ===, Number = 312
#  NSE cal: 0.9101
#  NSE val: 0.7293
#
# === Station 39101 ===, Number = 313
#  NSE cal: 0.8778
#  NSE val: 0.5433
#
# === Station 39105 ===, Number = 314
#  NSE cal: 0.8279
#  NSE val: 0.8112
#
# === Station 39108 ===, Number = 315
#  NSE cal: 0.9112
#  NSE val: 0.8648
#
# === Station 39114 ===, Number = 316
#  NSE cal: 0.8104
#  NSE val: 0.8299
#
# === Station 39120 ===, Number = 317
#  NSE cal: 0.7627
#  NSE val: 0.7473
#
# === Station 39125 ===, Number = 318
# ⚠️ Too many missing values (12.5%)
#
# === Station 39127 ===, Number = 319
# ⚠️ Too many missing values (17.6%)
#
# === Station 39141 ===, Number = 320
# ⚠️ Too many missing values (31.3%)
#
# === Station 39142 ===, Number = 321
# ⚠️ Too many missing values (23.0%)
#
# === Station 39143 ===, Number = 322
# ⚠️ Too many missing values (23.0%)
#
# === Station 39144 ===, Number = 323
# ⚠️ Too many missing values (23.0%)
#
# === Station 40003 ===, Number = 324
#  NSE cal: 0.7853
#  NSE val: 0.7576
#
# === Station 40004 ===, Number = 325
#  NSE cal: 0.7708
#  NSE val: 0.7465
#
# === Station 40005 ===, Number = 326
#  NSE cal: 0.6950
#  NSE val: 0.6877
#
# === Station 40006 ===, Number = 327
#  NSE cal: 0.6133
#  NSE val: -1.7027
#
# === Station 40007 ===, Number = 328
#  NSE cal: 0.7621
#  NSE val: 0.7710
#
# === Station 40009 ===, Number = 329
#  NSE cal: 0.6533
#  NSE val: 0.7205
#
# === Station 4001 ===, Number = 330
#  NSE cal: 0.7996
#  NSE val: 0.7704
#
# === Station 40010 ===, Number = 331
#  NSE cal: 0.6891
#  NSE val: 0.7165
#
# === Station 40011 ===, Number = 332
#  NSE cal: 0.8201
#  NSE val: 0.8388
#
# === Station 40012 ===, Number = 333
#  NSE cal: 0.8279
#  NSE val: 0.8598
#
# === Station 40013 ===, Number = 334
#  NSE cal: 0.7033
#  NSE val: 0.5930
#
# === Station 40016 ===, Number = 335
#  NSE cal: 0.5483
#  NSE val: 0.4167
#
# === Station 40017 ===, Number = 336
#  NSE cal: 0.7880
#  NSE val: 0.6748
#
# === Station 40018 ===, Number = 337
#  NSE cal: 0.7815
#  NSE val: 0.8274
#
# === Station 40020 ===, Number = 338
#  NSE cal: 0.7414
#  NSE val: 0.7437
#
# === Station 40021 ===, Number = 339
#  NSE cal: 0.7626
#  NSE val: 0.7530
#
# === Station 40022 ===, Number = 340
# ⚠️ Too many missing values (44.9%)
#
# === Station 4003 ===, Number = 341
#  NSE cal: 0.6099
#  NSE val: 0.5612
#
# === Station 40033 ===, Number = 342
#  NSE cal: 0.8525
#  NSE val: 0.8697
#
# === Station 4005 ===, Number = 343
#  NSE cal: 0.7172
#  NSE val: 0.7260
#
# === Station 4006 ===, Number = 344
#  NSE cal: 0.8258
#  NSE val: 0.8184
#
# === Station 41001 ===, Number = 345
#  NSE cal: 0.7274
#  NSE val: 0.6246
#
# === Station 41003 ===, Number = 346
#  NSE cal: 0.7285
#  NSE val: 0.6964
#
# === Station 41004 ===, Number = 347
# ⚠️ Too many missing values (19.1%)
#
# === Station 41005 ===, Number = 348
#  NSE cal: 0.7549
#  NSE val: 0.7433
#
# === Station 41006 ===, Number = 349
#  NSE cal: 0.7363
#  NSE val: 0.7054
#
# === Station 41009 ===, Number = 350
#  NSE cal: 0.8024
#  NSE val: 0.7573
#
# === Station 41011 ===, Number = 351
#  NSE cal: 0.7561
#  NSE val: 0.7043
#
# === Station 41012 ===, Number = 352
#  NSE cal: 0.7604
#  NSE val: 0.6953
#
# === Station 41013 ===, Number = 353
#  NSE cal: 0.7843
#  NSE val: 0.7535
#
# === Station 41014 ===, Number = 354
#  NSE cal: 0.7263
#  NSE val: 0.4569
#
# === Station 41016 ===, Number = 355
#  NSE cal: 0.7895
#  NSE val: 0.7715
#
# === Station 41019 ===, Number = 356
#  NSE cal: 0.6336
#  NSE val: 0.6823
#
# === Station 41020 ===, Number = 357
#  NSE cal: 0.7657
#  NSE val: 0.7370
#
# === Station 41022 ===, Number = 358
#  NSE cal: 0.7625
#  NSE val: 0.7083
#
# === Station 41023 ===, Number = 359
#  NSE cal: 0.8342
#  NSE val: 0.7144
#
# === Station 41025 ===, Number = 360
#  NSE cal: 0.6918
#  NSE val: 0.6084
#
# === Station 41027 ===, Number = 361
#  NSE cal: 0.7191
#  NSE val: 0.7115
#
# === Station 41028 ===, Number = 362
#  NSE cal: 0.6951
#  NSE val: 0.6918
#
# === Station 41029 ===, Number = 363
#  NSE cal: 0.7545
#  NSE val: 0.7534
#
# === Station 42001 ===, Number = 364
#  NSE cal: 0.7940
#  NSE val: 0.7352
#
# === Station 42003 ===, Number = 365
#  NSE cal: 0.7221
#  NSE val: 0.6849
#
# === Station 42004 ===, Number = 366
#  NSE cal: 0.9226
#  NSE val: 0.8649
#
# === Station 42006 ===, Number = 367
#  NSE cal: 0.9307
#  NSE val: 0.9401
#
# === Station 42008 ===, Number = 368
#  NSE cal: 0.9178
#  NSE val: 0.9462
#
# === Station 42010 ===, Number = 369
#  NSE cal: 0.9382
#  NSE val: 0.9242
#
# === Station 42011 ===, Number = 370
#  NSE cal: 0.7436
#  NSE val: 0.7471
#
# === Station 42016 ===, Number = 371
#  NSE cal: 0.9364
#  NSE val: 0.9029
#
# === Station 42017 ===, Number = 372
#  NSE cal: 0.7458
#  NSE val: 0.7628
#
# === Station 42024 ===, Number = 373
#  NSE cal: 0.9404
#  NSE val: 0.9425
#
# === Station 42026 ===, Number = 374
# ⚠️ Too many missing values (40.5%)
#
# === Station 42027 ===, Number = 375
# ⚠️ Too many missing values (40.0%)
#
# === Station 43005 ===, Number = 376
#  NSE cal: 0.9344
#  NSE val: 0.9327
#
# === Station 43006 ===, Number = 377
#  NSE cal: 0.8651
#  NSE val: 0.8618
#
# === Station 43007 ===, Number = 378
#  NSE cal: 0.8430
#  NSE val: 0.8423
#
# === Station 43008 ===, Number = 379
#  NSE cal: 0.9093
#  NSE val: 0.9231
#
# === Station 43009 ===, Number = 380
#  NSE cal: 0.7440
#  NSE val: 0.7517
#
# === Station 43014 ===, Number = 381
#  NSE cal: 0.8188
#  NSE val: 0.7653
#
# === Station 43017 ===, Number = 382
#  NSE cal: 0.8880
#  NSE val: 0.8866
#
# === Station 43018 ===, Number = 383
#  NSE cal: 0.9303
#  NSE val: 0.9133
#
# === Station 43021 ===, Number = 384
#  NSE cal: 0.8873
#  NSE val: 0.7847
#
# === Station 44001 ===, Number = 385
#  NSE cal: 0.9054
#  NSE val: 0.9251
#
# === Station 44002 ===, Number = 386
#  NSE cal: 0.9364
#  NSE val: 0.9396
#
# === Station 44006 ===, Number = 387
#  NSE cal: 0.9289
#  NSE val: 0.9286
#
# === Station 44009 ===, Number = 388
#  NSE cal: 0.9429
#  NSE val: 0.9258
#
# === Station 44011 ===, Number = 389
# ⚠️ Too many missing values (24.7%)
#
# === Station 45001 ===, Number = 390
#  NSE cal: 0.8930
#  NSE val: 0.8665
#
# === Station 45003 ===, Number = 391
#  NSE cal: 0.7653
#  NSE val: 0.6870
#
# === Station 45004 ===, Number = 392
#  NSE cal: 0.7380
#  NSE val: 0.6976
#
# === Station 45005 ===, Number = 393
#  NSE cal: 0.7593
#  NSE val: 0.6752
#
# === Station 45009 ===, Number = 394
#  NSE cal: 0.8852
#  NSE val: 0.8463
#
# === Station 45012 ===, Number = 395
#  NSE cal: 0.8504
#  NSE val: 0.7849
#
# === Station 46003 ===, Number = 396
#  NSE cal: 0.8793
#  NSE val: 0.8404
#
# === Station 46005 ===, Number = 397
#  NSE cal: 0.8477
#  NSE val: 0.7917
#
# === Station 46008 ===, Number = 398
#  NSE cal: 0.8952
#  NSE val: 0.8441
#
# === Station 46014 ===, Number = 399
# ⚠️ Too many missing values (56.5%)
#
# === Station 47001 ===, Number = 400
#  NSE cal: 0.8803
#  NSE val: 0.8527
#
# === Station 47004 ===, Number = 401
#  NSE cal: 0.9149
#  NSE val: 0.8874
#
# === Station 47005 ===, Number = 402
#  NSE cal: 0.8486
#  NSE val: 0.7924
#
# === Station 47008 ===, Number = 403
#  NSE cal: 0.8574
#  NSE val: 0.8503
#
# === Station 47009 ===, Number = 404
#  NSE cal: 0.9216
#  NSE val: 0.9093
#
# === Station 47011 ===, Number = 405
# ⚠️ Too many missing values (41.2%)
#
# === Station 47014 ===, Number = 406
#  NSE cal: 0.8540
#  NSE val: 0.7818
#
# === Station 47018 ===, Number = 407
#  NSE cal: 0.8680
#  NSE val: 0.8439
#
# === Station 48003 ===, Number = 408
#  NSE cal: 0.8834
#  NSE val: 0.9166
#
# === Station 48004 ===, Number = 409
#  NSE cal: 0.8765
#  NSE val: 0.8366
#
# === Station 48005 ===, Number = 410
#  NSE cal: 0.9014
#  NSE val: 0.9070
#
# === Station 48011 ===, Number = 411
#  NSE cal: 0.9025
#  NSE val: 0.8653
#
# === Station 49001 ===, Number = 412
#  NSE cal: 0.9025
#  NSE val: 0.8788
#
# === Station 49002 ===, Number = 413
#  NSE cal: 0.9273
#  NSE val: 0.9363
#
# === Station 49004 ===, Number = 414
#  NSE cal: 0.8809
#  NSE val: 0.8490
#
# === Station 50001 ===, Number = 415
#  NSE cal: 0.8869
#  NSE val: 0.8604
#
# === Station 50002 ===, Number = 416
#  NSE cal: 0.8452
#  NSE val: 0.8020
#
# === Station 50006 ===, Number = 417
#  NSE cal: 0.8886
#  NSE val: 0.8822
#
# === Station 50007 ===, Number = 418
#  NSE cal: 0.8780
#  NSE val: 0.8287
#
# === Station 50008 ===, Number = 419
#  NSE cal: 0.8706
#  NSE val: 0.8507
#
# === Station 50011 ===, Number = 420
#  NSE cal: 0.8693
#  NSE val: 0.8331
#
# === Station 5003 ===, Number = 421
#  NSE cal: 0.7116
#  NSE val: 0.7065
#
# === Station 51001 ===, Number = 422
#  NSE cal: 0.8945
#  NSE val: 0.8606
#
# === Station 52004 ===, Number = 423
#  NSE cal: 0.7687
#  NSE val: 0.7669
#
# === Station 52005 ===, Number = 424
#  NSE cal: 0.8532
#  NSE val: 0.8176
#
# === Station 52006 ===, Number = 425
#  NSE cal: 0.7880
#  NSE val: 0.7793
#
# === Station 52007 ===, Number = 426
#  NSE cal: 0.7568
#  NSE val: 0.7826
#
# === Station 52009 ===, Number = 427
#  NSE cal: 0.8645
#  NSE val: 0.8267
#
# === Station 52010 ===, Number = 428
#  NSE cal: 0.8045
#  NSE val: 0.7673
#
# === Station 52011 ===, Number = 429
#  NSE cal: 0.7739
#  NSE val: 0.7001
#
# === Station 52015 ===, Number = 430
#  NSE cal: 0.8467
#  NSE val: 0.5440
#
# === Station 52016 ===, Number = 431
#  NSE cal: 0.8859
#  NSE val: 0.8772
#
# === Station 53005 ===, Number = 432
#  NSE cal: 0.8831
#  NSE val: 0.8567
#
# === Station 53006 ===, Number = 433
#  NSE cal: 0.8247
#  NSE val: 0.8112
#
# === Station 53007 ===, Number = 434
#  NSE cal: 0.8368
#  NSE val: 0.8039
#
# === Station 53008 ===, Number = 435
#  NSE cal: 0.8907
#  NSE val: 0.8430
#
# === Station 53009 ===, Number = 436
#  NSE cal: 0.9117
#  NSE val: 0.8985
#
# === Station 53013 ===, Number = 437
#  NSE cal: 0.8323
#  NSE val: 0.7610
#
# === Station 53017 ===, Number = 438
#  NSE cal: 0.8493
#  NSE val: 0.7993
#
# === Station 53018 ===, Number = 439
#  NSE cal: 0.8889
#  NSE val: 0.8686
#
# === Station 53022 ===, Number = 440
# ⚠️ Too many missing values (28.7%)
#
# === Station 53023 ===, Number = 441
#  NSE cal: 0.9330
#  NSE val: 0.9177
#
# === Station 53028 ===, Number = 442
#  NSE cal: 0.9038
#  NSE val: 0.8981
#
# === Station 54001 ===, Number = 443
#  NSE cal: 0.8347
#  NSE val: 0.8326
#
# === Station 54002 ===, Number = 444
#  NSE cal: 0.7649
#  NSE val: 0.7571
#
# === Station 54003 ===, Number = 445
#  NSE cal: 0.5845
#  NSE val: 0.5435
#
# === Station 54004 ===, Number = 446
#  NSE cal: 0.6996
#  NSE val: 0.6631
#
# === Station 54005 ===, Number = 447
#  NSE cal: 0.8592
#  NSE val: 0.8493
#
# === Station 54007 ===, Number = 448
#  NSE cal: 0.6640
#  NSE val: 0.5851
#
# === Station 54008 ===, Number = 449
#  NSE cal: 0.8664
#  NSE val: 0.8662
#
# === Station 54011 ===, Number = 450
# ⚠️ Too many missing values (11.7%)
#
# === Station 54012 ===, Number = 451
#  NSE cal: 0.7955
#  NSE val: 0.8227
#
# === Station 54015 ===, Number = 452
#  NSE cal: 0.6321
#  NSE val: 0.4784
#
# === Station 54016 ===, Number = 453
#  NSE cal: 0.8614
#  NSE val: 0.8361
#
# === Station 54017 ===, Number = 454
#  NSE cal: 0.7392
#  NSE val: 0.6072
#
# === Station 54018 ===, Number = 455
#  NSE cal: 0.8267
#  NSE val: 0.8177
#
# === Station 54019 ===, Number = 456
#  NSE cal: 0.6977
#  NSE val: 0.7077
#
# === Station 54020 ===, Number = 457
#  NSE cal: 0.8487
#  NSE val: 0.8583
#
# === Station 54022 ===, Number = 458
# ⚠️ Too many missing values (20.1%)
#
# === Station 54024 ===, Number = 459
#  NSE cal: 0.7799
#  NSE val: 0.7611
#
# === Station 54025 ===, Number = 460
#  NSE cal: 0.9019
#  NSE val: 0.8929
#
# === Station 54027 ===, Number = 461
#  NSE cal: 0.9269
#  NSE val: 0.9062
#
# === Station 54028 ===, Number = 462
#  NSE cal: 0.8264
#  NSE val: 0.8185
#
# === Station 54029 ===, Number = 463
#  NSE cal: 0.8356
#  NSE val: 0.8308
#
# === Station 54032 ===, Number = 464
#  NSE cal: 0.8471
#  NSE val: 0.8445
#
# === Station 54034 ===, Number = 465
#  NSE cal: 0.7451
#  NSE val: 0.8051
#
# === Station 54036 ===, Number = 466
#  NSE cal: 0.7378
#  NSE val: 0.7676
#
# === Station 54038 ===, Number = 467
#  NSE cal: 0.8940
#  NSE val: 0.8839
#
# === Station 54044 ===, Number = 468
#  NSE cal: 0.6702
#  NSE val: 0.6297
#
# === Station 54048 ===, Number = 469
#  NSE cal: 0.7069
#  NSE val: 0.6168
#
# === Station 54049 ===, Number = 470
#  NSE cal: 0.6854
#  NSE val: 0.6839
#
# === Station 54052 ===, Number = 471
#  NSE cal: 0.6102
#  NSE val: 0.7456
#
# === Station 54057 ===, Number = 472
#  NSE cal: 0.8418
#  NSE val: 0.8253
#
# === Station 54060 ===, Number = 473
#  NSE cal: 0.5571
#  NSE val: 0.5554
#
# === Station 54063 ===, Number = 474
# ⚠️ Too many missing values (21.0%)
#
# === Station 54080 ===, Number = 475
#  NSE cal: 0.7699
#  NSE val: 0.8228
#
# === Station 54095 ===, Number = 476
#  NSE cal: 0.8364
#  NSE val: 0.8292
#
# === Station 54096 ===, Number = 477
#  NSE cal: 0.7143
#  NSE val: 0.6874
#
# === Station 55002 ===, Number = 478
#  NSE cal: 0.8154
#  NSE val: 0.7899
#
# === Station 55007 ===, Number = 479
#  NSE cal: 0.8447
#  NSE val: 0.8424
#
# === Station 55008 ===, Number = 480
# ⚠️ Too many missing values (16.2%)
#
# === Station 55013 ===, Number = 481
#  NSE cal: 0.8623
#  NSE val: 0.8726
#
# === Station 55014 ===, Number = 482
#  NSE cal: 0.8840
#  NSE val: 0.8829
#
# === Station 55016 ===, Number = 483
#  NSE cal: 0.8394
#  NSE val: 0.8372
#
# === Station 55018 ===, Number = 484
#  NSE cal: 0.7435
#  NSE val: 0.6810
#
# === Station 55021 ===, Number = 485
#  NSE cal: 0.8695
#  NSE val: 0.8377
#
# === Station 55023 ===, Number = 486
#  NSE cal: 0.8403
#  NSE val: 0.8621
#
# === Station 55025 ===, Number = 487
#  NSE cal: 0.8642
#  NSE val: 0.8665
#
# === Station 55026 ===, Number = 488
#  NSE cal: 0.8397
#  NSE val: 0.8270
#
# === Station 55029 ===, Number = 489
#  NSE cal: 0.8016
#  NSE val: 0.7790
#
# === Station 55032 ===, Number = 490
#  NSE cal: 0.6728
#  NSE val: 0.6836
#
# === Station 56001 ===, Number = 491
#  NSE cal: 0.8613
#  NSE val: 0.8399
#
# === Station 56002 ===, Number = 492
#  NSE cal: 0.8980
#  NSE val: 0.8690
#
# === Station 56007 ===, Number = 493
#  NSE cal: 0.8739
#  NSE val: 0.8670
#
# === Station 56012 ===, Number = 494
#  NSE cal: 0.8877
#  NSE val: 0.8557
#
# === Station 56013 ===, Number = 495
#  NSE cal: 0.8934
#  NSE val: 0.8779
#
# === Station 57004 ===, Number = 496
#  NSE cal: 0.8797
#  NSE val: 0.8553
#
# === Station 57005 ===, Number = 497
#  NSE cal: 0.8828
#  NSE val: 0.8669
#
# === Station 57006 ===, Number = 498
#  NSE cal: 0.8828
#  NSE val: 0.8536
#
# === Station 57007 ===, Number = 499
#  NSE cal: 0.8552
#  NSE val: 0.8203
#
# === Station 57008 ===, Number = 500
#  NSE cal: 0.8685
#  NSE val: 0.8678
#
# === Station 57009 ===, Number = 501
#  NSE cal: 0.8286
#  NSE val: 0.8267
#
# === Station 58001 ===, Number = 502
#  NSE cal: 0.8468
#  NSE val: 0.8121
#
# === Station 58002 ===, Number = 503
#  NSE cal: 0.8670
#  NSE val: 0.8414
#
# === Station 58006 ===, Number = 504
#  NSE cal: 0.8971
#  NSE val: 0.8693
#
# === Station 58008 ===, Number = 505
#  NSE cal: 0.8619
#  NSE val: 0.8527
#
# === Station 58009 ===, Number = 506
#  NSE cal: 0.7732
#  NSE val: 0.8320
#
# === Station 58010 ===, Number = 507
# ⚠️ Too many missing values (13.2%)
#
# === Station 58012 ===, Number = 508
#  NSE cal: 0.8491
#  NSE val: 0.8270
#
# === Station 59001 ===, Number = 509
#  NSE cal: 0.8290
#  NSE val: 0.8183
#
# === Station 60002 ===, Number = 510
#  NSE cal: 0.8450
#  NSE val: 0.8559
#
# === Station 60003 ===, Number = 511
#  NSE cal: 0.8768
#  NSE val: 0.8184
#
# === Station 60005 ===, Number = 512
#  NSE cal: 0.8318
#  NSE val: 0.7568
#
# === Station 60006 ===, Number = 513
#  NSE cal: 0.8587
#  NSE val: 0.8732
#
# === Station 60010 ===, Number = 514
#  NSE cal: 0.8714
#  NSE val: 0.8599
#
# === Station 60012 ===, Number = 515
#  NSE cal: 0.8499
#  NSE val: 0.8071
#
# === Station 6007 ===, Number = 516
#  NSE cal: 0.8312
#  NSE val: 0.8237
#
# === Station 6008 ===, Number = 517
#  NSE cal: 0.7272
#  NSE val: 0.6930
#
# === Station 61001 ===, Number = 518
#  NSE cal: 0.8678
#  NSE val: 0.7672
#
# === Station 61002 ===, Number = 519
#  NSE cal: 0.8399
#  NSE val: 0.8358
#
# === Station 62001 ===, Number = 520
#  NSE cal: 0.8970
#  NSE val: 0.8912
#
# === Station 63001 ===, Number = 521
#  NSE cal: 0.8532
#  NSE val: 0.8186
#
# === Station 63004 ===, Number = 522
#  NSE cal: 0.8141
#  NSE val: 0.8330
#
# === Station 64001 ===, Number = 523
#  NSE cal: 0.8679
#  NSE val: 0.8553
#
# === Station 64002 ===, Number = 524
#  NSE cal: 0.8092
#  NSE val: 0.7622
#
# === Station 64006 ===, Number = 525
#  NSE cal: 0.8645
#  NSE val: 0.8245
#
# === Station 65001 ===, Number = 526
#  NSE cal: 0.7928
#  NSE val: 0.8206
#
# === Station 65004 ===, Number = 527
# ⚠️ Too many missing values (16.0%)
#
# === Station 65005 ===, Number = 528
#  NSE cal: 0.6170
#  NSE val: 0.7600
#
# === Station 65006 ===, Number = 529
#  NSE cal: 0.8109
#  NSE val: 0.8035
#
# === Station 65007 ===, Number = 530
#  NSE cal: 0.8106
#  NSE val: 0.8099
#
# === Station 65008 ===, Number = 531
#  NSE cal: 0.7952
#  NSE val: 0.7914
#
# === Station 66001 ===, Number = 532
#  NSE cal: 0.8805
#  NSE val: 0.8370
#
# === Station 66004 ===, Number = 533
#  NSE cal: 0.9007
#  NSE val: 0.8591
#
# === Station 66006 ===, Number = 534
#  NSE cal: 0.8713
#  NSE val: 0.8356
#
# === Station 66011 ===, Number = 535
#  NSE cal: 0.8256
#  NSE val: 0.8191
#
# === Station 67001 ===, Number = 536
#  NSE cal: 0.7969
#  NSE val: 0.8196
#
# === Station 67005 ===, Number = 537
#  NSE cal: 0.8690
#  NSE val: 0.8397
#
# === Station 67006 ===, Number = 538
#  NSE cal: 0.8775
#  NSE val: 0.8376
#
# === Station 67008 ===, Number = 539
#  NSE cal: 0.8515
#  NSE val: 0.7786
#
# === Station 67010 ===, Number = 540
#  NSE cal: 0.8198
#  NSE val: 0.8522
#
# === Station 67015 ===, Number = 541
#  NSE cal: 0.8746
#  NSE val: 0.8581
#
# === Station 67018 ===, Number = 542
#  NSE cal: 0.8461
#  NSE val: 0.8611
#
# === Station 67025 ===, Number = 543
#  NSE cal: 0.7466
#  NSE val: 0.7279
#
# === Station 67033 ===, Number = 544
# ⚠️ Too many missing values (23.3%)
#
# === Station 68001 ===, Number = 545
#  NSE cal: 0.7667
#  NSE val: 0.7673
#
# === Station 68003 ===, Number = 546
#  NSE cal: 0.7480
#  NSE val: 0.6824
#
# === Station 68004 ===, Number = 547
#  NSE cal: 0.6834
#  NSE val: 0.7280
#
# === Station 68005 ===, Number = 548
#  NSE cal: 0.8332
#  NSE val: 0.7683
#
# === Station 68020 ===, Number = 549
#  NSE cal: 0.6385
#  NSE val: 0.6120
#
# === Station 69002 ===, Number = 550
#  NSE cal: 0.7532
#  NSE val: 0.7713
#
# === Station 69007 ===, Number = 551
#  NSE cal: 0.7857
#  NSE val: 0.7646
#
# === Station 69012 ===, Number = 552
#  NSE cal: 0.7955
#  NSE val: 0.7653
#
# === Station 69015 ===, Number = 553
#  NSE cal: 0.7923
#  NSE val: 0.7506
#
# === Station 69017 ===, Number = 554
#  NSE cal: 0.8633
#  NSE val: 0.8215
#
# === Station 69023 ===, Number = 555
#  NSE cal: 0.8148
#  NSE val: 0.7788
#
# === Station 69027 ===, Number = 556
#  NSE cal: 0.7665
#  NSE val: 0.7741
#
# === Station 69030 ===, Number = 557
#  NSE cal: 0.7522
#  NSE val: 0.7276
#
# === Station 69032 ===, Number = 558
#  NSE cal: 0.7896
#  NSE val: 0.7901
#
# === Station 69043 ===, Number = 559
# ⚠️ Too many missing values (21.3%)
#
# === Station 70002 ===, Number = 560
#  NSE cal: 0.7860
#  NSE val: 0.7946
#
# === Station 7001 ===, Number = 561
#  NSE cal: 0.4593
#  NSE val: 0.4086
#
# === Station 7002 ===, Number = 562
#  NSE cal: 0.5251
#  NSE val: 0.4029
#
# === Station 7003 ===, Number = 563
#  NSE cal: 0.6882
#  NSE val: 0.4332
#
# === Station 7005 ===, Number = 564
#  NSE cal: 0.6823
#  NSE val: 0.4699
#
# === Station 7006 ===, Number = 565
#  NSE cal: 0.5668
#  NSE val: 0.3802
#
# === Station 71001 ===, Number = 566
#  NSE cal: 0.7796
#  NSE val: 0.7888
#
# === Station 71004 ===, Number = 567
#  NSE cal: 0.8184
#  NSE val: 0.8220
#
# === Station 71006 ===, Number = 568
#  NSE cal: 0.8213
#  NSE val: 0.8145
#
# === Station 71008 ===, Number = 569
#  NSE cal: 0.8173
#  NSE val: 0.8193
#
# === Station 71014 ===, Number = 570
#  NSE cal: 0.7774
#  NSE val: 0.7632
#
# === Station 72002 ===, Number = 571
#  NSE cal: 0.7871
#  NSE val: 0.7428
#
# === Station 72004 ===, Number = 572
#  NSE cal: 0.8120
#  NSE val: 0.7902
#
# === Station 72005 ===, Number = 573
#  NSE cal: 0.8595
#  NSE val: 0.8426
#
# === Station 72007 ===, Number = 574
#  NSE cal: 0.8128
#  NSE val: 0.7935
#
# === Station 72009 ===, Number = 575
#  NSE cal: 0.8138
#  NSE val: 0.8190
#
# === Station 72014 ===, Number = 576
#  NSE cal: 0.8229
#  NSE val: 0.8009
#
# === Station 72015 ===, Number = 577
#  NSE cal: 0.8739
#  NSE val: 0.8624
#
# === Station 73005 ===, Number = 578
#  NSE cal: 0.8545
#  NSE val: 0.8349
#
# === Station 73009 ===, Number = 579
#  NSE cal: 0.8468
#  NSE val: 0.8324
#
# === Station 73010 ===, Number = 580
#  NSE cal: 0.8910
#  NSE val: 0.8764
#
# === Station 73011 ===, Number = 581
#  NSE cal: 0.8818
#  NSE val: 0.8694
#
# === Station 73014 ===, Number = 582
#  NSE cal: 0.7486
#  NSE val: 0.7371
#
# === Station 73015 ===, Number = 583
#  NSE cal: 0.7882
#  NSE val: 0.7788
#
# === Station 74001 ===, Number = 584
#  NSE cal: 0.8283
#  NSE val: 0.7991
#
# === Station 74005 ===, Number = 585
#  NSE cal: 0.8069
#  NSE val: 0.8222
#
# === Station 74006 ===, Number = 586
#  NSE cal: 0.7872
#  NSE val: 0.7719
#
# === Station 74007 ===, Number = 587
#  NSE cal: 0.7730
#  NSE val: 0.7948
#
# === Station 75003 ===, Number = 588
#  NSE cal: 0.8824
#  NSE val: 0.8648
#
# === Station 75004 ===, Number = 589
#  NSE cal: 0.8700
#  NSE val: 0.8318
#
# === Station 75017 ===, Number = 590
#  NSE cal: 0.8562
#  NSE val: 0.8146
#
# === Station 76003 ===, Number = 591
#  NSE cal: 0.8781
#  NSE val: 0.8598
#
# === Station 76005 ===, Number = 592
#  NSE cal: 0.8066
#  NSE val: 0.7650
#
# === Station 76007 ===, Number = 593
#  NSE cal: 0.8058
#  NSE val: 0.7836
#
# === Station 76008 ===, Number = 594
#  NSE cal: 0.7072
#  NSE val: 0.6796
#
# === Station 76011 ===, Number = 595
#  NSE cal: 0.7535
#  NSE val: 0.7519
#
# === Station 76014 ===, Number = 596
#  NSE cal: 0.8479
#  NSE val: 0.7890
#
# === Station 77002 ===, Number = 597
#  NSE cal: 0.8280
#  NSE val: 0.8130
#
# === Station 77003 ===, Number = 598
#  NSE cal: 0.7705
#  NSE val: 0.7464
#
# === Station 77004 ===, Number = 599
#  NSE cal: 0.8318
#  NSE val: 0.8001
#
# === Station 78003 ===, Number = 600
#  NSE cal: 0.8281
#  NSE val: 0.7941
#
# === Station 78004 ===, Number = 601
#  NSE cal: 0.7964
#  NSE val: 0.7470
#
# === Station 78006 ===, Number = 602
#  NSE cal: 0.8497
#  NSE val: 0.8067
#
# === Station 79002 ===, Number = 603
#  NSE cal: 0.8280
#  NSE val: 0.7807
#
# === Station 79003 ===, Number = 604
#  NSE cal: 0.8065
#  NSE val: 0.7396
#
# === Station 79004 ===, Number = 605
#  NSE cal: 0.8412
#  NSE val: 0.8170
#
# === Station 79005 ===, Number = 606
#  NSE cal: 0.8331
#  NSE val: 0.7858
#
# === Station 79006 ===, Number = 607
#  NSE cal: 0.8348
#  NSE val: 0.7885
#
# === Station 80001 ===, Number = 608
#  NSE cal: 0.8354
#  NSE val: 0.7758
#
# === Station 80002 ===, Number = 609
#  NSE cal: 0.8317
#  NSE val: 0.8142
#
# === Station 80003 ===, Number = 610
#  NSE cal: 0.8259
#  NSE val: 0.7851
#
# === Station 80004 ===, Number = 611
#  NSE cal: 0.8195
#  NSE val: 0.7451
#
# === Station 80005 ===, Number = 612
#  NSE cal: 0.8052
#  NSE val: 0.7575
#
# === Station 80006 ===, Number = 613
#  NSE cal: 0.8708
#  NSE val: 0.8660
#
# === Station 8004 ===, Number = 614
#  NSE cal: 0.4654
#  NSE val: 0.2875
#
# === Station 8005 ===, Number = 615
#  NSE cal: 0.6611
#  NSE val: 0.5902
#
# === Station 8006 ===, Number = 616
#  NSE cal: 0.6289
#  NSE val: 0.4633
#
# === Station 8009 ===, Number = 617
#  NSE cal: 0.5253
#  NSE val: 0.4197
#
# === Station 8011 ===, Number = 618
#  NSE cal: 0.5559
#  NSE val: 0.3400
#
# === Station 8013 ===, Number = 619
# ⚠️ Too many missing values (15.5%)
#
# === Station 81002 ===, Number = 620
#  NSE cal: 0.7565
#  NSE val: 0.7166
#
# === Station 81003 ===, Number = 621
#  NSE cal: 0.7529
#  NSE val: 0.7735
#
# === Station 81004 ===, Number = 622
#  NSE cal: 0.7415
#  NSE val: 0.7177
#
# === Station 81006 ===, Number = 623
#  NSE cal: 0.7547
#  NSE val: 0.7117
#
# === Station 81007 ===, Number = 624
#  NSE cal: 0.7640
#  NSE val: 0.7565
#
# === Station 82001 ===, Number = 625
#  NSE cal: 0.7931
#  NSE val: 0.7456
#
# === Station 82003 ===, Number = 626
#  NSE cal: 0.7784
#  NSE val: 0.7591
#
# === Station 83003 ===, Number = 627
#  NSE cal: 0.7302
#  NSE val: 0.6765
#
# === Station 83004 ===, Number = 628
#  NSE cal: 0.7764
#  NSE val: 0.6974
#
# === Station 83006 ===, Number = 629
#  NSE cal: 0.7533
#  NSE val: 0.6698
#
# === Station 83007 ===, Number = 630
#  NSE cal: 0.8224
#  NSE val: 0.7598
#
# === Station 83009 ===, Number = 631
#  NSE cal: 0.7523
#  NSE val: 0.6866
#
# === Station 83010 ===, Number = 632
#  NSE cal: 0.8301
#  NSE val: 0.8082
#
# === Station 83013 ===, Number = 633
#  NSE cal: 0.7677
#  NSE val: 0.7427
#
# === Station 84001 ===, Number = 634
#  NSE cal: 0.8195
#  NSE val: 0.7963
#
# === Station 84004 ===, Number = 635
#  NSE cal: 0.7815
#  NSE val: 0.7481
#
# === Station 84005 ===, Number = 636
#  NSE cal: 0.8198
#  NSE val: 0.7764
#
# === Station 84008 ===, Number = 637
#  NSE cal: 0.7945
#  NSE val: 0.7560
#
# === Station 84009 ===, Number = 638
#  NSE cal: 0.8043
#  NSE val: 0.7447
#
# === Station 84012 ===, Number = 639
#  NSE cal: 0.8264
#  NSE val: 0.7636
#
# === Station 84013 ===, Number = 640
#  NSE cal: 0.8015
#  NSE val: 0.7803
#
# === Station 84014 ===, Number = 641
#  NSE cal: 0.8005
#  NSE val: 0.7556
#
# === Station 84016 ===, Number = 642
#  NSE cal: 0.7501
#  NSE val: 0.7455
#
# === Station 84017 ===, Number = 643
#  NSE cal: 0.8566
#  NSE val: 0.8220
#
# === Station 84018 ===, Number = 644
#  NSE cal: 0.7733
#  NSE val: 0.7105
#
# === Station 84019 ===, Number = 645
#  NSE cal: 0.7479
#  NSE val: 0.7347
#
# === Station 84020 ===, Number = 646
#  NSE cal: 0.8012
#  NSE val: 0.7436
#
# === Station 84022 ===, Number = 647
#  NSE cal: 0.7329
#  NSE val: 0.7268
#
# === Station 84026 ===, Number = 648
#  NSE cal: 0.8274
#  NSE val: 0.7238
#
# === Station 84030 ===, Number = 649
#  NSE cal: 0.8447
#  NSE val: 0.7916
#
# === Station 85001 ===, Number = 650
#  NSE cal: 0.9164
#  NSE val: 0.9033
#
# === Station 85002 ===, Number = 651
#  NSE cal: 0.8075
#  NSE val: 0.6866
#
# === Station 85003 ===, Number = 652
#  NSE cal: 0.8063
#  NSE val: 0.7274
#
# === Station 85004 ===, Number = 653
#  NSE cal: 0.7875
#  NSE val: 0.7604
#
# === Station 88001 ===, Number = 654
# ⚠️ Too many missing values (23.8%)
#
# === Station 89002 ===, Number = 655
#  NSE cal: 0.7404
#  NSE val: 0.6976
#
# === Station 89003 ===, Number = 656
#  NSE cal: 0.7745
#  NSE val: 0.7321
#
# === Station 89005 ===, Number = 657
#  NSE cal: 0.6462
#  NSE val: 0.6057
#
# === Station 89007 ===, Number = 658
#  NSE cal: 0.6770
#  NSE val: 0.6331
#
# === Station 90003 ===, Number = 659
#  NSE cal: 0.7590
#  NSE val: 0.7306
#
# === Station 9002 ===, Number = 660
#  NSE cal: 0.6955
#  NSE val: 0.4979
#
# === Station 9003 ===, Number = 661
#  NSE cal: 0.7064
#  NSE val: 0.5506
#
# === Station 9004 ===, Number = 662
#  NSE cal: 0.7508
#  NSE val: 0.5664
#
# === Station 9005 ===, Number = 663
#  NSE cal: 0.5452
#  NSE val: 0.3837
#
# === Station 92001 ===, Number = 664
# ⚠️ Too many missing values (22.3%)
#
# === Station 93001 ===, Number = 665
#  NSE cal: 0.7671
#  NSE val: 0.7599
#
# === Station 94001 ===, Number = 666
#  NSE cal: 0.9116
#  NSE val: 0.9154
#
# === Station 95001 ===, Number = 667
#  NSE cal: 0.8581
#  NSE val: 0.8299
#
# === Station 96001 ===, Number = 668
#  NSE cal: 0.6946
#  NSE val: 0.6148
#
# === Station 96002 ===, Number = 669
#  NSE cal: 0.8023
#  NSE val: 0.7345
#
# === Station 96004 ===, Number = 670
#  NSE cal: 0.7552
#  NSE val: 0.7034
#
# === Station 97002 ===, Number = 671
#  NSE cal: 0.6651
#  NSE val: 0.5268
#
# ✅ Simulation completed for 623 valid basins.
# Total time: 3709.08 s
# Total time: 61.82 min
# Total time: 1.03 h

# %%
# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — CALIBRATION
# =============================================================
nse_cal = [res['NSE_cal'] for res in results_GRH_semi_exp.values() if not np.isnan(res['NSE_cal'])]
rmse_cal = [res['RMSE_cal'] for res in results_GRH_semi_exp.values() if not np.isnan(res['RMSE_cal'])]

print("\n================= CALIBRATION =================\n")

# ----- NSE -----
if nse_cal:
    print(f"NSE Calibration -> Median: {np.percentile(nse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_cal, 95):.4f}")
    print("MEAN NSE_CAL:", np.mean(nse_cal))
    print("MIN NSE_CAL:", np.min(nse_cal))
    print("MAX NSE_CAL:", np.max(nse_cal))
else:
    print("No NSE available for the calibration.")

# ----- RMSE -----
print("\n--- RMSE Calibration ---")
if rmse_cal:
    print(f"RMSE Calibration -> Median: {np.percentile(rmse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_cal, 95):.4f}")
    print("MEAN RMSE_CAL:", np.mean(rmse_cal))
    print("MIN RMSE_CAL:", np.min(rmse_cal))
    print("MAX RMSE_CAL:", np.max(rmse_cal))
else:
    print("No RMSE available for the calibration.")


# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — VALIDATION
# =============================================================
print("\n\n================= VALIDATION =================\n")

nse_val = [res['NSE_val'] for res in results_GRH_semi_exp.values() if not np.isnan(res['NSE_val'])]
rmse_val = [res['RMSE_val'] for res in results_GRH_semi_exp.values() if not np.isnan(res['RMSE_val'])]

# ----- NSE -----
if nse_val:
    print(f"NSE Validation -> Median: {np.percentile(nse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_val, 95):.4f}")
    print("MEAN NSE_VAL:", np.mean(nse_val))
    print("MIN NSE_VAL:", np.min(nse_val))
    print("MAX NSE_VAL:", np.max(nse_val))
else:
    print("No valid station for NSE in validation.")

# ----- RMSE -----
print("\n--- RMSE Validation ---")
if rmse_val:
    print(f"RMSE Validation -> Median: {np.percentile(rmse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_val, 95):.4f}")
    print("MEAN RMSE_VAL:", np.mean(rmse_val))
    print("MIN RMSE_VAL:", np.min(rmse_val))
    print("MAX RMSE_VAL:", np.max(rmse_val))
else:
    print("No valid station for RMSE in validation.")
# Out:
# ================= CALIBRATION =================
#
# NSE Calibration -> Median: 0.787, 5th percentile: 0.6281, 95th percentile: 0.9092
# MEAN NSE_CAL: 0.7814399107592024
# MIN NSE_CAL: 0.05885001050479077
# MAX NSE_CAL: 0.9506259493912581
#
# --- RMSE Calibration ---
# RMSE Calibration -> Median: 0.841, 5th percentile: 0.1503, 95th percentile: 2.8037
# MEAN RMSE_CAL: 1.1133037143574298
# MIN RMSE_CAL: 0.048459348307743545
# MAX RMSE_CAL: 10.242094881778334
#
#
# ================= VALIDATION =================
#
# NSE Validation -> Median: 0.758, 5th percentile: 0.5169, 95th percentile: 0.8908
# MEAN NSE_VAL: 0.7346496349288566
# MIN NSE_VAL: -1.7026746467237177
# MAX NSE_VAL: 0.9507097595818322
#
# --- RMSE Validation ---
# RMSE Validation -> Median: 1.010, 5th percentile: 0.1719, 95th percentile: 3.0532
# MEAN RMSE_VAL: 1.2528198740823604
# MIN RMSE_VAL: 0.03968719486955541
# MAX RMSE_VAL: 10.076058049280638

# %% [markdown]
# #GR4J

# %%
start_time = time.perf_counter()

# ============================================
# General infos
# ============================================

results_GR4J = {}

# ============================================
# GR4J objective function (minimize RMSE)
# ============================================
def objective_gr4j(x, Q, P, ET):
    model = GR4J()
    params = dict(zip(model.get_parameter_names(), x))
    model.set_params(params)
    try:
        Qsim = model.simulate(P, ET).flatten()
        rmse = RMSE(Q, Qsim)
        return rmse if np.isfinite(rmse) else 1e6
    except Exception:
        return 1e6


# ============================================
# GR4J bounds
# ============================================
bounds = [
    (1, 3500),   # x1
    (-15, 15),   # x2
    (1, 1200),   # x3
    (0.5, 5)     # x4
]

# ============================================
# Main loop over basins
# ============================================
for i, station_id in enumerate(stations, start=1):

    print(f"\n=== Station {station_id} ({i}/{len(stations)}) ===")

    Q_obs = ds_recent[station_id].sel(dynamic_features="q_mmd_obs").to_numpy()
    P = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    ET = ds_recent[station_id].sel(dynamic_features="pet_mm").to_numpy()

    N = len(Q_obs)
    if N == 0 or np.all(np.isnan(Q_obs)):
        print("⚠️ Station ignored (no valid data)")
        continue

    missing_ratio = np.isnan(Q_obs).sum() / N
    if missing_ratio > max_missing_ratio:
        print(f"⚠️ Too many missing values ({missing_ratio*100:.1f}%)")
        continue

    # ============================================
    # Split calibration / validation
    # ============================================
    b1 = int(N * b1_ratio)

    Q_cal, Q_val = Q_obs[:b1], Q_obs[b1:]
    P_cal, P_val = P[:b1], P[b1:]
    ET_cal, ET_val = ET[:b1], ET[b1:]

    # ============================================
    # Multi-start calibration
    # ============================================
    best_fun = np.inf
    best_x = None
    np.random.seed(42)

    for _ in range(20):
        x0 = [np.random.uniform(b[0], b[1]) for b in bounds]

        res = minimize(
            objective_gr4j,
            x0,
            args=(Q_cal, P_cal, ET_cal),
            method="L-BFGS-B",
            bounds=bounds,
            options={"maxiter": 3000}
        )

        if res.fun < best_fun:
            best_fun = res.fun
            best_x = res.x

    if best_x is None:
        print("⚠️ Calibration failed")
        continue

    # ============================================
    # Final simulation
    # ============================================
    model = GR4J()
    params = dict(zip(model.get_parameter_names(), best_x))
    model.set_params(params)

    Qsim_cal = model.simulate(P_cal, ET_cal).flatten()
    Qsim_val = model.simulate(P_val, ET_val).flatten()

    # ============================================
    # Metrics
    # ============================================
    nse_cal = NSE(Q_cal, Qsim_cal)
    rmse_cal = RMSE(Q_cal, Qsim_cal)

    nse_val = NSE(Q_val, Qsim_val)
    rmse_val = RMSE(Q_val, Qsim_val)

    FHV_val = FHV(Q_val, Qsim_val)
    FLV_val = FLV(Q_val, Qsim_val)
    KGE_val, KGE_1, KGE_2, KGE_3  = KGE(Q_val, Qsim_val)

    # ============================================
    # Store results
    # ============================================
    results_GR4J[station_id] = {
        "NSE_cal": nse_cal,
        "RMSE_cal": rmse_cal,
        "NSE_val": nse_val,
        "RMSE_val": rmse_val,
        "FHV_val": FHV_val,
        "FLV_val": FLV_val,
        "KGE_val": KGE_val,
        "KGE_1": KGE_1,
        "KGE_2": KGE_2,
        "KGE_3": KGE_3,

        "Qsim": Qsim_val,
        "Q_obs": Q_val,
        **params
    }

    # ============================================
    # Display
    # ============================================
    print(f"NSE calibration   : {nse_cal:.3f}")
    print(f"NSE validation    : {nse_val:.3f}")

print(f"\n✅ Finished : {len(results_GR4J)} calibrated basins")

end_time = time.perf_counter()

total_time = end_time - start_time

print(f"Total time: {total_time:.2f} s")
print(f"Total time: {total_time/60:.2f} min")
print(f"Total time: {total_time/3600:.2f} h")
# Out:
# === Station 10002 (1/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.685
#
# === Station 10003 (2/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.695
#
# === Station 1001 (3/671) ===
# ⚠️ Too many missing values (23.4%)
#
# === Station 101002 (4/671) ===
# NSE calibration   : 0.720
# NSE validation    : 0.656
#
# === Station 101005 (5/671) ===
# NSE calibration   : 0.736
# NSE validation    : 0.808
#
# === Station 102001 (6/671) ===
# NSE calibration   : 0.791
# NSE validation    : 0.781
#
# === Station 106001 (7/671) ===
# ⚠️ Too many missing values (28.0%)
#
# === Station 107001 (8/671) ===
# ⚠️ Too many missing values (38.4%)
#
# === Station 11001 (9/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.613
#
# === Station 11003 (10/671) ===
# NSE calibration   : 0.700
# NSE validation    : 0.401
#
# === Station 11004 (11/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.585
#
# === Station 12001 (12/671) ===
# NSE calibration   : 0.583
# NSE validation    : 0.411
#
# === Station 12002 (13/671) ===
# NSE calibration   : 0.649
# NSE validation    : 0.509
#
# === Station 12005 (14/671) ===
# NSE calibration   : 0.650
# NSE validation    : 0.499
#
# === Station 12006 (15/671) ===
# NSE calibration   : 0.526
# NSE validation    : 0.291
#
# === Station 12007 (16/671) ===
# NSE calibration   : 0.432
# NSE validation    : 0.393
#
# === Station 12008 (17/671) ===
# NSE calibration   : 0.750
# NSE validation    : 0.730
#
# === Station 12009 (18/671) ===
# NSE calibration   : 0.666
# NSE validation    : 0.700
#
# === Station 13001 (19/671) ===
# NSE calibration   : 0.842
# NSE validation    : 0.825
#
# === Station 13004 (20/671) ===
# NSE calibration   : 0.724
# NSE validation    : 0.681
#
# === Station 13005 (21/671) ===
# NSE calibration   : 0.844
# NSE validation    : -0.325
#
# === Station 13007 (22/671) ===
# NSE calibration   : 0.747
# NSE validation    : 0.680
#
# === Station 13008 (23/671) ===
# NSE calibration   : 0.730
# NSE validation    : 0.697
#
# === Station 14001 (24/671) ===
# NSE calibration   : 0.840
# NSE validation    : 0.797
#
# === Station 14002 (25/671) ===
# NSE calibration   : 0.810
# NSE validation    : -0.864
#
# === Station 14005 (26/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.799
#
# === Station 15006 (27/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.799
#
# === Station 15007 (28/671) ===
# NSE calibration   : 0.883
# NSE validation    : 0.839
#
# === Station 15010 (29/671) ===
# NSE calibration   : 0.725
# NSE validation    : 0.742
#
# === Station 15011 (30/671) ===
# NSE calibration   : 0.670
# NSE validation    : 0.560
#
# === Station 15012 (31/671) ===
# NSE calibration   : 0.802
# NSE validation    : 0.724
#
# === Station 15013 (32/671) ===
# NSE calibration   : 0.725
# NSE validation    : 0.663
#
# === Station 15014 (33/671) ===
# NSE calibration   : 0.612
# NSE validation    : 0.555
#
# === Station 15016 (34/671) ===
# NSE calibration   : 0.909
# NSE validation    : 0.883
#
# === Station 15021 (35/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.824
#
# === Station 15023 (36/671) ===
# NSE calibration   : 0.792
# NSE validation    : 0.696
#
# === Station 15024 (37/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.812
#
# === Station 15025 (38/671) ===
# NSE calibration   : 0.685
# NSE validation    : 0.663
#
# === Station 15030 (39/671) ===
# NSE calibration   : 0.827
# NSE validation    : 0.727
#
# === Station 15039 (40/671) ===
# NSE calibration   : 0.498
# NSE validation    : 0.412
#
# === Station 16001 (41/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.806
#
# === Station 16003 (42/671) ===
# NSE calibration   : 0.802
# NSE validation    : 0.733
#
# === Station 16004 (43/671) ===
# NSE calibration   : 0.872
# NSE validation    : 0.824
#
# === Station 17001 (44/671) ===
# NSE calibration   : 0.737
# NSE validation    : 0.740
#
# === Station 17003 (45/671) ===
# NSE calibration   : 0.797
# NSE validation    : 0.701
#
# === Station 17004 (46/671) ===
# NSE calibration   : 0.848
# NSE validation    : 0.817
#
# === Station 17005 (47/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.763
#
# === Station 17015 (48/671) ===
# NSE calibration   : 0.737
# NSE validation    : 0.691
#
# === Station 17018 (49/671) ===
# ⚠️ Too many missing values (18.6%)
#
# === Station 18001 (50/671) ===
# NSE calibration   : 0.792
# NSE validation    : 0.722
#
# === Station 18002 (51/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.729
#
# === Station 18003 (52/671) ===
# NSE calibration   : 0.886
# NSE validation    : 0.885
#
# === Station 18008 (53/671) ===
# NSE calibration   : 0.889
# NSE validation    : 0.890
#
# === Station 18010 (54/671) ===
# ⚠️ Too many missing values (12.0%)
#
# === Station 18011 (55/671) ===
# NSE calibration   : 0.878
# NSE validation    : 0.927
#
# === Station 18014 (56/671) ===
# NSE calibration   : 0.827
# NSE validation    : 0.758
#
# === Station 18017 (57/671) ===
# ⚠️ Too many missing values (72.0%)
#
# === Station 18018 (58/671) ===
# ⚠️ Too many missing values (72.0%)
#
# === Station 19001 (59/671) ===
# NSE calibration   : 0.853
# NSE validation    : 0.838
#
# === Station 19006 (60/671) ===
# NSE calibration   : 0.802
# NSE validation    : 0.763
#
# === Station 19010 (61/671) ===
# ⚠️ Too many missing values (20.0%)
#
# === Station 19017 (62/671) ===
# NSE calibration   : 0.770
# NSE validation    : 0.632
#
# === Station 19020 (63/671) ===
# NSE calibration   : 0.783
# NSE validation    : 0.683
#
# === Station 20002 (64/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.603
#
# === Station 20003 (65/671) ===
# NSE calibration   : 0.815
# NSE validation    : 0.628
#
# === Station 20007 (66/671) ===
# NSE calibration   : 0.805
# NSE validation    : 0.584
#
# === Station 2001 (67/671) ===
# NSE calibration   : 0.670
# NSE validation    : 0.632
#
# === Station 2002 (68/671) ===
# ⚠️ Too many missing values (13.3%)
#
# === Station 21003 (69/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.829
#
# === Station 21006 (70/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.824
#
# === Station 21008 (71/671) ===
# NSE calibration   : 0.770
# NSE validation    : 0.776
#
# === Station 21009 (72/671) ===
# NSE calibration   : 0.820
# NSE validation    : 0.815
#
# === Station 21011 (73/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.805
#
# === Station 21012 (74/671) ===
# NSE calibration   : 0.792
# NSE validation    : 0.767
#
# === Station 21013 (75/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.689
#
# === Station 21015 (76/671) ===
# ⚠️ Too many missing values (11.0%)
#
# === Station 21016 (77/671) ===
# NSE calibration   : 0.708
# NSE validation    : 0.712
#
# === Station 21017 (78/671) ===
# ⚠️ Too many missing values (15.2%)
#
# === Station 21018 (79/671) ===
# NSE calibration   : 0.828
# NSE validation    : 0.710
#
# === Station 21022 (80/671) ===
# NSE calibration   : 0.769
# NSE validation    : 0.637
#
# === Station 21023 (81/671) ===
# NSE calibration   : 0.504
# NSE validation    : 0.518
#
# === Station 21024 (82/671) ===
# NSE calibration   : 0.656
# NSE validation    : 0.677
#
# === Station 21026 (83/671) ===
# NSE calibration   : 0.730
# NSE validation    : 0.708
#
# === Station 21027 (84/671) ===
# NSE calibration   : 0.725
# NSE validation    : 0.652
#
# === Station 22001 (85/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.777
#
# === Station 22006 (86/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.784
#
# === Station 22007 (87/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.748
#
# === Station 22009 (88/671) ===
# NSE calibration   : 0.758
# NSE validation    : 0.737
#
# === Station 23001 (89/671) ===
# NSE calibration   : 0.821
# NSE validation    : 0.789
#
# === Station 23004 (90/671) ===
# NSE calibration   : 0.796
# NSE validation    : 0.792
#
# === Station 23006 (91/671) ===
# NSE calibration   : 0.788
# NSE validation    : 0.784
#
# === Station 23007 (92/671) ===
# NSE calibration   : 0.719
# NSE validation    : 0.751
#
# === Station 23008 (93/671) ===
# NSE calibration   : 0.781
# NSE validation    : 0.739
#
# === Station 23011 (94/671) ===
# NSE calibration   : 0.721
# NSE validation    : 0.733
#
# === Station 23016 (95/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.815
#
# === Station 24001 (96/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.788
#
# === Station 24003 (97/671) ===
# NSE calibration   : 0.742
# NSE validation    : 0.749
#
# === Station 24004 (98/671) ===
# NSE calibration   : 0.773
# NSE validation    : 0.729
#
# === Station 24005 (99/671) ===
# NSE calibration   : 0.798
# NSE validation    : 0.791
#
# === Station 25001 (100/671) ===
# NSE calibration   : 0.768
# NSE validation    : 0.756
#
# === Station 25003 (101/671) ===
# NSE calibration   : 0.582
# NSE validation    : 0.541
#
# === Station 25006 (102/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.726
#
# === Station 25012 (103/671) ===
# NSE calibration   : 0.747
# NSE validation    : 0.751
#
# === Station 25020 (104/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.677
#
# === Station 25021 (105/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.699
#
# === Station 25029 (106/671) ===
# ⚠️ Too many missing values (68.0%)
#
# === Station 26003 (107/671) ===
# NSE calibration   : 0.808
# NSE validation    : 0.340
#
# === Station 26005 (108/671) ===
# NSE calibration   : 0.185
# NSE validation    : -0.037
#
# === Station 26006 (109/671) ===
# NSE calibration   : 0.344
# NSE validation    : 0.201
#
# === Station 26008 (110/671) ===
# NSE calibration   : 0.846
# NSE validation    : 0.392
#
# === Station 26009 (111/671) ===
# NSE calibration   : 0.755
# NSE validation    : 0.403
#
# === Station 27001 (112/671) ===
# NSE calibration   : 0.848
# NSE validation    : 0.849
#
# === Station 27002 (113/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.789
#
# === Station 27003 (114/671) ===
# NSE calibration   : 0.867
# NSE validation    : 0.839
#
# === Station 27006 (115/671) ===
# NSE calibration   : 0.733
# NSE validation    : 0.708
#
# === Station 27007 (116/671) ===
# NSE calibration   : 0.858
# NSE validation    : 0.833
#
# === Station 27009 (117/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.793
#
# === Station 27021 (118/671) ===
# NSE calibration   : 0.807
# NSE validation    : 0.785
#
# === Station 27023 (119/671) ===
# NSE calibration   : 0.723
# NSE validation    : 0.779
#
# === Station 27025 (120/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.729
#
# === Station 27026 (121/671) ===
# NSE calibration   : 0.806
# NSE validation    : 0.778
#
# === Station 27029 (122/671) ===
# NSE calibration   : 0.819
# NSE validation    : 0.789
#
# === Station 27030 (123/671) ===
# NSE calibration   : 0.788
# NSE validation    : 0.761
#
# === Station 27032 (124/671) ===
# NSE calibration   : 0.682
# NSE validation    : 0.546
#
# === Station 27034 (125/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.828
#
# === Station 27035 (126/671) ===
# NSE calibration   : 0.900
# NSE validation    : 0.846
#
# === Station 27038 (127/671) ===
# NSE calibration   : 0.389
# NSE validation    : -0.632
#
# === Station 27041 (128/671) ===
# NSE calibration   : 0.851
# NSE validation    : 0.707
#
# === Station 27042 (129/671) ===
# NSE calibration   : 0.780
# NSE validation    : 0.711
#
# === Station 27043 (130/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.823
#
# === Station 27047 (131/671) ===
# NSE calibration   : 0.860
# NSE validation    : 0.869
#
# === Station 27049 (132/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.761
#
# === Station 27051 (133/671) ===
# NSE calibration   : 0.798
# NSE validation    : 0.832
#
# === Station 27062 (134/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.899
#
# === Station 27064 (135/671) ===
# NSE calibration   : 0.816
# NSE validation    : 0.759
#
# === Station 27065 (136/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.795
#
# === Station 27071 (137/671) ===
# NSE calibration   : 0.831
# NSE validation    : 0.751
#
# === Station 27073 (138/671) ===
# NSE calibration   : 0.775
# NSE validation    : 0.511
#
# === Station 27077 (139/671) ===
# NSE calibration   : 0.763
# NSE validation    : 0.805
#
# === Station 27079 (140/671) ===
# NSE calibration   : 0.842
# NSE validation    : 0.825
#
# === Station 27080 (141/671) ===
# NSE calibration   : 0.860
# NSE validation    : 0.829
#
# === Station 27084 (142/671) ===
# NSE calibration   : 0.867
# NSE validation    : 0.835
#
# === Station 27087 (143/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.518
#
# === Station 27089 (144/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.850
#
# === Station 27090 (145/671) ===
# ⚠️ Too many missing values (11.8%)
#
# === Station 28001 (146/671) ===
# NSE calibration   : 0.553
# NSE validation    : 0.455
#
# === Station 28003 (147/671) ===
# ⚠️ Too many missing values (12.3%)
#
# === Station 28008 (148/671) ===
# NSE calibration   : 0.754
# NSE validation    : 0.678
#
# === Station 28009 (149/671) ===
# NSE calibration   : 0.852
# NSE validation    : 0.754
#
# === Station 28012 (150/671) ===
# ⚠️ Too many missing values (11.3%)
#
# === Station 28015 (151/671) ===
# NSE calibration   : 0.443
# NSE validation    : 0.201
#
# === Station 28018 (152/671) ===
# NSE calibration   : 0.847
# NSE validation    : 0.821
#
# === Station 28022 (153/671) ===
# NSE calibration   : 0.827
# NSE validation    : 0.735
#
# === Station 28023 (154/671) ===
# ⚠️ Too many missing values (16.6%)
#
# === Station 28024 (155/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.764
#
# === Station 28026 (156/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.798
#
# === Station 28031 (157/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.779
#
# === Station 28033 (158/671) ===
# ⚠️ Too many missing values (27.2%)
#
# === Station 28039 (159/671) ===
# NSE calibration   : 0.726
# NSE validation    : 0.763
#
# === Station 28040 (160/671) ===
# NSE calibration   : 0.823
# NSE validation    : 0.753
#
# === Station 28043 (161/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.691
#
# === Station 28044 (162/671) ===
# NSE calibration   : 0.395
# NSE validation    : 0.006
#
# === Station 28046 (163/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.705
#
# === Station 28048 (164/671) ===
# NSE calibration   : 0.773
# NSE validation    : 0.693
#
# === Station 28050 (165/671) ===
# NSE calibration   : 0.637
# NSE validation    : 0.336
#
# === Station 28052 (166/671) ===
# NSE calibration   : 0.767
# NSE validation    : 0.669
#
# === Station 28055 (167/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.740
#
# === Station 28056 (168/671) ===
# NSE calibration   : 0.824
# NSE validation    : 0.770
#
# === Station 28060 (169/671) ===
# NSE calibration   : 0.589
# NSE validation    : 0.398
#
# === Station 28066 (170/671) ===
# NSE calibration   : 0.631
# NSE validation    : 0.538
#
# === Station 28067 (171/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.809
#
# === Station 28072 (172/671) ===
# NSE calibration   : 0.728
# NSE validation    : 0.577
#
# === Station 28074 (173/671) ===
# NSE calibration   : 0.898
# NSE validation    : 0.773
#
# === Station 28080 (174/671) ===
# NSE calibration   : 0.693
# NSE validation    : 0.566
#
# === Station 28081 (175/671) ===
# NSE calibration   : 0.606
# NSE validation    : 0.563
#
# === Station 28082 (176/671) ===
# NSE calibration   : 0.860
# NSE validation    : 0.835
#
# === Station 28085 (177/671) ===
# NSE calibration   : 0.880
# NSE validation    : 0.820
#
# === Station 28091 (178/671) ===
# NSE calibration   : 0.764
# NSE validation    : 0.357
#
# === Station 28093 (179/671) ===
# NSE calibration   : 0.861
# NSE validation    : 0.784
#
# === Station 28115 (180/671) ===
# NSE calibration   : 0.829
# NSE validation    : -0.114
#
# === Station 28116 (181/671) ===
# ⚠️ Too many missing values (28.2%)
#
# === Station 28117 (182/671) ===
# ⚠️ Too many missing values (28.0%)
#
# === Station 29002 (183/671) ===
# NSE calibration   : 0.802
# NSE validation    : -0.076
#
# === Station 29003 (184/671) ===
# NSE calibration   : 0.847
# NSE validation    : 0.188
#
# === Station 29005 (185/671) ===
# NSE calibration   : 0.717
# NSE validation    : 0.535
#
# === Station 29009 (186/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.793
#
# === Station 30001 (187/671) ===
# NSE calibration   : 0.852
# NSE validation    : 0.611
#
# === Station 30004 (188/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.587
#
# === Station 30005 (189/671) ===
# ⚠️ Too many missing values (24.0%)
#
# === Station 30011 (190/671) ===
# NSE calibration   : 0.869
# NSE validation    : 0.517
#
# === Station 30012 (191/671) ===
# NSE calibration   : 0.764
# NSE validation    : 0.719
#
# === Station 30014 (192/671) ===
# NSE calibration   : 0.712
# NSE validation    : 0.590
#
# === Station 30015 (193/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.544
#
# === Station 3003 (194/671) ===
# NSE calibration   : 0.783
# NSE validation    : 0.758
#
# === Station 31002 (195/671) ===
# NSE calibration   : 0.841
# NSE validation    : 0.757
#
# === Station 31006 (196/671) ===
# NSE calibration   : 0.737
# NSE validation    : 0.387
#
# === Station 31010 (197/671) ===
# NSE calibration   : 0.841
# NSE validation    : 0.723
#
# === Station 31021 (198/671) ===
# NSE calibration   : 0.819
# NSE validation    : 0.756
#
# === Station 31023 (199/671) ===
# NSE calibration   : 0.690
# NSE validation    : 0.509
#
# === Station 31025 (200/671) ===
# NSE calibration   : 0.766
# NSE validation    : 0.679
#
# === Station 32003 (201/671) ===
# NSE calibration   : 0.767
# NSE validation    : 0.707
#
# === Station 32004 (202/671) ===
# NSE calibration   : 0.847
# NSE validation    : 0.741
#
# === Station 32006 (203/671) ===
# NSE calibration   : 0.773
# NSE validation    : 0.768
#
# === Station 32008 (204/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.762
#
# === Station 33006 (205/671) ===
# NSE calibration   : 0.828
# NSE validation    : 0.439
#
# === Station 33007 (206/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.076
#
# === Station 33012 (207/671) ===
# NSE calibration   : 0.772
# NSE validation    : 0.752
#
# === Station 33013 (208/671) ===
# NSE calibration   : 0.864
# NSE validation    : 0.754
#
# === Station 33014 (209/671) ===
# NSE calibration   : 0.808
# NSE validation    : 0.439
#
# === Station 33018 (210/671) ===
# NSE calibration   : 0.822
# NSE validation    : 0.696
#
# === Station 33019 (211/671) ===
# NSE calibration   : 0.893
# NSE validation    : 0.674
#
# === Station 33020 (212/671) ===
# ⚠️ Too many missing values (17.1%)
#
# === Station 33021 (213/671) ===
# NSE calibration   : 0.812
# NSE validation    : 0.716
#
# === Station 33022 (214/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.716
#
# === Station 33023 (215/671) ===
# NSE calibration   : 0.769
# NSE validation    : 0.572
#
# === Station 33024 (216/671) ===
# NSE calibration   : 0.766
# NSE validation    : 0.671
#
# === Station 33026 (217/671) ===
# NSE calibration   : 0.848
# NSE validation    : 0.824
#
# === Station 33028 (218/671) ===
# NSE calibration   : 0.618
# NSE validation    : 0.554
#
# === Station 33029 (219/671) ===
# NSE calibration   : 0.892
# NSE validation    : 0.619
#
# === Station 33031 (220/671) ===
# NSE calibration   : 0.754
# NSE validation    : 0.612
#
# === Station 33032 (221/671) ===
# NSE calibration   : 0.883
# NSE validation    : -0.025
#
# === Station 33033 (222/671) ===
# NSE calibration   : 0.591
# NSE validation    : 0.385
#
# === Station 33034 (223/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.622
#
# === Station 33035 (224/671) ===
# NSE calibration   : 0.781
# NSE validation    : 0.551
#
# === Station 33039 (225/671) ===
# NSE calibration   : 0.856
# NSE validation    : 0.827
#
# === Station 33053 (226/671) ===
# ⚠️ Too many missing values (16.0%)
#
# === Station 33054 (227/671) ===
# NSE calibration   : 0.822
# NSE validation    : -0.607
#
# === Station 33058 (228/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.717
#
# === Station 34002 (229/671) ===
# NSE calibration   : 0.873
# NSE validation    : 0.811
#
# === Station 34003 (230/671) ===
# NSE calibration   : 0.561
# NSE validation    : -0.684
#
# === Station 34004 (231/671) ===
# NSE calibration   : 0.664
# NSE validation    : 0.045
#
# === Station 34005 (232/671) ===
# NSE calibration   : 0.705
# NSE validation    : 0.556
#
# === Station 34006 (233/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.833
#
# === Station 34007 (234/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.772
#
# === Station 34008 (235/671) ===
# NSE calibration   : 0.244
# NSE validation    : -3.670
#
# === Station 34010 (236/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.757
#
# === Station 34011 (237/671) ===
# NSE calibration   : 0.780
# NSE validation    : 0.020
#
# === Station 34012 (238/671) ===
# NSE calibration   : 0.855
# NSE validation    : -0.944
#
# === Station 35003 (239/671) ===
# NSE calibration   : 0.683
# NSE validation    : 0.539
#
# === Station 35008 (240/671) ===
# NSE calibration   : 0.816
# NSE validation    : 0.810
#
# === Station 36003 (241/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.810
#
# === Station 36006 (242/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.794
#
# === Station 36009 (243/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.700
#
# === Station 36010 (244/671) ===
# NSE calibration   : 0.673
# NSE validation    : 0.683
#
# === Station 36011 (245/671) ===
# NSE calibration   : 0.725
# NSE validation    : 0.630
#
# === Station 36012 (246/671) ===
# NSE calibration   : -0.063
# NSE validation    : 0.239
#
# === Station 37001 (247/671) ===
# NSE calibration   : 0.860
# NSE validation    : 0.890
#
# === Station 37003 (248/671) ===
# NSE calibration   : 0.816
# NSE validation    : 0.738
#
# === Station 37005 (249/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.865
#
# === Station 37008 (250/671) ===
# NSE calibration   : 0.846
# NSE validation    : 0.867
#
# === Station 37009 (251/671) ===
# NSE calibration   : 0.729
# NSE validation    : 0.797
#
# === Station 37010 (252/671) ===
# NSE calibration   : 0.711
# NSE validation    : 0.783
#
# === Station 37011 (253/671) ===
# NSE calibration   : 0.783
# NSE validation    : 0.844
#
# === Station 37018 (254/671) ===
# NSE calibration   : 0.719
# NSE validation    : 0.741
#
# === Station 37019 (255/671) ===
# NSE calibration   : 0.648
# NSE validation    : 0.655
#
# === Station 37020 (256/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.770
#
# === Station 37031 (257/671) ===
# NSE calibration   : 0.559
# NSE validation    : 0.563
#
# === Station 37033 (258/671) ===
# NSE calibration   : 0.651
# NSE validation    : 0.813
#
# === Station 38001 (259/671) ===
# NSE calibration   : 0.840
# NSE validation    : 0.816
#
# === Station 38003 (260/671) ===
# NSE calibration   : 0.725
# NSE validation    : -0.608
#
# === Station 38004 (261/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.799
#
# === Station 38007 (262/671) ===
# NSE calibration   : 0.671
# NSE validation    : 0.651
#
# === Station 38012 (263/671) ===
# NSE calibration   : 0.467
# NSE validation    : 0.428
#
# === Station 38014 (264/671) ===
# NSE calibration   : 0.754
# NSE validation    : 0.692
#
# === Station 38017 (265/671) ===
# NSE calibration   : 0.519
# NSE validation    : -0.852
#
# === Station 38018 (266/671) ===
# NSE calibration   : 0.723
# NSE validation    : 0.217
#
# === Station 38021 (267/671) ===
# NSE calibration   : 0.674
# NSE validation    : 0.682
#
# === Station 38026 (268/671) ===
# NSE calibration   : 0.846
# NSE validation    : 0.847
#
# === Station 38029 (269/671) ===
# NSE calibration   : 0.707
# NSE validation    : 0.770
#
# === Station 38030 (270/671) ===
# NSE calibration   : 0.704
# NSE validation    : 0.579
#
# === Station 39001 (271/671) ===
# NSE calibration   : 0.846
# NSE validation    : 0.817
#
# === Station 39002 (272/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.808
#
# === Station 39004 (273/671) ===
# NSE calibration   : 0.283
# NSE validation    : 0.196
#
# === Station 39005 (274/671) ===
# NSE calibration   : 0.526
# NSE validation    : 0.270
#
# === Station 39006 (275/671) ===
# NSE calibration   : 0.841
# NSE validation    : 0.687
#
# === Station 39007 (276/671) ===
# NSE calibration   : 0.763
# NSE validation    : 0.656
#
# === Station 39008 (277/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.777
#
# === Station 39010 (278/671) ===
# NSE calibration   : 0.694
# NSE validation    : -0.652
#
# === Station 39011 (279/671) ===
# NSE calibration   : 0.724
# NSE validation    : 0.671
#
# === Station 39012 (280/671) ===
# NSE calibration   : 0.584
# NSE validation    : 0.308
#
# === Station 39014 (281/671) ===
# NSE calibration   : 0.794
# NSE validation    : -0.447
#
# === Station 39015 (282/671) ===
# NSE calibration   : 0.635
# NSE validation    : 0.337
#
# === Station 39016 (283/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.531
#
# === Station 39017 (284/671) ===
# NSE calibration   : 0.727
# NSE validation    : 0.616
#
# === Station 39019 (285/671) ===
# NSE calibration   : 0.772
# NSE validation    : 0.461
#
# === Station 39020 (286/671) ===
# NSE calibration   : 0.794
# NSE validation    : 0.675
#
# === Station 39021 (287/671) ===
# NSE calibration   : 0.829
# NSE validation    : 0.726
#
# === Station 39022 (288/671) ===
# NSE calibration   : 0.702
# NSE validation    : 0.610
#
# === Station 39023 (289/671) ===
# NSE calibration   : 0.558
# NSE validation    : -2.608
#
# === Station 39025 (290/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.845
#
# === Station 39027 (291/671) ===
# NSE calibration   : 0.708
# NSE validation    : 0.312
#
# === Station 39028 (292/671) ===
# NSE calibration   : 0.669
# NSE validation    : 0.502
#
# === Station 39029 (293/671) ===
# NSE calibration   : 0.220
# NSE validation    : -0.291
#
# === Station 39034 (294/671) ===
# NSE calibration   : 0.861
# NSE validation    : 0.732
#
# === Station 39035 (295/671) ===
# NSE calibration   : 0.806
# NSE validation    : 0.417
#
# === Station 39036 (296/671) ===
# NSE calibration   : -0.529
# NSE validation    : -1.741
#
# === Station 39037 (297/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.689
#
# === Station 39042 (298/671) ===
# NSE calibration   : 0.832
# NSE validation    : 0.623
#
# === Station 39049 (299/671) ===
# NSE calibration   : 0.696
# NSE validation    : 0.650
#
# === Station 39052 (300/671) ===
# NSE calibration   : 0.747
# NSE validation    : 0.695
#
# === Station 39054 (301/671) ===
# ⚠️ Too many missing values (16.3%)
#
# === Station 39056 (302/671) ===
# NSE calibration   : 0.579
# NSE validation    : 0.560
#
# === Station 39061 (303/671) ===
# NSE calibration   : 0.698
# NSE validation    : 0.398
#
# === Station 39065 (304/671) ===
# NSE calibration   : 0.516
# NSE validation    : -0.036
#
# === Station 39069 (305/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.844
#
# === Station 39072 (306/671) ===
# NSE calibration   : 0.805
# NSE validation    : 0.761
#
# === Station 39078 (307/671) ===
# NSE calibration   : 0.686
# NSE validation    : 0.723
#
# === Station 39081 (308/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.754
#
# === Station 39087 (309/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.767
#
# === Station 39088 (310/671) ===
# NSE calibration   : 0.607
# NSE validation    : -0.627
#
# === Station 39095 (311/671) ===
# NSE calibration   : 0.597
# NSE validation    : 0.596
#
# === Station 39099 (312/671) ===
# NSE calibration   : 0.853
# NSE validation    : 0.692
#
# === Station 39101 (313/671) ===
# NSE calibration   : 0.644
# NSE validation    : 0.471
#
# === Station 39105 (314/671) ===
# NSE calibration   : 0.856
# NSE validation    : 0.865
#
# === Station 39108 (315/671) ===
# NSE calibration   : 0.853
# NSE validation    : 0.706
#
# === Station 39114 (316/671) ===
# NSE calibration   : 0.444
# NSE validation    : 0.179
#
# === Station 39120 (317/671) ===
# NSE calibration   : 0.506
# NSE validation    : 0.418
#
# === Station 39125 (318/671) ===
# ⚠️ Too many missing values (12.5%)
#
# === Station 39127 (319/671) ===
# ⚠️ Too many missing values (17.6%)
#
# === Station 39141 (320/671) ===
# ⚠️ Too many missing values (31.3%)
#
# === Station 39142 (321/671) ===
# ⚠️ Too many missing values (23.0%)
#
# === Station 39143 (322/671) ===
# ⚠️ Too many missing values (23.0%)
#
# === Station 39144 (323/671) ===
# ⚠️ Too many missing values (23.0%)
#
# === Station 40003 (324/671) ===
# NSE calibration   : 0.815
# NSE validation    : 0.851
#
# === Station 40004 (325/671) ===
# NSE calibration   : 0.816
# NSE validation    : 0.852
#
# === Station 40005 (326/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.829
#
# === Station 40006 (327/671) ===
# NSE calibration   : 0.622
# NSE validation    : -1.983
#
# === Station 40007 (328/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.859
#
# === Station 40009 (329/671) ===
# NSE calibration   : 0.719
# NSE validation    : 0.751
#
# === Station 4001 (330/671) ===
# NSE calibration   : 0.774
# NSE validation    : 0.706
#
# === Station 40010 (331/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.872
#
# === Station 40011 (332/671) ===
# NSE calibration   : 0.832
# NSE validation    : 0.775
#
# === Station 40012 (333/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.755
#
# === Station 40013 (334/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.649
#
# === Station 40016 (335/671) ===
# NSE calibration   : 0.567
# NSE validation    : 0.476
#
# === Station 40017 (336/671) ===
# NSE calibration   : 0.761
# NSE validation    : 0.697
#
# === Station 40018 (337/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.468
#
# === Station 40020 (338/671) ===
# NSE calibration   : 0.741
# NSE validation    : 0.777
#
# === Station 40021 (339/671) ===
# NSE calibration   : 0.792
# NSE validation    : 0.781
#
# === Station 40022 (340/671) ===
# ⚠️ Too many missing values (44.9%)
#
# === Station 4003 (341/671) ===
# NSE calibration   : 0.637
# NSE validation    : 0.564
#
# === Station 40033 (342/671) ===
# NSE calibration   : 0.775
# NSE validation    : 0.372
#
# === Station 4005 (343/671) ===
# NSE calibration   : 0.713
# NSE validation    : 0.703
#
# === Station 4006 (344/671) ===
# NSE calibration   : 0.851
# NSE validation    : 0.849
#
# === Station 41001 (345/671) ===
# NSE calibration   : 0.656
# NSE validation    : 0.552
#
# === Station 41003 (346/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.794
#
# === Station 41004 (347/671) ===
# ⚠️ Too many missing values (19.1%)
#
# === Station 41005 (348/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.858
#
# === Station 41006 (349/671) ===
# NSE calibration   : 0.763
# NSE validation    : 0.731
#
# === Station 41009 (350/671) ===
# NSE calibration   : 0.683
# NSE validation    : 0.561
#
# === Station 41011 (351/671) ===
# NSE calibration   : 0.772
# NSE validation    : 0.751
#
# === Station 41012 (352/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.767
#
# === Station 41013 (353/671) ===
# NSE calibration   : 0.751
# NSE validation    : 0.741
#
# === Station 41014 (354/671) ===
# NSE calibration   : 0.878
# NSE validation    : 0.476
#
# === Station 41016 (355/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.775
#
# === Station 41019 (356/671) ===
# NSE calibration   : 0.670
# NSE validation    : 0.814
#
# === Station 41020 (357/671) ===
# NSE calibration   : 0.670
# NSE validation    : 0.714
#
# === Station 41022 (358/671) ===
# NSE calibration   : 0.710
# NSE validation    : 0.662
#
# === Station 41023 (359/671) ===
# NSE calibration   : 0.603
# NSE validation    : 0.561
#
# === Station 41025 (360/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.729
#
# === Station 41027 (361/671) ===
# NSE calibration   : 0.723
# NSE validation    : 0.720
#
# === Station 41028 (362/671) ===
# NSE calibration   : 0.666
# NSE validation    : 0.754
#
# === Station 41029 (363/671) ===
# NSE calibration   : 0.688
# NSE validation    : 0.719
#
# === Station 42001 (364/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.709
#
# === Station 42003 (365/671) ===
# NSE calibration   : 0.807
# NSE validation    : 0.806
#
# === Station 42004 (366/671) ===
# NSE calibration   : 0.567
# NSE validation    : 0.082
#
# === Station 42006 (367/671) ===
# NSE calibration   : 0.832
# NSE validation    : 0.835
#
# === Station 42008 (368/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.680
#
# === Station 42010 (369/671) ===
# NSE calibration   : 0.494
# NSE validation    : -0.048
#
# === Station 42011 (370/671) ===
# NSE calibration   : 0.735
# NSE validation    : 0.674
#
# === Station 42016 (371/671) ===
# NSE calibration   : 0.372
# NSE validation    : -0.585
#
# === Station 42017 (372/671) ===
# NSE calibration   : 0.727
# NSE validation    : 0.756
#
# === Station 42024 (373/671) ===
# NSE calibration   : 0.401
# NSE validation    : -0.165
#
# === Station 42026 (374/671) ===
# ⚠️ Too many missing values (40.5%)
#
# === Station 42027 (375/671) ===
# ⚠️ Too many missing values (40.0%)
#
# === Station 43005 (376/671) ===
# NSE calibration   : 0.808
# NSE validation    : 0.781
#
# === Station 43006 (377/671) ===
# NSE calibration   : 0.796
# NSE validation    : 0.806
#
# === Station 43007 (378/671) ===
# NSE calibration   : 0.844
# NSE validation    : 0.878
#
# === Station 43008 (379/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.861
#
# === Station 43009 (380/671) ===
# NSE calibration   : 0.881
# NSE validation    : 0.902
#
# === Station 43014 (381/671) ===
# NSE calibration   : 0.644
# NSE validation    : 0.297
#
# === Station 43017 (382/671) ===
# NSE calibration   : 0.843
# NSE validation    : 0.897
#
# === Station 43018 (383/671) ===
# NSE calibration   : 0.803
# NSE validation    : 0.838
#
# === Station 43021 (384/671) ===
# NSE calibration   : 0.749
# NSE validation    : 0.743
#
# === Station 44001 (385/671) ===
# NSE calibration   : 0.779
# NSE validation    : 0.705
#
# === Station 44002 (386/671) ===
# NSE calibration   : 0.820
# NSE validation    : 0.855
#
# === Station 44006 (387/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.804
#
# === Station 44009 (388/671) ===
# NSE calibration   : 0.719
# NSE validation    : 0.637
#
# === Station 44011 (389/671) ===
# ⚠️ Too many missing values (24.7%)
#
# === Station 45001 (390/671) ===
# NSE calibration   : 0.922
# NSE validation    : 0.899
#
# === Station 45003 (391/671) ===
# NSE calibration   : 0.819
# NSE validation    : 0.807
#
# === Station 45004 (392/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.804
#
# === Station 45005 (393/671) ===
# NSE calibration   : 0.739
# NSE validation    : 0.642
#
# === Station 45009 (394/671) ===
# NSE calibration   : 0.913
# NSE validation    : 0.880
#
# === Station 45012 (395/671) ===
# NSE calibration   : 0.854
# NSE validation    : 0.830
#
# === Station 46003 (396/671) ===
# NSE calibration   : 0.886
# NSE validation    : 0.848
#
# === Station 46005 (397/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.806
#
# === Station 46008 (398/671) ===
# NSE calibration   : 0.918
# NSE validation    : 0.856
#
# === Station 46014 (399/671) ===
# ⚠️ Too many missing values (56.5%)
#
# === Station 47001 (400/671) ===
# NSE calibration   : 0.915
# NSE validation    : 0.901
#
# === Station 47004 (401/671) ===
# NSE calibration   : 0.908
# NSE validation    : 0.888
#
# === Station 47005 (402/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.829
#
# === Station 47008 (403/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.840
#
# === Station 47009 (404/671) ===
# NSE calibration   : 0.921
# NSE validation    : 0.915
#
# === Station 47011 (405/671) ===
# ⚠️ Too many missing values (41.2%)
#
# === Station 47014 (406/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.787
#
# === Station 47018 (407/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.844
#
# === Station 48003 (408/671) ===
# NSE calibration   : 0.857
# NSE validation    : 0.888
#
# === Station 48004 (409/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.823
#
# === Station 48005 (410/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.899
#
# === Station 48011 (411/671) ===
# NSE calibration   : 0.891
# NSE validation    : 0.878
#
# === Station 49001 (412/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.871
#
# === Station 49002 (413/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.877
#
# === Station 49004 (414/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.861
#
# === Station 50001 (415/671) ===
# NSE calibration   : 0.925
# NSE validation    : 0.902
#
# === Station 50002 (416/671) ===
# NSE calibration   : 0.906
# NSE validation    : 0.875
#
# === Station 50006 (417/671) ===
# NSE calibration   : 0.922
# NSE validation    : 0.907
#
# === Station 50007 (418/671) ===
# NSE calibration   : 0.875
# NSE validation    : 0.834
#
# === Station 50008 (419/671) ===
# NSE calibration   : 0.880
# NSE validation    : 0.852
#
# === Station 50011 (420/671) ===
# NSE calibration   : 0.887
# NSE validation    : 0.833
#
# === Station 5003 (421/671) ===
# NSE calibration   : 0.645
# NSE validation    : 0.630
#
# === Station 51001 (422/671) ===
# NSE calibration   : 0.848
# NSE validation    : 0.858
#
# === Station 52004 (423/671) ===
# NSE calibration   : 0.797
# NSE validation    : 0.821
#
# === Station 52005 (424/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.800
#
# === Station 52006 (425/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.855
#
# === Station 52007 (426/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.837
#
# === Station 52009 (427/671) ===
# NSE calibration   : 0.822
# NSE validation    : 0.822
#
# === Station 52010 (428/671) ===
# NSE calibration   : 0.842
# NSE validation    : 0.821
#
# === Station 52011 (429/671) ===
# NSE calibration   : 0.841
# NSE validation    : 0.801
#
# === Station 52015 (430/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.541
#
# === Station 52016 (431/671) ===
# NSE calibration   : 0.833
# NSE validation    : 0.804
#
# === Station 53005 (432/671) ===
# NSE calibration   : 0.866
# NSE validation    : 0.873
#
# === Station 53006 (433/671) ===
# NSE calibration   : 0.873
# NSE validation    : 0.879
#
# === Station 53007 (434/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.857
#
# === Station 53008 (435/671) ===
# NSE calibration   : 0.890
# NSE validation    : 0.869
#
# === Station 53009 (436/671) ===
# NSE calibration   : 0.883
# NSE validation    : 0.898
#
# === Station 53013 (437/671) ===
# NSE calibration   : 0.833
# NSE validation    : 0.754
#
# === Station 53017 (438/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.792
#
# === Station 53018 (439/671) ===
# NSE calibration   : 0.898
# NSE validation    : 0.924
#
# === Station 53022 (440/671) ===
# ⚠️ Too many missing values (28.7%)
#
# === Station 53023 (441/671) ===
# NSE calibration   : 0.898
# NSE validation    : 0.883
#
# === Station 53028 (442/671) ===
# NSE calibration   : 0.903
# NSE validation    : 0.922
#
# === Station 54001 (443/671) ===
# NSE calibration   : 0.844
# NSE validation    : 0.813
#
# === Station 54002 (444/671) ===
# NSE calibration   : 0.858
# NSE validation    : 0.712
#
# === Station 54003 (445/671) ===
# NSE calibration   : 0.580
# NSE validation    : 0.555
#
# === Station 54004 (446/671) ===
# NSE calibration   : 0.737
# NSE validation    : 0.626
#
# === Station 54005 (447/671) ===
# NSE calibration   : 0.921
# NSE validation    : 0.873
#
# === Station 54007 (448/671) ===
# NSE calibration   : 0.756
# NSE validation    : 0.511
#
# === Station 54008 (449/671) ===
# NSE calibration   : 0.881
# NSE validation    : 0.810
#
# === Station 54011 (450/671) ===
# ⚠️ Too many missing values (11.7%)
#
# === Station 54012 (451/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.704
#
# === Station 54015 (452/671) ===
# NSE calibration   : 0.740
# NSE validation    : 0.271
#
# === Station 54016 (453/671) ===
# NSE calibration   : 0.857
# NSE validation    : 0.809
#
# === Station 54017 (454/671) ===
# NSE calibration   : 0.768
# NSE validation    : 0.521
#
# === Station 54018 (455/671) ===
# NSE calibration   : 0.842
# NSE validation    : 0.753
#
# === Station 54019 (456/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.803
#
# === Station 54020 (457/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.766
#
# === Station 54022 (458/671) ===
# ⚠️ Too many missing values (20.1%)
#
# === Station 54024 (459/671) ===
# NSE calibration   : 0.791
# NSE validation    : 0.582
#
# === Station 54025 (460/671) ===
# NSE calibration   : 0.919
# NSE validation    : 0.883
#
# === Station 54027 (461/671) ===
# NSE calibration   : 0.766
# NSE validation    : 0.699
#
# === Station 54028 (462/671) ===
# NSE calibration   : 0.904
# NSE validation    : 0.878
#
# === Station 54029 (463/671) ===
# NSE calibration   : 0.879
# NSE validation    : 0.807
#
# === Station 54032 (464/671) ===
# NSE calibration   : 0.823
# NSE validation    : 0.789
#
# === Station 54034 (465/671) ===
# NSE calibration   : 0.696
# NSE validation    : 0.542
#
# === Station 54036 (466/671) ===
# NSE calibration   : 0.784
# NSE validation    : 0.574
#
# === Station 54038 (467/671) ===
# NSE calibration   : 0.916
# NSE validation    : 0.880
#
# === Station 54044 (468/671) ===
# NSE calibration   : 0.648
# NSE validation    : 0.391
#
# === Station 54048 (469/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.490
#
# === Station 54049 (470/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.703
#
# === Station 54052 (471/671) ===
# NSE calibration   : 0.473
# NSE validation    : 0.696
#
# === Station 54057 (472/671) ===
# NSE calibration   : 0.829
# NSE validation    : 0.733
#
# === Station 54060 (473/671) ===
# NSE calibration   : 0.581
# NSE validation    : 0.542
#
# === Station 54063 (474/671) ===
# ⚠️ Too many missing values (21.0%)
#
# === Station 54080 (475/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.782
#
# === Station 54095 (476/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.831
#
# === Station 54096 (477/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.688
#
# === Station 55002 (478/671) ===
# NSE calibration   : 0.926
# NSE validation    : 0.881
#
# === Station 55007 (479/671) ===
# NSE calibration   : 0.903
# NSE validation    : 0.871
#
# === Station 55008 (480/671) ===
# ⚠️ Too many missing values (16.2%)
#
# === Station 55013 (481/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.847
#
# === Station 55014 (482/671) ===
# NSE calibration   : 0.864
# NSE validation    : 0.842
#
# === Station 55016 (483/671) ===
# NSE calibration   : 0.884
# NSE validation    : 0.844
#
# === Station 55018 (484/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.746
#
# === Station 55021 (485/671) ===
# NSE calibration   : 0.851
# NSE validation    : 0.809
#
# === Station 55023 (486/671) ===
# NSE calibration   : 0.874
# NSE validation    : 0.878
#
# === Station 55025 (487/671) ===
# NSE calibration   : 0.842
# NSE validation    : 0.858
#
# === Station 55026 (488/671) ===
# NSE calibration   : 0.890
# NSE validation    : 0.868
#
# === Station 55029 (489/671) ===
# NSE calibration   : 0.808
# NSE validation    : 0.783
#
# === Station 55032 (490/671) ===
# NSE calibration   : 0.696
# NSE validation    : 0.712
#
# === Station 56001 (491/671) ===
# NSE calibration   : 0.822
# NSE validation    : 0.790
#
# === Station 56002 (492/671) ===
# NSE calibration   : 0.912
# NSE validation    : 0.870
#
# === Station 56007 (493/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.863
#
# === Station 56012 (494/671) ===
# NSE calibration   : 0.848
# NSE validation    : 0.813
#
# === Station 56013 (495/671) ===
# NSE calibration   : 0.884
# NSE validation    : 0.865
#
# === Station 57004 (496/671) ===
# NSE calibration   : 0.905
# NSE validation    : 0.863
#
# === Station 57005 (497/671) ===
# NSE calibration   : 0.879
# NSE validation    : 0.845
#
# === Station 57006 (498/671) ===
# NSE calibration   : 0.892
# NSE validation    : 0.860
#
# === Station 57007 (499/671) ===
# NSE calibration   : 0.890
# NSE validation    : 0.838
#
# === Station 57008 (500/671) ===
# NSE calibration   : 0.893
# NSE validation    : 0.869
#
# === Station 57009 (501/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.857
#
# === Station 58001 (502/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.850
#
# === Station 58002 (503/671) ===
# NSE calibration   : 0.875
# NSE validation    : 0.834
#
# === Station 58006 (504/671) ===
# NSE calibration   : 0.899
# NSE validation    : 0.856
#
# === Station 58008 (505/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.842
#
# === Station 58009 (506/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.849
#
# === Station 58010 (507/671) ===
# ⚠️ Too many missing values (13.2%)
#
# === Station 58012 (508/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.844
#
# === Station 59001 (509/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.806
#
# === Station 60002 (510/671) ===
# NSE calibration   : 0.885
# NSE validation    : 0.861
#
# === Station 60003 (511/671) ===
# NSE calibration   : 0.891
# NSE validation    : 0.822
#
# === Station 60005 (512/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.739
#
# === Station 60006 (513/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.833
#
# === Station 60010 (514/671) ===
# NSE calibration   : 0.926
# NSE validation    : 0.901
#
# === Station 60012 (515/671) ===
# NSE calibration   : 0.852
# NSE validation    : 0.789
#
# === Station 6007 (516/671) ===
# NSE calibration   : 0.843
# NSE validation    : 0.813
#
# === Station 6008 (517/671) ===
# NSE calibration   : 0.787
# NSE validation    : 0.781
#
# === Station 61001 (518/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.713
#
# === Station 61002 (519/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.807
#
# === Station 62001 (520/671) ===
# NSE calibration   : 0.942
# NSE validation    : 0.907
#
# === Station 63001 (521/671) ===
# NSE calibration   : 0.901
# NSE validation    : 0.841
#
# === Station 63004 (522/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.826
#
# === Station 64001 (523/671) ===
# NSE calibration   : 0.916
# NSE validation    : 0.891
#
# === Station 64002 (524/671) ===
# NSE calibration   : 0.854
# NSE validation    : 0.809
#
# === Station 64006 (525/671) ===
# NSE calibration   : 0.906
# NSE validation    : 0.895
#
# === Station 65001 (526/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.808
#
# === Station 65004 (527/671) ===
# ⚠️ Too many missing values (16.0%)
#
# === Station 65005 (528/671) ===
# NSE calibration   : 0.605
# NSE validation    : 0.743
#
# === Station 65006 (529/671) ===
# NSE calibration   : 0.890
# NSE validation    : 0.864
#
# === Station 65007 (530/671) ===
# NSE calibration   : 0.806
# NSE validation    : 0.792
#
# === Station 65008 (531/671) ===
# NSE calibration   : 0.796
# NSE validation    : 0.796
#
# === Station 66001 (532/671) ===
# NSE calibration   : 0.886
# NSE validation    : 0.856
#
# === Station 66004 (533/671) ===
# NSE calibration   : 0.812
# NSE validation    : 0.639
#
# === Station 66006 (534/671) ===
# NSE calibration   : 0.891
# NSE validation    : 0.853
#
# === Station 66011 (535/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.806
#
# === Station 67001 (536/671) ===
# NSE calibration   : 0.898
# NSE validation    : 0.900
#
# === Station 67005 (537/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.836
#
# === Station 67006 (538/671) ===
# NSE calibration   : 0.890
# NSE validation    : 0.826
#
# === Station 67008 (539/671) ===
# NSE calibration   : 0.852
# NSE validation    : 0.738
#
# === Station 67010 (540/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.846
#
# === Station 67015 (541/671) ===
# NSE calibration   : 0.930
# NSE validation    : 0.890
#
# === Station 67018 (542/671) ===
# NSE calibration   : 0.861
# NSE validation    : 0.861
#
# === Station 67025 (543/671) ===
# NSE calibration   : 0.676
# NSE validation    : 0.659
#
# === Station 67033 (544/671) ===
# ⚠️ Too many missing values (23.3%)
#
# === Station 68001 (545/671) ===
# NSE calibration   : 0.822
# NSE validation    : 0.790
#
# === Station 68003 (546/671) ===
# NSE calibration   : 0.867
# NSE validation    : 0.782
#
# === Station 68004 (547/671) ===
# NSE calibration   : 0.676
# NSE validation    : 0.611
#
# === Station 68005 (548/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.759
#
# === Station 68020 (549/671) ===
# NSE calibration   : 0.751
# NSE validation    : 0.643
#
# === Station 69002 (550/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.801
#
# === Station 69007 (551/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.792
#
# === Station 69012 (552/671) ===
# NSE calibration   : 0.807
# NSE validation    : 0.705
#
# === Station 69015 (553/671) ===
# NSE calibration   : 0.823
# NSE validation    : 0.742
#
# === Station 69017 (554/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.759
#
# === Station 69023 (555/671) ===
# NSE calibration   : 0.848
# NSE validation    : 0.805
#
# === Station 69027 (556/671) ===
# NSE calibration   : 0.811
# NSE validation    : 0.774
#
# === Station 69030 (557/671) ===
# NSE calibration   : 0.751
# NSE validation    : 0.731
#
# === Station 69032 (558/671) ===
# NSE calibration   : 0.763
# NSE validation    : 0.740
#
# === Station 69043 (559/671) ===
# ⚠️ Too many missing values (21.3%)
#
# === Station 70002 (560/671) ===
# NSE calibration   : 0.778
# NSE validation    : 0.748
#
# === Station 7001 (561/671) ===
# NSE calibration   : 0.467
# NSE validation    : 0.415
#
# === Station 7002 (562/671) ===
# NSE calibration   : 0.581
# NSE validation    : 0.454
#
# === Station 7003 (563/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.626
#
# === Station 7005 (564/671) ===
# NSE calibration   : 0.758
# NSE validation    : 0.513
#
# === Station 7006 (565/671) ===
# NSE calibration   : 0.656
# NSE validation    : 0.466
#
# === Station 71001 (566/671) ===
# NSE calibration   : 0.861
# NSE validation    : 0.836
#
# === Station 71004 (567/671) ===
# NSE calibration   : 0.829
# NSE validation    : 0.818
#
# === Station 71006 (568/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.842
#
# === Station 71008 (569/671) ===
# NSE calibration   : 0.823
# NSE validation    : 0.808
#
# === Station 71014 (570/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.774
#
# === Station 72002 (571/671) ===
# NSE calibration   : 0.858
# NSE validation    : 0.794
#
# === Station 72004 (572/671) ===
# NSE calibration   : 0.869
# NSE validation    : 0.842
#
# === Station 72005 (573/671) ===
# NSE calibration   : 0.870
# NSE validation    : 0.859
#
# === Station 72007 (574/671) ===
# NSE calibration   : 0.816
# NSE validation    : 0.808
#
# === Station 72009 (575/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.806
#
# === Station 72014 (576/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.795
#
# === Station 72015 (577/671) ===
# NSE calibration   : 0.892
# NSE validation    : 0.880
#
# === Station 73005 (578/671) ===
# NSE calibration   : 0.892
# NSE validation    : 0.883
#
# === Station 73009 (579/671) ===
# NSE calibration   : 0.861
# NSE validation    : 0.859
#
# === Station 73010 (580/671) ===
# NSE calibration   : 0.951
# NSE validation    : 0.947
#
# === Station 73011 (581/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.885
#
# === Station 73014 (582/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.812
#
# === Station 73015 (583/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.755
#
# === Station 74001 (584/671) ===
# NSE calibration   : 0.833
# NSE validation    : 0.837
#
# === Station 74005 (585/671) ===
# NSE calibration   : 0.866
# NSE validation    : 0.875
#
# === Station 74006 (586/671) ===
# NSE calibration   : 0.792
# NSE validation    : 0.807
#
# === Station 74007 (587/671) ===
# NSE calibration   : 0.784
# NSE validation    : 0.821
#
# === Station 75003 (588/671) ===
# NSE calibration   : 0.955
# NSE validation    : 0.955
#
# === Station 75004 (589/671) ===
# NSE calibration   : 0.930
# NSE validation    : 0.926
#
# === Station 75017 (590/671) ===
# NSE calibration   : 0.887
# NSE validation    : 0.852
#
# === Station 76003 (591/671) ===
# NSE calibration   : 0.904
# NSE validation    : 0.887
#
# === Station 76005 (592/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.821
#
# === Station 76007 (593/671) ===
# NSE calibration   : 0.897
# NSE validation    : 0.882
#
# === Station 76008 (594/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.763
#
# === Station 76011 (595/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.763
#
# === Station 76014 (596/671) ===
# NSE calibration   : 0.861
# NSE validation    : 0.792
#
# === Station 77002 (597/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.846
#
# === Station 77003 (598/671) ===
# NSE calibration   : 0.778
# NSE validation    : 0.755
#
# === Station 77004 (599/671) ===
# NSE calibration   : 0.827
# NSE validation    : 0.803
#
# === Station 78003 (600/671) ===
# NSE calibration   : 0.894
# NSE validation    : 0.878
#
# === Station 78004 (601/671) ===
# NSE calibration   : 0.792
# NSE validation    : 0.741
#
# === Station 78006 (602/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.807
#
# === Station 79002 (603/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.844
#
# === Station 79003 (604/671) ===
# NSE calibration   : 0.781
# NSE validation    : 0.682
#
# === Station 79004 (605/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.814
#
# === Station 79005 (606/671) ===
# NSE calibration   : 0.877
# NSE validation    : 0.859
#
# === Station 79006 (607/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.841
#
# === Station 80001 (608/671) ===
# NSE calibration   : 0.877
# NSE validation    : 0.852
#
# === Station 80002 (609/671) ===
# NSE calibration   : 0.886
# NSE validation    : 0.895
#
# === Station 80003 (610/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.751
#
# === Station 80004 (611/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.734
#
# === Station 80005 (612/671) ===
# NSE calibration   : 0.819
# NSE validation    : 0.762
#
# === Station 80006 (613/671) ===
# NSE calibration   : 0.920
# NSE validation    : 0.932
#
# === Station 8004 (614/671) ===
# NSE calibration   : 0.481
# NSE validation    : 0.298
#
# === Station 8005 (615/671) ===
# NSE calibration   : 0.618
# NSE validation    : 0.506
#
# === Station 8006 (616/671) ===
# NSE calibration   : 0.572
# NSE validation    : 0.376
#
# === Station 8009 (617/671) ===
# NSE calibration   : 0.525
# NSE validation    : 0.414
#
# === Station 8011 (618/671) ===
# NSE calibration   : 0.615
# NSE validation    : 0.320
#
# === Station 8013 (619/671) ===
# ⚠️ Too many missing values (15.5%)
#
# === Station 81002 (620/671) ===
# NSE calibration   : 0.856
# NSE validation    : 0.849
#
# === Station 81003 (621/671) ===
# NSE calibration   : 0.804
# NSE validation    : 0.815
#
# === Station 81004 (622/671) ===
# NSE calibration   : 0.913
# NSE validation    : 0.906
#
# === Station 81006 (623/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.791
#
# === Station 81007 (624/671) ===
# NSE calibration   : 0.763
# NSE validation    : 0.726
#
# === Station 82001 (625/671) ===
# NSE calibration   : 0.846
# NSE validation    : 0.817
#
# === Station 82003 (626/671) ===
# NSE calibration   : 0.821
# NSE validation    : 0.816
#
# === Station 83003 (627/671) ===
# NSE calibration   : 0.730
# NSE validation    : 0.650
#
# === Station 83004 (628/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.753
#
# === Station 83006 (629/671) ===
# NSE calibration   : 0.826
# NSE validation    : 0.765
#
# === Station 83007 (630/671) ===
# NSE calibration   : 0.866
# NSE validation    : 0.814
#
# === Station 83009 (631/671) ===
# NSE calibration   : 0.789
# NSE validation    : 0.742
#
# === Station 83010 (632/671) ===
# NSE calibration   : 0.843
# NSE validation    : 0.806
#
# === Station 83013 (633/671) ===
# NSE calibration   : 0.811
# NSE validation    : 0.821
#
# === Station 84001 (634/671) ===
# NSE calibration   : 0.856
# NSE validation    : 0.834
#
# === Station 84004 (635/671) ===
# NSE calibration   : 0.877
# NSE validation    : 0.878
#
# === Station 84005 (636/671) ===
# NSE calibration   : 0.896
# NSE validation    : 0.892
#
# === Station 84008 (637/671) ===
# NSE calibration   : 0.787
# NSE validation    : 0.740
#
# === Station 84009 (638/671) ===
# NSE calibration   : 0.805
# NSE validation    : 0.720
#
# === Station 84012 (639/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.820
#
# === Station 84013 (640/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.894
#
# === Station 84014 (641/671) ===
# NSE calibration   : 0.797
# NSE validation    : 0.734
#
# === Station 84016 (642/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.778
#
# === Station 84017 (643/671) ===
# NSE calibration   : 0.897
# NSE validation    : 0.866
#
# === Station 84018 (644/671) ===
# NSE calibration   : 0.878
# NSE validation    : 0.858
#
# === Station 84019 (645/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.722
#
# === Station 84020 (646/671) ===
# NSE calibration   : 0.821
# NSE validation    : 0.750
#
# === Station 84022 (647/671) ===
# NSE calibration   : 0.743
# NSE validation    : 0.696
#
# === Station 84026 (648/671) ===
# NSE calibration   : 0.833
# NSE validation    : 0.742
#
# === Station 84030 (649/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.767
#
# === Station 85001 (650/671) ===
# NSE calibration   : 0.854
# NSE validation    : 0.830
#
# === Station 85002 (651/671) ===
# NSE calibration   : 0.789
# NSE validation    : 0.673
#
# === Station 85003 (652/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.745
#
# === Station 85004 (653/671) ===
# NSE calibration   : 0.785
# NSE validation    : 0.741
#
# === Station 88001 (654/671) ===
# ⚠️ Too many missing values (23.8%)
#
# === Station 89002 (655/671) ===
# NSE calibration   : 0.756
# NSE validation    : 0.709
#
# === Station 89003 (656/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.736
#
# === Station 89005 (657/671) ===
# NSE calibration   : 0.627
# NSE validation    : 0.605
#
# === Station 89007 (658/671) ===
# NSE calibration   : 0.681
# NSE validation    : 0.649
#
# === Station 90003 (659/671) ===
# NSE calibration   : 0.777
# NSE validation    : 0.738
#
# === Station 9002 (660/671) ===
# NSE calibration   : 0.783
# NSE validation    : 0.570
#
# === Station 9003 (661/671) ===
# NSE calibration   : 0.788
# NSE validation    : 0.611
#
# === Station 9004 (662/671) ===
# NSE calibration   : 0.807
# NSE validation    : 0.505
#
# === Station 9005 (663/671) ===
# NSE calibration   : 0.594
# NSE validation    : 0.391
#
# === Station 92001 (664/671) ===
# ⚠️ Too many missing values (22.3%)
#
# === Station 93001 (665/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.765
#
# === Station 94001 (666/671) ===
# NSE calibration   : 0.915
# NSE validation    : 0.899
#
# === Station 95001 (667/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.808
#
# === Station 96001 (668/671) ===
# NSE calibration   : 0.735
# NSE validation    : 0.657
#
# === Station 96002 (669/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.797
#
# === Station 96004 (670/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.706
#
# === Station 97002 (671/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.676
#
# ✅ Finished : 623 calibrated basins
# Total time: 7791.25 s
# Total time: 129.85 min
# Total time: 2.16 h

# %%
# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — CALIBRATION
# =============================================================
nse_cal = [res['NSE_cal'] for res in results_GR4J.values() if not np.isnan(res['NSE_cal'])]
rmse_cal = [res['RMSE_cal'] for res in results_GR4J.values() if not np.isnan(res['RMSE_cal'])]

print("\n================= CALIBRATION =================\n")

# ----- NSE -----
if nse_cal:
    print(f"NSE Calibration -> Median: {np.percentile(nse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_cal, 95):.4f}")
    print("MEAN NSE_CAL:", np.mean(nse_cal))
    print("MIN NSE_CAL:", np.min(nse_cal))
    print("MAX NSE_CAL:", np.max(nse_cal))
else:
    print("No NSE available for calibration.")

# ----- RMSE -----
print("\n--- RMSE Calibration ---")
if rmse_cal:
    print(f"RMSE Calibration -> Median: {np.percentile(rmse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_cal, 95):.4f}")
    print("MEAN RMSE_CAL:", np.mean(rmse_cal))
    print("MIN RMSE_CAL:", np.min(rmse_cal))
    print("MAX RMSE_CAL:", np.max(rmse_cal))
else:
    print("No RMSE available for calibration.")


# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — VALIDATION
# =============================================================
print("\n\n================= VALIDATION =================\n")

nse_val = [res['NSE_val'] for res in results_GR4J.values() if not np.isnan(res['NSE_val'])]
rmse_val = [res['RMSE_val'] for res in results_GR4J.values() if not np.isnan(res['RMSE_val'])]

# ----- NSE -----
if nse_val:
    print(f"NSE Validation -> Median: {np.percentile(nse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_val, 95):.4f}")
    print("MEAN NSE_VAL:", np.mean(nse_val))
    print("MIN NSE_VAL:", np.min(nse_val))
    print("MAX NSE_VAL:", np.max(nse_val))
else:
    print("No valid station for validation.")

# ----- RMSE -----
print("\n--- RMSE Validation ---")
if rmse_val:
    print(f"RMSE Validation -> Median: {np.percentile(rmse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_val, 95):.4f}")
    print("MEAN RMSE_VAL:", np.mean(rmse_val))
    print("MIN RMSE_VAL:", np.min(rmse_val))
    print("MAX RMSE_VAL:", np.max(rmse_val))
else:
    print("No valid station for RMSE in validation.")
# Out:
# ================= CALIBRATION =================
#
# NSE Calibration -> Median: 0.814, 5th percentile: 0.5673, 95th percentile: 0.9007
# MEAN NSE_CAL: 0.7826899265047589
# MIN NSE_CAL: -0.5286319282541476
# MAX NSE_CAL: 0.9550577706677827
#
# --- RMSE Calibration ---
# RMSE Calibration -> Median: 0.757, 5th percentile: 0.1865, 95th percentile: 2.7695
# MEAN RMSE_CAL: 1.0628525730765996
# MIN RMSE_CAL: 0.0805996707558844
# MAX RMSE_CAL: 10.52069210892935
#
#
# ================= VALIDATION =================
#
# NSE Validation -> Median: 0.759, 5th percentile: 0.1968, 95th percentile: 0.8877
# MEAN NSE_VAL: 0.665496505753149
# MIN NSE_VAL: -3.6695473000443
# MAX NSE_VAL: 0.9553012114514174
#
# --- RMSE Validation ---
# RMSE Validation -> Median: 0.931, 5th percentile: 0.2520, 95th percentile: 3.0295
# MEAN RMSE_VAL: 1.2335054870412532
# MIN RMSE_VAL: 0.1305648855778599
# MAX RMSE_VAL: 10.089213602640902

# %% [markdown]
# ##HBV

# %%
start_time = time.perf_counter()

# ============================================
# 1️⃣ General setting
# ============================================

results_HBV = {}

# ============================================
# 3️⃣ HBV
# ============================================
@njit
def hbv_numba(P, ET, params):
    FC, BETA, LP, K0, K1, K2, UZL, PERC = params

    SM = 0.5 * FC
    UZ = 0.0
    LZ = 0.0

    n = len(P)
    Qsim = np.zeros(n)

    for t in range(n):
        p = P[t]
        et = ET[t]

        # Soil moisture
        soil_ratio = SM / FC
        recharge = p * soil_ratio**BETA
        SM += p - recharge
        if SM > FC:
            recharge += SM - FC
            SM = FC
        evap = min(et * min(SM / (LP * FC), 1.0), SM)
        SM -= evap

        # Upper reservoir
        UZ += recharge
        perc = min(PERC, UZ)
        UZ -= perc
        LZ += perc

        # Quick flow
        Q0 = K0 * (UZ - UZL) if UZ > UZL else 0.0
        if Q0 > 0:
            UZ -= Q0

        # Interflow
        Q1 = K1 * UZ
        UZ -= Q1

        # Baseflow
        Q2 = K2 * LZ
        LZ -= Q2

        # Total discharge
        Qsim[t] = max(0.0, Q0 + Q1 + Q2)

    return Qsim

# ============================================
# 4️⃣ Fonction objective
# ============================================
def objective_hbv(x, Q, P, ET):
    Qsim = hbv_numba(P, ET, x)
    nse = NSE(Q, Qsim)
    return 1 - nse if np.isfinite(nse) else 1e6

# ============================================
# 5️⃣ Boucle sur stations
# ============================================
bounds = [
    (50,1000), (1,6), (0.3,1), (0,0.5), (0,0.3),
    (0,0.1), (0,100), (0,5)
]

for i, station_id in enumerate(stations, start=1):
    print(f"\n=== Station {station_id} ({i}/{len(stations)}) ===")

    Q_obs = ds_recent[station_id].sel(dynamic_features="q_mmd_obs").to_numpy()
    P     = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    ET   = ds_recent[station_id].sel(dynamic_features="pet_mm").to_numpy()

    N = len(Q_obs)
    if N == 0 or np.all(np.isnan(Q_obs)):
        continue

    missing_ratio = np.sum(np.isnan(Q_obs)) / N
    if missing_ratio > max_missing_ratio:
        continue

    # Calibration / validation
    b1 = int(N * b1_ratio)
    Q_cal, Q_val = Q_obs[:b1], Q_obs[b1:]
    P_cal, P_val = P[:b1], P[b1:]
    ET_cal, ET_val = ET[:b1], ET[b1:]

    # Multi-start calibration
    best_fun = np.inf
    best_x = None
    np.random.seed(42)
    for _ in range(20):
        x0 = [np.random.uniform(b[0], b[1]) for b in bounds]
        res = minimize(
            objective_hbv,
            x0,
            args=(Q_cal, P_cal, ET_cal),
            method="L-BFGS-B",
            bounds=bounds,
            options={"maxiter":3000}
        )
        if res.fun < best_fun:
            best_fun = res.fun
            best_x = res.x

    if best_x is None:
        continue

    Qsim_cal = hbv_numba(P_cal, ET_cal, best_x)
    Qsim_val = hbv_numba(P_val, ET_val, best_x)

    # ============================================
    # Metrics
    # ============================================
    nse_cal = NSE(Q_cal, Qsim_cal)
    rmse_cal = RMSE(Q_cal, Qsim_cal)

    nse_val = NSE(Q_val, Qsim_val)
    rmse_val = RMSE(Q_val, Qsim_val)

    FHV_val = FHV(Q_val, Qsim_val)
    FLV_val = FLV(Q_val, Qsim_val)
    KGE_val, KGE_1, KGE_2, KGE_3  = KGE(Q_val, Qsim_val)

    # ============================================
    # Store results
    # ============================================
    results_HBV[station_id] = {
        "NSE_cal": nse_cal,
        "RMSE_cal": rmse_cal,
        "NSE_val": nse_val,
        "RMSE_val": rmse_val,
        "FHV_val": FHV_val,
        "FLV_val": FLV_val,
        "KGE_val": KGE_val,
        "KGE_1": KGE_1,
        "KGE_2": KGE_2,
        "KGE_3": KGE_3,

        "Qsim": Qsim_val,
        "Q_obs": Q_val,
        **params
    }

    # ============================================
    # Display
    # ============================================
    print(f"NSE calibration   : {nse_cal:.3f}")
    print(f"NSE validation    : {nse_val:.3f}")

print(f"\n✅ Finished : {len(results_HBV)} calibrated basins")

end_time = time.perf_counter()

total_time = end_time - start_time

print(f"Total time: {total_time:.2f} s")
print(f"Total time: {total_time/60:.2f} min")
print(f"Total time: {total_time/3600:.2f} h")
# Out:
# === Station 10002 (1/671) ===
# NSE calibration   : 0.718
# NSE validation    : 0.577
#
# === Station 10003 (2/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.751
#
# === Station 1001 (3/671) ===
#
# === Station 101002 (4/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.680
#
# === Station 101005 (5/671) ===
# NSE calibration   : 0.761
# NSE validation    : 0.783
#
# === Station 102001 (6/671) ===
# NSE calibration   : 0.719
# NSE validation    : 0.737
#
# === Station 106001 (7/671) ===
#
# === Station 107001 (8/671) ===
#
# === Station 11001 (9/671) ===
# NSE calibration   : 0.802
# NSE validation    : 0.600
#
# === Station 11003 (10/671) ===
# NSE calibration   : 0.723
# NSE validation    : 0.443
#
# === Station 11004 (11/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.681
#
# === Station 12001 (12/671) ===
# NSE calibration   : 0.604
# NSE validation    : 0.424
#
# === Station 12002 (13/671) ===
# NSE calibration   : 0.671
# NSE validation    : 0.517
#
# === Station 12005 (14/671) ===
# NSE calibration   : 0.660
# NSE validation    : 0.526
#
# === Station 12006 (15/671) ===
# NSE calibration   : 0.557
# NSE validation    : 0.358
#
# === Station 12007 (16/671) ===
# NSE calibration   : 0.448
# NSE validation    : 0.374
#
# === Station 12008 (17/671) ===
# NSE calibration   : 0.739
# NSE validation    : 0.730
#
# === Station 12009 (18/671) ===
# NSE calibration   : 0.670
# NSE validation    : 0.691
#
# === Station 13001 (19/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.803
#
# === Station 13004 (20/671) ===
# NSE calibration   : 0.744
# NSE validation    : 0.702
#
# === Station 13005 (21/671) ===
# NSE calibration   : 0.833
# NSE validation    : 0.085
#
# === Station 13007 (22/671) ===
# NSE calibration   : 0.752
# NSE validation    : 0.669
#
# === Station 13008 (23/671) ===
# NSE calibration   : 0.746
# NSE validation    : 0.684
#
# === Station 14001 (24/671) ===
# NSE calibration   : 0.840
# NSE validation    : 0.779
#
# === Station 14002 (25/671) ===
# NSE calibration   : 0.808
# NSE validation    : -0.309
#
# === Station 14005 (26/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.696
#
# === Station 15006 (27/671) ===
# NSE calibration   : 0.851
# NSE validation    : 0.804
#
# === Station 15007 (28/671) ===
# NSE calibration   : 0.878
# NSE validation    : 0.842
#
# === Station 15010 (29/671) ===
# NSE calibration   : 0.730
# NSE validation    : 0.683
#
# === Station 15011 (30/671) ===
# NSE calibration   : 0.611
# NSE validation    : 0.444
#
# === Station 15012 (31/671) ===
# NSE calibration   : 0.823
# NSE validation    : 0.737
#
# === Station 15013 (32/671) ===
# NSE calibration   : 0.712
# NSE validation    : 0.650
#
# === Station 15014 (33/671) ===
# NSE calibration   : 0.642
# NSE validation    : 0.593
#
# === Station 15016 (34/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.817
#
# === Station 15021 (35/671) ===
# NSE calibration   : 0.829
# NSE validation    : 0.790
#
# === Station 15023 (36/671) ===
# NSE calibration   : 0.812
# NSE validation    : 0.718
#
# === Station 15024 (37/671) ===
# NSE calibration   : 0.779
# NSE validation    : 0.751
#
# === Station 15025 (38/671) ===
# NSE calibration   : 0.699
# NSE validation    : 0.657
#
# === Station 15030 (39/671) ===
# NSE calibration   : 0.828
# NSE validation    : 0.753
#
# === Station 15039 (40/671) ===
# NSE calibration   : 0.483
# NSE validation    : 0.414
#
# === Station 16001 (41/671) ===
# NSE calibration   : 0.856
# NSE validation    : 0.806
#
# === Station 16003 (42/671) ===
# NSE calibration   : 0.789
# NSE validation    : 0.735
#
# === Station 16004 (43/671) ===
# NSE calibration   : 0.856
# NSE validation    : 0.797
#
# === Station 17001 (44/671) ===
# NSE calibration   : 0.752
# NSE validation    : 0.756
#
# === Station 17003 (45/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.706
#
# === Station 17004 (46/671) ===
# NSE calibration   : 0.820
# NSE validation    : 0.753
#
# === Station 17005 (47/671) ===
# NSE calibration   : 0.805
# NSE validation    : 0.805
#
# === Station 17015 (48/671) ===
# NSE calibration   : 0.745
# NSE validation    : 0.694
#
# === Station 17018 (49/671) ===
#
# === Station 18001 (50/671) ===
# NSE calibration   : 0.778
# NSE validation    : 0.707
#
# === Station 18002 (51/671) ===
# NSE calibration   : 0.742
# NSE validation    : 0.638
#
# === Station 18003 (52/671) ===
# NSE calibration   : 0.858
# NSE validation    : 0.847
#
# === Station 18008 (53/671) ===
# NSE calibration   : 0.803
# NSE validation    : 0.786
#
# === Station 18010 (54/671) ===
#
# === Station 18011 (55/671) ===
# NSE calibration   : 0.806
# NSE validation    : 0.844
#
# === Station 18014 (56/671) ===
# NSE calibration   : 0.819
# NSE validation    : 0.742
#
# === Station 18017 (57/671) ===
#
# === Station 18018 (58/671) ===
#
# === Station 19001 (59/671) ===
# NSE calibration   : 0.798
# NSE validation    : 0.764
#
# === Station 19006 (60/671) ===
# NSE calibration   : 0.790
# NSE validation    : 0.760
#
# === Station 19010 (61/671) ===
#
# === Station 19017 (62/671) ===
# NSE calibration   : 0.789
# NSE validation    : 0.654
#
# === Station 19020 (63/671) ===
# NSE calibration   : 0.798
# NSE validation    : 0.707
#
# === Station 20002 (64/671) ===
# NSE calibration   : 0.750
# NSE validation    : 0.466
#
# === Station 20003 (65/671) ===
# NSE calibration   : 0.769
# NSE validation    : 0.553
#
# === Station 20007 (66/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.578
#
# === Station 2001 (67/671) ===
# NSE calibration   : 0.655
# NSE validation    : 0.602
#
# === Station 2002 (68/671) ===
#
# === Station 21003 (69/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.788
#
# === Station 21006 (70/671) ===
# NSE calibration   : 0.807
# NSE validation    : 0.781
#
# === Station 21008 (71/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.729
#
# === Station 21009 (72/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.725
#
# === Station 21011 (73/671) ===
# NSE calibration   : 0.793
# NSE validation    : 0.747
#
# === Station 21012 (74/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.782
#
# === Station 21013 (75/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.662
#
# === Station 21015 (76/671) ===
#
# === Station 21016 (77/671) ===
# NSE calibration   : 0.663
# NSE validation    : 0.619
#
# === Station 21017 (78/671) ===
#
# === Station 21018 (79/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.657
#
# === Station 21022 (80/671) ===
# NSE calibration   : 0.714
# NSE validation    : 0.545
#
# === Station 21023 (81/671) ===
# NSE calibration   : 0.475
# NSE validation    : 0.447
#
# === Station 21024 (82/671) ===
# NSE calibration   : 0.704
# NSE validation    : 0.697
#
# === Station 21026 (83/671) ===
# NSE calibration   : 0.720
# NSE validation    : 0.678
#
# === Station 21027 (84/671) ===
# NSE calibration   : 0.666
# NSE validation    : 0.545
#
# === Station 22001 (85/671) ===
# NSE calibration   : 0.744
# NSE validation    : 0.701
#
# === Station 22006 (86/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.687
#
# === Station 22007 (87/671) ===
# NSE calibration   : 0.758
# NSE validation    : 0.666
#
# === Station 22009 (88/671) ===
# NSE calibration   : 0.719
# NSE validation    : 0.700
#
# === Station 23001 (89/671) ===
# NSE calibration   : 0.766
# NSE validation    : 0.721
#
# === Station 23004 (90/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.779
#
# === Station 23006 (91/671) ===
# NSE calibration   : 0.790
# NSE validation    : 0.792
#
# === Station 23007 (92/671) ===
# NSE calibration   : 0.675
# NSE validation    : 0.668
#
# === Station 23008 (93/671) ===
# NSE calibration   : 0.724
# NSE validation    : 0.663
#
# === Station 23011 (94/671) ===
# NSE calibration   : 0.721
# NSE validation    : 0.722
#
# === Station 23016 (95/671) ===
# NSE calibration   : 0.821
# NSE validation    : 0.796
#
# === Station 24001 (96/671) ===
# NSE calibration   : 0.758
# NSE validation    : 0.706
#
# === Station 24003 (97/671) ===
# NSE calibration   : 0.740
# NSE validation    : 0.748
#
# === Station 24004 (98/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.705
#
# === Station 24005 (99/671) ===
# NSE calibration   : 0.738
# NSE validation    : 0.664
#
# === Station 25001 (100/671) ===
# NSE calibration   : 0.744
# NSE validation    : 0.711
#
# === Station 25003 (101/671) ===
# NSE calibration   : 0.605
# NSE validation    : 0.588
#
# === Station 25006 (102/671) ===
# NSE calibration   : 0.783
# NSE validation    : 0.745
#
# === Station 25012 (103/671) ===
# NSE calibration   : 0.746
# NSE validation    : 0.761
#
# === Station 25020 (104/671) ===
# NSE calibration   : 0.755
# NSE validation    : 0.721
#
# === Station 25021 (105/671) ===
# NSE calibration   : 0.708
# NSE validation    : 0.628
#
# === Station 25029 (106/671) ===
#
# === Station 26003 (107/671) ===
# NSE calibration   : 0.826
# NSE validation    : 0.542
#
# === Station 26005 (108/671) ===
# NSE calibration   : 0.895
# NSE validation    : 0.660
#
# === Station 26006 (109/671) ===
# NSE calibration   : -0.312
# NSE validation    : -0.339
#
# === Station 26008 (110/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.615
#
# === Station 26009 (111/671) ===
# NSE calibration   : 0.832
# NSE validation    : 0.689
#
# === Station 27001 (112/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.704
#
# === Station 27002 (113/671) ===
# NSE calibration   : 0.751
# NSE validation    : 0.659
#
# === Station 27003 (114/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.796
#
# === Station 27006 (115/671) ===
# NSE calibration   : 0.760
# NSE validation    : 0.693
#
# === Station 27007 (116/671) ===
# NSE calibration   : 0.746
# NSE validation    : 0.704
#
# === Station 27009 (117/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.765
#
# === Station 27021 (118/671) ===
# NSE calibration   : 0.790
# NSE validation    : 0.752
#
# === Station 27023 (119/671) ===
# NSE calibration   : 0.663
# NSE validation    : 0.696
#
# === Station 27025 (120/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.727
#
# === Station 27026 (121/671) ===
# NSE calibration   : 0.780
# NSE validation    : 0.761
#
# === Station 27029 (122/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.797
#
# === Station 27030 (123/671) ===
# NSE calibration   : 0.790
# NSE validation    : 0.752
#
# === Station 27032 (124/671) ===
# NSE calibration   : 0.448
# NSE validation    : 0.439
#
# === Station 27034 (125/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.776
#
# === Station 27035 (126/671) ===
# NSE calibration   : 0.864
# NSE validation    : 0.821
#
# === Station 27038 (127/671) ===
# NSE calibration   : -3.448
# NSE validation    : -1.932
#
# === Station 27041 (128/671) ===
# NSE calibration   : 0.847
# NSE validation    : 0.738
#
# === Station 27042 (129/671) ===
# NSE calibration   : 0.784
# NSE validation    : 0.738
#
# === Station 27043 (130/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.789
#
# === Station 27047 (131/671) ===
# NSE calibration   : 0.851
# NSE validation    : 0.874
#
# === Station 27049 (132/671) ===
# NSE calibration   : 0.769
# NSE validation    : 0.741
#
# === Station 27051 (133/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.796
#
# === Station 27062 (134/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.753
#
# === Station 27064 (135/671) ===
# NSE calibration   : 0.698
# NSE validation    : 0.596
#
# === Station 27065 (136/671) ===
# NSE calibration   : 0.841
# NSE validation    : 0.827
#
# === Station 27071 (137/671) ===
# NSE calibration   : 0.775
# NSE validation    : 0.716
#
# === Station 27073 (138/671) ===
# NSE calibration   : -0.036
# NSE validation    : -0.122
#
# === Station 27077 (139/671) ===
# NSE calibration   : 0.731
# NSE validation    : 0.708
#
# === Station 27079 (140/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.788
#
# === Station 27080 (141/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.843
#
# === Station 27084 (142/671) ===
# NSE calibration   : 0.854
# NSE validation    : 0.831
#
# === Station 27087 (143/671) ===
# NSE calibration   : 0.802
# NSE validation    : 0.692
#
# === Station 27089 (144/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.715
#
# === Station 27090 (145/671) ===
#
# === Station 28001 (146/671) ===
# NSE calibration   : 0.678
# NSE validation    : 0.580
#
# === Station 28003 (147/671) ===
#
# === Station 28008 (148/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.777
#
# === Station 28009 (149/671) ===
# NSE calibration   : 0.842
# NSE validation    : 0.803
#
# === Station 28012 (150/671) ===
#
# === Station 28015 (151/671) ===
# NSE calibration   : 0.610
# NSE validation    : 0.217
#
# === Station 28018 (152/671) ===
# NSE calibration   : 0.776
# NSE validation    : 0.730
#
# === Station 28022 (153/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.800
#
# === Station 28023 (154/671) ===
#
# === Station 28024 (155/671) ===
# NSE calibration   : 0.740
# NSE validation    : 0.686
#
# === Station 28026 (156/671) ===
# NSE calibration   : 0.694
# NSE validation    : 0.644
#
# === Station 28031 (157/671) ===
# NSE calibration   : 0.824
# NSE validation    : 0.761
#
# === Station 28033 (158/671) ===
#
# === Station 28039 (159/671) ===
# NSE calibration   : 0.811
# NSE validation    : 0.746
#
# === Station 28040 (160/671) ===
# NSE calibration   : 0.798
# NSE validation    : 0.703
#
# === Station 28043 (161/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.728
#
# === Station 28044 (162/671) ===
# NSE calibration   : 0.805
# NSE validation    : 0.366
#
# === Station 28046 (163/671) ===
# NSE calibration   : 0.892
# NSE validation    : 0.844
#
# === Station 28048 (164/671) ===
# NSE calibration   : 0.737
# NSE validation    : 0.644
#
# === Station 28050 (165/671) ===
# NSE calibration   : 0.755
# NSE validation    : 0.622
#
# === Station 28052 (166/671) ===
# NSE calibration   : 0.692
# NSE validation    : 0.555
#
# === Station 28055 (167/671) ===
# NSE calibration   : 0.823
# NSE validation    : 0.731
#
# === Station 28056 (168/671) ===
# NSE calibration   : 0.736
# NSE validation    : 0.682
#
# === Station 28060 (169/671) ===
# NSE calibration   : 0.481
# NSE validation    : 0.132
#
# === Station 28066 (170/671) ===
# NSE calibration   : 0.744
# NSE validation    : 0.696
#
# === Station 28067 (171/671) ===
# NSE calibration   : 0.798
# NSE validation    : 0.737
#
# === Station 28072 (172/671) ===
# NSE calibration   : 0.656
# NSE validation    : 0.582
#
# === Station 28074 (173/671) ===
# NSE calibration   : 0.799
# NSE validation    : 0.726
#
# === Station 28080 (174/671) ===
# NSE calibration   : 0.691
# NSE validation    : 0.706
#
# === Station 28081 (175/671) ===
# NSE calibration   : 0.811
# NSE validation    : 0.769
#
# === Station 28082 (176/671) ===
# NSE calibration   : 0.751
# NSE validation    : 0.724
#
# === Station 28085 (177/671) ===
# NSE calibration   : 0.846
# NSE validation    : 0.780
#
# === Station 28091 (178/671) ===
# NSE calibration   : 0.784
# NSE validation    : 0.653
#
# === Station 28093 (179/671) ===
# NSE calibration   : 0.775
# NSE validation    : 0.728
#
# === Station 28115 (180/671) ===
# NSE calibration   : 0.343
# NSE validation    : -0.073
#
# === Station 28116 (181/671) ===
#
# === Station 28117 (182/671) ===
#
# === Station 29002 (183/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.601
#
# === Station 29003 (184/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.509
#
# === Station 29005 (185/671) ===
# NSE calibration   : 0.668
# NSE validation    : 0.466
#
# === Station 29009 (186/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.656
#
# === Station 30001 (187/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.644
#
# === Station 30004 (188/671) ===
# NSE calibration   : 0.738
# NSE validation    : 0.702
#
# === Station 30005 (189/671) ===
#
# === Station 30011 (190/671) ===
# NSE calibration   : 0.768
# NSE validation    : 0.539
#
# === Station 30012 (191/671) ===
# NSE calibration   : 0.693
# NSE validation    : 0.658
#
# === Station 30014 (192/671) ===
# NSE calibration   : 0.692
# NSE validation    : 0.574
#
# === Station 30015 (193/671) ===
# NSE calibration   : 0.812
# NSE validation    : 0.626
#
# === Station 3003 (194/671) ===
# NSE calibration   : 0.784
# NSE validation    : 0.760
#
# === Station 31002 (195/671) ===
# NSE calibration   : 0.715
# NSE validation    : 0.608
#
# === Station 31006 (196/671) ===
# NSE calibration   : 0.707
# NSE validation    : 0.443
#
# === Station 31010 (197/671) ===
# NSE calibration   : 0.733
# NSE validation    : 0.642
#
# === Station 31021 (198/671) ===
# NSE calibration   : 0.717
# NSE validation    : 0.648
#
# === Station 31023 (199/671) ===
# NSE calibration   : 0.722
# NSE validation    : 0.561
#
# === Station 31025 (200/671) ===
# NSE calibration   : 0.745
# NSE validation    : 0.652
#
# === Station 32003 (201/671) ===
# NSE calibration   : 0.694
# NSE validation    : 0.564
#
# === Station 32004 (202/671) ===
# NSE calibration   : 0.733
# NSE validation    : 0.664
#
# === Station 32006 (203/671) ===
# NSE calibration   : 0.756
# NSE validation    : 0.732
#
# === Station 32008 (204/671) ===
# NSE calibration   : 0.768
# NSE validation    : 0.725
#
# === Station 33006 (205/671) ===
# NSE calibration   : 0.853
# NSE validation    : 0.627
#
# === Station 33007 (206/671) ===
# NSE calibration   : 0.834
# NSE validation    : 0.441
#
# === Station 33012 (207/671) ===
# NSE calibration   : 0.707
# NSE validation    : 0.620
#
# === Station 33013 (208/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.664
#
# === Station 33014 (209/671) ===
# NSE calibration   : 0.737
# NSE validation    : 0.583
#
# === Station 33018 (210/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.658
#
# === Station 33019 (211/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.768
#
# === Station 33020 (212/671) ===
#
# === Station 33021 (213/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.588
#
# === Station 33022 (214/671) ===
# NSE calibration   : 0.774
# NSE validation    : 0.669
#
# === Station 33023 (215/671) ===
# NSE calibration   : 0.656
# NSE validation    : 0.407
#
# === Station 33024 (216/671) ===
# NSE calibration   : 0.711
# NSE validation    : 0.619
#
# === Station 33026 (217/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.754
#
# === Station 33028 (218/671) ===
# NSE calibration   : 0.730
# NSE validation    : 0.607
#
# === Station 33029 (219/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.654
#
# === Station 33031 (220/671) ===
# NSE calibration   : 0.627
# NSE validation    : 0.490
#
# === Station 33032 (221/671) ===
# NSE calibration   : 0.895
# NSE validation    : 0.025
#
# === Station 33033 (222/671) ===
# NSE calibration   : 0.746
# NSE validation    : 0.639
#
# === Station 33034 (223/671) ===
# NSE calibration   : 0.852
# NSE validation    : 0.667
#
# === Station 33035 (224/671) ===
# NSE calibration   : 0.738
# NSE validation    : 0.582
#
# === Station 33039 (225/671) ===
# NSE calibration   : 0.811
# NSE validation    : 0.766
#
# === Station 33053 (226/671) ===
#
# === Station 33054 (227/671) ===
# NSE calibration   : 0.889
# NSE validation    : -0.030
#
# === Station 33058 (228/671) ===
# NSE calibration   : 0.739
# NSE validation    : 0.617
#
# === Station 34002 (229/671) ===
# NSE calibration   : 0.711
# NSE validation    : 0.604
#
# === Station 34003 (230/671) ===
# NSE calibration   : 0.631
# NSE validation    : 0.564
#
# === Station 34004 (231/671) ===
# NSE calibration   : 0.650
# NSE validation    : 0.441
#
# === Station 34005 (232/671) ===
# NSE calibration   : 0.596
# NSE validation    : 0.240
#
# === Station 34006 (233/671) ===
# NSE calibration   : 0.728
# NSE validation    : 0.711
#
# === Station 34007 (234/671) ===
# NSE calibration   : 0.669
# NSE validation    : 0.600
#
# === Station 34008 (235/671) ===
# NSE calibration   : 0.511
# NSE validation    : -0.751
#
# === Station 34010 (236/671) ===
# NSE calibration   : 0.752
# NSE validation    : 0.643
#
# === Station 34011 (237/671) ===
# NSE calibration   : 0.681
# NSE validation    : 0.306
#
# === Station 34012 (238/671) ===
# NSE calibration   : 0.929
# NSE validation    : -0.354
#
# === Station 35003 (239/671) ===
# NSE calibration   : 0.515
# NSE validation    : 0.347
#
# === Station 35008 (240/671) ===
# NSE calibration   : 0.743
# NSE validation    : 0.690
#
# === Station 36003 (241/671) ===
# NSE calibration   : 0.714
# NSE validation    : 0.617
#
# === Station 36006 (242/671) ===
# NSE calibration   : 0.727
# NSE validation    : 0.679
#
# === Station 36009 (243/671) ===
# NSE calibration   : 0.743
# NSE validation    : 0.662
#
# === Station 36010 (244/671) ===
# NSE calibration   : 0.712
# NSE validation    : 0.729
#
# === Station 36011 (245/671) ===
# NSE calibration   : 0.767
# NSE validation    : 0.679
#
# === Station 36012 (246/671) ===
# NSE calibration   : 0.088
# NSE validation    : 0.229
#
# === Station 37001 (247/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.785
#
# === Station 37003 (248/671) ===
# NSE calibration   : 0.744
# NSE validation    : 0.646
#
# === Station 37005 (249/671) ===
# NSE calibration   : 0.725
# NSE validation    : 0.708
#
# === Station 37008 (250/671) ===
# NSE calibration   : 0.731
# NSE validation    : 0.701
#
# === Station 37009 (251/671) ===
# NSE calibration   : 0.704
# NSE validation    : 0.680
#
# === Station 37010 (252/671) ===
# NSE calibration   : 0.669
# NSE validation    : 0.668
#
# === Station 37011 (253/671) ===
# NSE calibration   : 0.721
# NSE validation    : 0.666
#
# === Station 37018 (254/671) ===
# NSE calibration   : 0.744
# NSE validation    : 0.677
#
# === Station 37019 (255/671) ===
# NSE calibration   : 0.773
# NSE validation    : 0.759
#
# === Station 37020 (256/671) ===
# NSE calibration   : 0.740
# NSE validation    : 0.608
#
# === Station 37031 (257/671) ===
# NSE calibration   : 0.656
# NSE validation    : 0.646
#
# === Station 37033 (258/671) ===
# NSE calibration   : 0.759
# NSE validation    : 0.770
#
# === Station 38001 (259/671) ===
# NSE calibration   : 0.738
# NSE validation    : 0.686
#
# === Station 38003 (260/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.684
#
# === Station 38004 (261/671) ===
# NSE calibration   : 0.669
# NSE validation    : 0.579
#
# === Station 38007 (262/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.789
#
# === Station 38012 (263/671) ===
# NSE calibration   : 0.598
# NSE validation    : 0.711
#
# === Station 38014 (264/671) ===
# NSE calibration   : 0.833
# NSE validation    : 0.763
#
# === Station 38017 (265/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.422
#
# === Station 38018 (266/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.807
#
# === Station 38021 (267/671) ===
# NSE calibration   : 0.779
# NSE validation    : 0.750
#
# === Station 38026 (268/671) ===
# NSE calibration   : 0.796
# NSE validation    : 0.726
#
# === Station 38029 (269/671) ===
# NSE calibration   : 0.621
# NSE validation    : 0.647
#
# === Station 38030 (270/671) ===
# NSE calibration   : 0.578
# NSE validation    : 0.470
#
# === Station 39001 (271/671) ===
# NSE calibration   : 0.894
# NSE validation    : 0.844
#
# === Station 39002 (272/671) ===
# NSE calibration   : 0.896
# NSE validation    : 0.875
#
# === Station 39004 (273/671) ===
# NSE calibration   : 0.474
# NSE validation    : 0.343
#
# === Station 39005 (274/671) ===
# NSE calibration   : 0.679
# NSE validation    : 0.652
#
# === Station 39006 (275/671) ===
# NSE calibration   : 0.844
# NSE validation    : 0.790
#
# === Station 39007 (276/671) ===
# NSE calibration   : 0.827
# NSE validation    : 0.772
#
# === Station 39008 (277/671) ===
# NSE calibration   : 0.906
# NSE validation    : 0.846
#
# === Station 39010 (278/671) ===
# NSE calibration   : 0.854
# NSE validation    : 0.767
#
# === Station 39011 (279/671) ===
# NSE calibration   : 0.618
# NSE validation    : 0.554
#
# === Station 39012 (280/671) ===
# NSE calibration   : 0.651
# NSE validation    : 0.604
#
# === Station 39014 (281/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.407
#
# === Station 39015 (282/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.793
#
# === Station 39016 (283/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.821
#
# === Station 39017 (284/671) ===
# NSE calibration   : 0.663
# NSE validation    : 0.577
#
# === Station 39019 (285/671) ===
# NSE calibration   : 0.884
# NSE validation    : 0.746
#
# === Station 39020 (286/671) ===
# NSE calibration   : 0.906
# NSE validation    : 0.850
#
# === Station 39021 (287/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.738
#
# === Station 39022 (288/671) ===
# NSE calibration   : 0.811
# NSE validation    : 0.722
#
# === Station 39023 (289/671) ===
# NSE calibration   : 0.833
# NSE validation    : -0.022
#
# === Station 39025 (290/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.818
#
# === Station 39027 (291/671) ===
# NSE calibration   : 0.741
# NSE validation    : 0.495
#
# === Station 39028 (292/671) ===
# NSE calibration   : 0.743
# NSE validation    : 0.669
#
# === Station 39029 (293/671) ===
# NSE calibration   : 0.602
# NSE validation    : 0.610
#
# === Station 39034 (294/671) ===
# NSE calibration   : 0.899
# NSE validation    : 0.781
#
# === Station 39035 (295/671) ===
# NSE calibration   : 0.892
# NSE validation    : 0.438
#
# === Station 39036 (296/671) ===
# NSE calibration   : -0.097
# NSE validation    : -1.031
#
# === Station 39037 (297/671) ===
# NSE calibration   : 0.871
# NSE validation    : 0.814
#
# === Station 39042 (298/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.703
#
# === Station 39049 (299/671) ===
# NSE calibration   : 0.821
# NSE validation    : 0.835
#
# === Station 39052 (300/671) ===
# NSE calibration   : 0.817
# NSE validation    : 0.788
#
# === Station 39054 (301/671) ===
#
# === Station 39056 (302/671) ===
# NSE calibration   : 0.592
# NSE validation    : 0.647
#
# === Station 39061 (303/671) ===
# NSE calibration   : 0.328
# NSE validation    : 0.040
#
# === Station 39065 (304/671) ===
# NSE calibration   : 0.840
# NSE validation    : 0.655
#
# === Station 39069 (305/671) ===
# NSE calibration   : 0.746
# NSE validation    : 0.711
#
# === Station 39072 (306/671) ===
# NSE calibration   : 0.875
# NSE validation    : 0.856
#
# === Station 39078 (307/671) ===
# NSE calibration   : 0.582
# NSE validation    : 0.397
#
# === Station 39081 (308/671) ===
# NSE calibration   : 0.862
# NSE validation    : 0.796
#
# === Station 39087 (309/671) ===
# NSE calibration   : 0.784
# NSE validation    : 0.729
#
# === Station 39088 (310/671) ===
# NSE calibration   : 0.834
# NSE validation    : 0.746
#
# === Station 39095 (311/671) ===
# NSE calibration   : 0.711
# NSE validation    : 0.740
#
# === Station 39099 (312/671) ===
# NSE calibration   : 0.862
# NSE validation    : 0.630
#
# === Station 39101 (313/671) ===
# NSE calibration   : 0.900
# NSE validation    : 0.609
#
# === Station 39105 (314/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.777
#
# === Station 39108 (315/671) ===
# NSE calibration   : 0.915
# NSE validation    : 0.806
#
# === Station 39114 (316/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.505
#
# === Station 39120 (317/671) ===
# NSE calibration   : 0.647
# NSE validation    : 0.321
#
# === Station 39125 (318/671) ===
#
# === Station 39127 (319/671) ===
#
# === Station 39141 (320/671) ===
#
# === Station 39142 (321/671) ===
#
# === Station 39143 (322/671) ===
#
# === Station 39144 (323/671) ===
#
# === Station 40003 (324/671) ===
# NSE calibration   : 0.806
# NSE validation    : 0.770
#
# === Station 40004 (325/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.763
#
# === Station 40005 (326/671) ===
# NSE calibration   : 0.711
# NSE validation    : 0.709
#
# === Station 40006 (327/671) ===
# NSE calibration   : 0.646
# NSE validation    : -1.892
#
# === Station 40007 (328/671) ===
# NSE calibration   : 0.782
# NSE validation    : 0.775
#
# === Station 40009 (329/671) ===
# NSE calibration   : 0.734
# NSE validation    : 0.762
#
# === Station 4001 (330/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.710
#
# === Station 40010 (331/671) ===
# NSE calibration   : 0.705
# NSE validation    : 0.740
#
# === Station 40011 (332/671) ===
# NSE calibration   : 0.812
# NSE validation    : 0.830
#
# === Station 40012 (333/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.742
#
# === Station 40013 (334/671) ===
# NSE calibration   : 0.755
# NSE validation    : 0.639
#
# === Station 40016 (335/671) ===
# NSE calibration   : 0.493
# NSE validation    : 0.387
#
# === Station 40017 (336/671) ===
# NSE calibration   : 0.793
# NSE validation    : 0.689
#
# === Station 40018 (337/671) ===
# NSE calibration   : 0.742
# NSE validation    : 0.668
#
# === Station 40020 (338/671) ===
# NSE calibration   : 0.768
# NSE validation    : 0.768
#
# === Station 40021 (339/671) ===
# NSE calibration   : 0.763
# NSE validation    : 0.754
#
# === Station 40022 (340/671) ===
#
# === Station 4003 (341/671) ===
# NSE calibration   : 0.615
# NSE validation    : 0.528
#
# === Station 40033 (342/671) ===
# NSE calibration   : 0.870
# NSE validation    : 0.738
#
# === Station 4005 (343/671) ===
# NSE calibration   : 0.721
# NSE validation    : 0.715
#
# === Station 4006 (344/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.815
#
# === Station 41001 (345/671) ===
# NSE calibration   : 0.711
# NSE validation    : 0.568
#
# === Station 41003 (346/671) ===
# NSE calibration   : 0.756
# NSE validation    : 0.712
#
# === Station 41004 (347/671) ===
#
# === Station 41005 (348/671) ===
# NSE calibration   : 0.771
# NSE validation    : 0.762
#
# === Station 41006 (349/671) ===
# NSE calibration   : 0.746
# NSE validation    : 0.720
#
# === Station 41009 (350/671) ===
# NSE calibration   : 0.713
# NSE validation    : 0.583
#
# === Station 41011 (351/671) ===
# NSE calibration   : 0.794
# NSE validation    : 0.744
#
# === Station 41012 (352/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.666
#
# === Station 41013 (353/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.769
#
# === Station 41014 (354/671) ===
# NSE calibration   : 0.757
# NSE validation    : 0.451
#
# === Station 41016 (355/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.793
#
# === Station 41019 (356/671) ===
# NSE calibration   : 0.659
# NSE validation    : 0.705
#
# === Station 41020 (357/671) ===
# NSE calibration   : 0.803
# NSE validation    : 0.753
#
# === Station 41022 (358/671) ===
# NSE calibration   : 0.774
# NSE validation    : 0.730
#
# === Station 41023 (359/671) ===
# NSE calibration   : 0.919
# NSE validation    : 0.821
#
# === Station 41025 (360/671) ===
# NSE calibration   : 0.684
# NSE validation    : 0.602
#
# === Station 41027 (361/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.732
#
# === Station 41028 (362/671) ===
# NSE calibration   : 0.681
# NSE validation    : 0.695
#
# === Station 41029 (363/671) ===
# NSE calibration   : 0.767
# NSE validation    : 0.767
#
# === Station 42001 (364/671) ===
# NSE calibration   : 0.720
# NSE validation    : 0.630
#
# === Station 42003 (365/671) ===
# NSE calibration   : 0.746
# NSE validation    : 0.702
#
# === Station 42004 (366/671) ===
# NSE calibration   : 0.877
# NSE validation    : 0.740
#
# === Station 42006 (367/671) ===
# NSE calibration   : 0.917
# NSE validation    : 0.903
#
# === Station 42008 (368/671) ===
# NSE calibration   : 0.878
# NSE validation    : 0.871
#
# === Station 42010 (369/671) ===
# NSE calibration   : 0.910
# NSE validation    : 0.787
#
# === Station 42011 (370/671) ===
# NSE calibration   : 0.698
# NSE validation    : 0.690
#
# === Station 42016 (371/671) ===
# NSE calibration   : 0.904
# NSE validation    : 0.837
#
# === Station 42017 (372/671) ===
# NSE calibration   : 0.760
# NSE validation    : 0.775
#
# === Station 42024 (373/671) ===
# NSE calibration   : 0.862
# NSE validation    : 0.798
#
# === Station 42026 (374/671) ===
#
# === Station 42027 (375/671) ===
#
# === Station 43005 (376/671) ===
# NSE calibration   : 0.914
# NSE validation    : 0.906
#
# === Station 43006 (377/671) ===
# NSE calibration   : 0.863
# NSE validation    : 0.837
#
# === Station 43007 (378/671) ===
# NSE calibration   : 0.843
# NSE validation    : 0.831
#
# === Station 43008 (379/671) ===
# NSE calibration   : 0.879
# NSE validation    : 0.892
#
# === Station 43009 (380/671) ===
# NSE calibration   : 0.761
# NSE validation    : 0.752
#
# === Station 43014 (381/671) ===
# NSE calibration   : 0.826
# NSE validation    : 0.775
#
# === Station 43017 (382/671) ===
# NSE calibration   : 0.862
# NSE validation    : 0.836
#
# === Station 43018 (383/671) ===
# NSE calibration   : 0.896
# NSE validation    : 0.897
#
# === Station 43021 (384/671) ===
# NSE calibration   : 0.870
# NSE validation    : 0.786
#
# === Station 44001 (385/671) ===
# NSE calibration   : 0.873
# NSE validation    : 0.853
#
# === Station 44002 (386/671) ===
# NSE calibration   : 0.905
# NSE validation    : 0.917
#
# === Station 44006 (387/671) ===
# NSE calibration   : 0.890
# NSE validation    : 0.904
#
# === Station 44009 (388/671) ===
# NSE calibration   : 0.142
# NSE validation    : -0.033
#
# === Station 44011 (389/671) ===
#
# === Station 45001 (390/671) ===
# NSE calibration   : 0.910
# NSE validation    : 0.875
#
# === Station 45003 (391/671) ===
# NSE calibration   : 0.803
# NSE validation    : 0.725
#
# === Station 45004 (392/671) ===
# NSE calibration   : 0.769
# NSE validation    : 0.721
#
# === Station 45005 (393/671) ===
# NSE calibration   : 0.788
# NSE validation    : 0.713
#
# === Station 45009 (394/671) ===
# NSE calibration   : 0.910
# NSE validation    : 0.869
#
# === Station 45012 (395/671) ===
# NSE calibration   : 0.856
# NSE validation    : 0.792
#
# === Station 46003 (396/671) ===
# NSE calibration   : 0.898
# NSE validation    : 0.855
#
# === Station 46005 (397/671) ===
# NSE calibration   : 0.869
# NSE validation    : 0.816
#
# === Station 46008 (398/671) ===
# NSE calibration   : 0.910
# NSE validation    : 0.846
#
# === Station 46014 (399/671) ===
#
# === Station 47001 (400/671) ===
# NSE calibration   : 0.886
# NSE validation    : 0.848
#
# === Station 47004 (401/671) ===
# NSE calibration   : 0.915
# NSE validation    : 0.882
#
# === Station 47005 (402/671) ===
# NSE calibration   : 0.847
# NSE validation    : 0.806
#
# === Station 47008 (403/671) ===
# NSE calibration   : 0.852
# NSE validation    : 0.835
#
# === Station 47009 (404/671) ===
# NSE calibration   : 0.928
# NSE validation    : 0.905
#
# === Station 47011 (405/671) ===
#
# === Station 47014 (406/671) ===
# NSE calibration   : 0.893
# NSE validation    : 0.811
#
# === Station 47018 (407/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.842
#
# === Station 48003 (408/671) ===
# NSE calibration   : 0.883
# NSE validation    : 0.908
#
# === Station 48004 (409/671) ===
# NSE calibration   : 0.878
# NSE validation    : 0.849
#
# === Station 48005 (410/671) ===
# NSE calibration   : 0.909
# NSE validation    : 0.911
#
# === Station 48011 (411/671) ===
# NSE calibration   : 0.902
# NSE validation    : 0.847
#
# === Station 49001 (412/671) ===
# NSE calibration   : 0.910
# NSE validation    : 0.875
#
# === Station 49002 (413/671) ===
# NSE calibration   : 0.918
# NSE validation    : 0.926
#
# === Station 49004 (414/671) ===
# NSE calibration   : 0.882
# NSE validation    : 0.878
#
# === Station 50001 (415/671) ===
# NSE calibration   : 0.895
# NSE validation    : 0.854
#
# === Station 50002 (416/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.802
#
# === Station 50006 (417/671) ===
# NSE calibration   : 0.909
# NSE validation    : 0.888
#
# === Station 50007 (418/671) ===
# NSE calibration   : 0.892
# NSE validation    : 0.840
#
# === Station 50008 (419/671) ===
# NSE calibration   : 0.879
# NSE validation    : 0.846
#
# === Station 50011 (420/671) ===
# NSE calibration   : 0.887
# NSE validation    : 0.841
#
# === Station 5003 (421/671) ===
# NSE calibration   : 0.695
# NSE validation    : 0.634
#
# === Station 51001 (422/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.888
#
# === Station 52004 (423/671) ===
# NSE calibration   : 0.801
# NSE validation    : 0.787
#
# === Station 52005 (424/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.817
#
# === Station 52006 (425/671) ===
# NSE calibration   : 0.793
# NSE validation    : 0.764
#
# === Station 52007 (426/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.794
#
# === Station 52009 (427/671) ===
# NSE calibration   : 0.880
# NSE validation    : 0.835
#
# === Station 52010 (428/671) ===
# NSE calibration   : 0.815
# NSE validation    : 0.773
#
# === Station 52011 (429/671) ===
# NSE calibration   : 0.788
# NSE validation    : 0.723
#
# === Station 52015 (430/671) ===
# NSE calibration   : 0.806
# NSE validation    : 0.475
#
# === Station 52016 (431/671) ===
# NSE calibration   : 0.867
# NSE validation    : 0.835
#
# === Station 53005 (432/671) ===
# NSE calibration   : 0.899
# NSE validation    : 0.868
#
# === Station 53006 (433/671) ===
# NSE calibration   : 0.852
# NSE validation    : 0.812
#
# === Station 53007 (434/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.792
#
# === Station 53008 (435/671) ===
# NSE calibration   : 0.881
# NSE validation    : 0.825
#
# === Station 53009 (436/671) ===
# NSE calibration   : 0.925
# NSE validation    : 0.903
#
# === Station 53013 (437/671) ===
# NSE calibration   : 0.844
# NSE validation    : 0.759
#
# === Station 53017 (438/671) ===
# NSE calibration   : 0.854
# NSE validation    : 0.792
#
# === Station 53018 (439/671) ===
# NSE calibration   : 0.891
# NSE validation    : 0.872
#
# === Station 53022 (440/671) ===
#
# === Station 53023 (441/671) ===
# NSE calibration   : 0.933
# NSE validation    : 0.894
#
# === Station 53028 (442/671) ===
# NSE calibration   : 0.901
# NSE validation    : 0.889
#
# === Station 54001 (443/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.832
#
# === Station 54002 (444/671) ===
# NSE calibration   : 0.784
# NSE validation    : 0.696
#
# === Station 54003 (445/671) ===
# NSE calibration   : 0.675
# NSE validation    : 0.611
#
# === Station 54004 (446/671) ===
# NSE calibration   : 0.773
# NSE validation    : 0.709
#
# === Station 54005 (447/671) ===
# NSE calibration   : 0.877
# NSE validation    : 0.845
#
# === Station 54007 (448/671) ===
# NSE calibration   : 0.715
# NSE validation    : 0.532
#
# === Station 54008 (449/671) ===
# NSE calibration   : 0.875
# NSE validation    : 0.819
#
# === Station 54011 (450/671) ===
#
# === Station 54012 (451/671) ===
# NSE calibration   : 0.786
# NSE validation    : 0.755
#
# === Station 54015 (452/671) ===
# NSE calibration   : 0.621
# NSE validation    : 0.244
#
# === Station 54016 (453/671) ===
# NSE calibration   : 0.834
# NSE validation    : 0.755
#
# === Station 54017 (454/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.537
#
# === Station 54018 (455/671) ===
# NSE calibration   : 0.828
# NSE validation    : 0.774
#
# === Station 54019 (456/671) ===
# NSE calibration   : 0.705
# NSE validation    : 0.664
#
# === Station 54020 (457/671) ===
# NSE calibration   : 0.826
# NSE validation    : 0.727
#
# === Station 54022 (458/671) ===
#
# === Station 54024 (459/671) ===
# NSE calibration   : 0.653
# NSE validation    : 0.583
#
# === Station 54025 (460/671) ===
# NSE calibration   : 0.903
# NSE validation    : 0.876
#
# === Station 54027 (461/671) ===
# NSE calibration   : 0.904
# NSE validation    : 0.880
#
# === Station 54028 (462/671) ===
# NSE calibration   : 0.836
# NSE validation    : 0.808
#
# === Station 54029 (463/671) ===
# NSE calibration   : 0.845
# NSE validation    : 0.790
#
# === Station 54032 (464/671) ===
# NSE calibration   : 0.874
# NSE validation    : 0.818
#
# === Station 54034 (465/671) ===
# NSE calibration   : 0.756
# NSE validation    : 0.656
#
# === Station 54036 (466/671) ===
# NSE calibration   : 0.733
# NSE validation    : 0.667
#
# === Station 54038 (467/671) ===
# NSE calibration   : 0.901
# NSE validation    : 0.868
#
# === Station 54044 (468/671) ===
# NSE calibration   : 0.625
# NSE validation    : 0.563
#
# === Station 54048 (469/671) ===
# NSE calibration   : 0.708
# NSE validation    : 0.436
#
# === Station 54049 (470/671) ===
# NSE calibration   : 0.668
# NSE validation    : 0.593
#
# === Station 54052 (471/671) ===
# NSE calibration   : 0.628
# NSE validation    : 0.732
#
# === Station 54057 (472/671) ===
# NSE calibration   : 0.874
# NSE validation    : 0.796
#
# === Station 54060 (473/671) ===
# NSE calibration   : 0.585
# NSE validation    : 0.517
#
# === Station 54063 (474/671) ===
#
# === Station 54080 (475/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.780
#
# === Station 54095 (476/671) ===
# NSE calibration   : 0.868
# NSE validation    : 0.829
#
# === Station 54096 (477/671) ===
# NSE calibration   : 0.693
# NSE validation    : 0.567
#
# === Station 55002 (478/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.780
#
# === Station 55007 (479/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.828
#
# === Station 55008 (480/671) ===
#
# === Station 55013 (481/671) ===
# NSE calibration   : 0.878
# NSE validation    : 0.853
#
# === Station 55014 (482/671) ===
# NSE calibration   : 0.899
# NSE validation    : 0.855
#
# === Station 55016 (483/671) ===
# NSE calibration   : 0.851
# NSE validation    : 0.829
#
# === Station 55018 (484/671) ===
# NSE calibration   : 0.758
# NSE validation    : 0.692
#
# === Station 55021 (485/671) ===
# NSE calibration   : 0.890
# NSE validation    : 0.806
#
# === Station 55023 (486/671) ===
# NSE calibration   : 0.862
# NSE validation    : 0.864
#
# === Station 55025 (487/671) ===
# NSE calibration   : 0.877
# NSE validation    : 0.858
#
# === Station 55026 (488/671) ===
# NSE calibration   : 0.855
# NSE validation    : 0.841
#
# === Station 55029 (489/671) ===
# NSE calibration   : 0.834
# NSE validation    : 0.774
#
# === Station 55032 (490/671) ===
# NSE calibration   : 0.742
# NSE validation    : 0.681
#
# === Station 56001 (491/671) ===
# NSE calibration   : 0.874
# NSE validation    : 0.842
#
# === Station 56002 (492/671) ===
# NSE calibration   : 0.919
# NSE validation    : 0.887
#
# === Station 56007 (493/671) ===
# NSE calibration   : 0.884
# NSE validation    : 0.873
#
# === Station 56012 (494/671) ===
# NSE calibration   : 0.858
# NSE validation    : 0.841
#
# === Station 56013 (495/671) ===
# NSE calibration   : 0.900
# NSE validation    : 0.879
#
# === Station 57004 (496/671) ===
# NSE calibration   : 0.893
# NSE validation    : 0.856
#
# === Station 57005 (497/671) ===
# NSE calibration   : 0.894
# NSE validation    : 0.862
#
# === Station 57006 (498/671) ===
# NSE calibration   : 0.898
# NSE validation    : 0.869
#
# === Station 57007 (499/671) ===
# NSE calibration   : 0.866
# NSE validation    : 0.813
#
# === Station 57008 (500/671) ===
# NSE calibration   : 0.885
# NSE validation    : 0.868
#
# === Station 57009 (501/671) ===
# NSE calibration   : 0.844
# NSE validation    : 0.837
#
# === Station 58001 (502/671) ===
# NSE calibration   : 0.866
# NSE validation    : 0.839
#
# === Station 58002 (503/671) ===
# NSE calibration   : 0.876
# NSE validation    : 0.843
#
# === Station 58006 (504/671) ===
# NSE calibration   : 0.903
# NSE validation    : 0.867
#
# === Station 58008 (505/671) ===
# NSE calibration   : 0.872
# NSE validation    : 0.847
#
# === Station 58009 (506/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.877
#
# === Station 58010 (507/671) ===
#
# === Station 58012 (508/671) ===
# NSE calibration   : 0.877
# NSE validation    : 0.835
#
# === Station 59001 (509/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.803
#
# === Station 60002 (510/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.835
#
# === Station 60003 (511/671) ===
# NSE calibration   : 0.872
# NSE validation    : 0.790
#
# === Station 60005 (512/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.747
#
# === Station 60006 (513/671) ===
# NSE calibration   : 0.873
# NSE validation    : 0.857
#
# === Station 60010 (514/671) ===
# NSE calibration   : 0.880
# NSE validation    : 0.853
#
# === Station 60012 (515/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.803
#
# === Station 6007 (516/671) ===
# NSE calibration   : 0.846
# NSE validation    : 0.820
#
# === Station 6008 (517/671) ===
# NSE calibration   : 0.738
# NSE validation    : 0.709
#
# === Station 61001 (518/671) ===
# NSE calibration   : 0.866
# NSE validation    : 0.726
#
# === Station 61002 (519/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.837
#
# === Station 62001 (520/671) ===
# NSE calibration   : 0.900
# NSE validation    : 0.863
#
# === Station 63001 (521/671) ===
# NSE calibration   : 0.860
# NSE validation    : 0.817
#
# === Station 63004 (522/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.818
#
# === Station 64001 (523/671) ===
# NSE calibration   : 0.871
# NSE validation    : 0.849
#
# === Station 64002 (524/671) ===
# NSE calibration   : 0.822
# NSE validation    : 0.782
#
# === Station 64006 (525/671) ===
# NSE calibration   : 0.870
# NSE validation    : 0.873
#
# === Station 65001 (526/671) ===
# NSE calibration   : 0.805
# NSE validation    : 0.836
#
# === Station 65004 (527/671) ===
#
# === Station 65005 (528/671) ===
# NSE calibration   : 0.633
# NSE validation    : 0.771
#
# === Station 65006 (529/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.788
#
# === Station 65007 (530/671) ===
# NSE calibration   : 0.827
# NSE validation    : 0.813
#
# === Station 65008 (531/671) ===
# NSE calibration   : 0.744
# NSE validation    : 0.761
#
# === Station 66001 (532/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.823
#
# === Station 66004 (533/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.790
#
# === Station 66006 (534/671) ===
# NSE calibration   : 0.880
# NSE validation    : 0.842
#
# === Station 66011 (535/671) ===
# NSE calibration   : 0.834
# NSE validation    : 0.832
#
# === Station 67001 (536/671) ===
# NSE calibration   : 0.834
# NSE validation    : 0.831
#
# === Station 67005 (537/671) ===
# NSE calibration   : 0.874
# NSE validation    : 0.826
#
# === Station 67006 (538/671) ===
# NSE calibration   : 0.884
# NSE validation    : 0.826
#
# === Station 67008 (539/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.692
#
# === Station 67010 (540/671) ===
# NSE calibration   : 0.818
# NSE validation    : 0.859
#
# === Station 67015 (541/671) ===
# NSE calibration   : 0.893
# NSE validation    : 0.852
#
# === Station 67018 (542/671) ===
# NSE calibration   : 0.853
# NSE validation    : 0.860
#
# === Station 67025 (543/671) ===
# NSE calibration   : 0.761
# NSE validation    : 0.731
#
# === Station 67033 (544/671) ===
#
# === Station 68001 (545/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.684
#
# === Station 68003 (546/671) ===
# NSE calibration   : 0.781
# NSE validation    : 0.710
#
# === Station 68004 (547/671) ===
# NSE calibration   : 0.692
# NSE validation    : 0.742
#
# === Station 68005 (548/671) ===
# NSE calibration   : 0.819
# NSE validation    : 0.667
#
# === Station 68020 (549/671) ===
# NSE calibration   : 0.709
# NSE validation    : 0.541
#
# === Station 69002 (550/671) ===
# NSE calibration   : 0.809
# NSE validation    : 0.798
#
# === Station 69007 (551/671) ===
# NSE calibration   : 0.824
# NSE validation    : 0.795
#
# === Station 69012 (552/671) ===
# NSE calibration   : 0.854
# NSE validation    : 0.824
#
# === Station 69015 (553/671) ===
# NSE calibration   : 0.791
# NSE validation    : 0.702
#
# === Station 69017 (554/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.810
#
# === Station 69023 (555/671) ===
# NSE calibration   : 0.864
# NSE validation    : 0.818
#
# === Station 69027 (556/671) ===
# NSE calibration   : 0.830
# NSE validation    : 0.814
#
# === Station 69030 (557/671) ===
# NSE calibration   : 0.810
# NSE validation    : 0.780
#
# === Station 69032 (558/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.828
#
# === Station 69043 (559/671) ===
#
# === Station 70002 (560/671) ===
# NSE calibration   : 0.827
# NSE validation    : 0.833
#
# === Station 7001 (561/671) ===
# NSE calibration   : 0.468
# NSE validation    : 0.413
#
# === Station 7002 (562/671) ===
# NSE calibration   : 0.563
# NSE validation    : 0.403
#
# === Station 7003 (563/671) ===
# NSE calibration   : 0.713
# NSE validation    : 0.463
#
# === Station 7005 (564/671) ===
# NSE calibration   : 0.731
# NSE validation    : 0.499
#
# === Station 7006 (565/671) ===
# NSE calibration   : 0.617
# NSE validation    : 0.418
#
# === Station 71001 (566/671) ===
# NSE calibration   : 0.799
# NSE validation    : 0.793
#
# === Station 71004 (567/671) ===
# NSE calibration   : 0.851
# NSE validation    : 0.832
#
# === Station 71006 (568/671) ===
# NSE calibration   : 0.831
# NSE validation    : 0.817
#
# === Station 71008 (569/671) ===
# NSE calibration   : 0.828
# NSE validation    : 0.806
#
# === Station 71014 (570/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.784
#
# === Station 72002 (571/671) ===
# NSE calibration   : 0.799
# NSE validation    : 0.712
#
# === Station 72004 (572/671) ===
# NSE calibration   : 0.824
# NSE validation    : 0.800
#
# === Station 72005 (573/671) ===
# NSE calibration   : 0.859
# NSE validation    : 0.853
#
# === Station 72007 (574/671) ===
# NSE calibration   : 0.816
# NSE validation    : 0.777
#
# === Station 72009 (575/671) ===
# NSE calibration   : 0.807
# NSE validation    : 0.819
#
# === Station 72014 (576/671) ===
# NSE calibration   : 0.829
# NSE validation    : 0.788
#
# === Station 72015 (577/671) ===
# NSE calibration   : 0.872
# NSE validation    : 0.863
#
# === Station 73005 (578/671) ===
# NSE calibration   : 0.874
# NSE validation    : 0.862
#
# === Station 73009 (579/671) ===
# NSE calibration   : 0.867
# NSE validation    : 0.856
#
# === Station 73010 (580/671) ===
# NSE calibration   : 0.897
# NSE validation    : 0.870
#
# === Station 73011 (581/671) ===
# NSE calibration   : 0.896
# NSE validation    : 0.891
#
# === Station 73014 (582/671) ===
# NSE calibration   : 0.751
# NSE validation    : 0.745
#
# === Station 73015 (583/671) ===
# NSE calibration   : 0.795
# NSE validation    : 0.776
#
# === Station 74001 (584/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.817
#
# === Station 74005 (585/671) ===
# NSE calibration   : 0.822
# NSE validation    : 0.829
#
# === Station 74006 (586/671) ===
# NSE calibration   : 0.798
# NSE validation    : 0.778
#
# === Station 74007 (587/671) ===
# NSE calibration   : 0.790
# NSE validation    : 0.811
#
# === Station 75003 (588/671) ===
# NSE calibration   : 0.888
# NSE validation    : 0.861
#
# === Station 75004 (589/671) ===
# NSE calibration   : 0.875
# NSE validation    : 0.835
#
# === Station 75017 (590/671) ===
# NSE calibration   : 0.869
# NSE validation    : 0.825
#
# === Station 76003 (591/671) ===
# NSE calibration   : 0.893
# NSE validation    : 0.857
#
# === Station 76005 (592/671) ===
# NSE calibration   : 0.824
# NSE validation    : 0.782
#
# === Station 76007 (593/671) ===
# NSE calibration   : 0.831
# NSE validation    : 0.804
#
# === Station 76008 (594/671) ===
# NSE calibration   : 0.736
# NSE validation    : 0.697
#
# === Station 76011 (595/671) ===
# NSE calibration   : 0.760
# NSE validation    : 0.771
#
# === Station 76014 (596/671) ===
# NSE calibration   : 0.848
# NSE validation    : 0.793
#
# === Station 77002 (597/671) ===
# NSE calibration   : 0.849
# NSE validation    : 0.820
#
# === Station 77003 (598/671) ===
# NSE calibration   : 0.793
# NSE validation    : 0.762
#
# === Station 77004 (599/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.805
#
# === Station 78003 (600/671) ===
# NSE calibration   : 0.837
# NSE validation    : 0.802
#
# === Station 78004 (601/671) ===
# NSE calibration   : 0.800
# NSE validation    : 0.746
#
# === Station 78006 (602/671) ===
# NSE calibration   : 0.862
# NSE validation    : 0.821
#
# === Station 79002 (603/671) ===
# NSE calibration   : 0.838
# NSE validation    : 0.792
#
# === Station 79003 (604/671) ===
# NSE calibration   : 0.807
# NSE validation    : 0.746
#
# === Station 79004 (605/671) ===
# NSE calibration   : 0.847
# NSE validation    : 0.829
#
# === Station 79005 (606/671) ===
# NSE calibration   : 0.841
# NSE validation    : 0.796
#
# === Station 79006 (607/671) ===
# NSE calibration   : 0.843
# NSE validation    : 0.799
#
# === Station 80001 (608/671) ===
# NSE calibration   : 0.840
# NSE validation    : 0.779
#
# === Station 80002 (609/671) ===
# NSE calibration   : 0.839
# NSE validation    : 0.820
#
# === Station 80003 (610/671) ===
# NSE calibration   : 0.824
# NSE validation    : 0.789
#
# === Station 80004 (611/671) ===
# NSE calibration   : 0.808
# NSE validation    : 0.737
#
# === Station 80005 (612/671) ===
# NSE calibration   : 0.803
# NSE validation    : 0.759
#
# === Station 80006 (613/671) ===
# NSE calibration   : 0.874
# NSE validation    : 0.872
#
# === Station 8004 (614/671) ===
# NSE calibration   : 0.541
# NSE validation    : 0.334
#
# === Station 8005 (615/671) ===
# NSE calibration   : 0.641
# NSE validation    : 0.537
#
# === Station 8006 (616/671) ===
# NSE calibration   : 0.649
# NSE validation    : 0.456
#
# === Station 8009 (617/671) ===
# NSE calibration   : 0.542
# NSE validation    : 0.413
#
# === Station 8011 (618/671) ===
# NSE calibration   : 0.655
# NSE validation    : 0.358
#
# === Station 8013 (619/671) ===
#
# === Station 81002 (620/671) ===
# NSE calibration   : 0.759
# NSE validation    : 0.707
#
# === Station 81003 (621/671) ===
# NSE calibration   : 0.756
# NSE validation    : 0.777
#
# === Station 81004 (622/671) ===
# NSE calibration   : 0.747
# NSE validation    : 0.720
#
# === Station 81006 (623/671) ===
# NSE calibration   : 0.764
# NSE validation    : 0.717
#
# === Station 81007 (624/671) ===
# NSE calibration   : 0.770
# NSE validation    : 0.762
#
# === Station 82001 (625/671) ===
# NSE calibration   : 0.799
# NSE validation    : 0.744
#
# === Station 82003 (626/671) ===
# NSE calibration   : 0.779
# NSE validation    : 0.760
#
# === Station 83003 (627/671) ===
# NSE calibration   : 0.741
# NSE validation    : 0.681
#
# === Station 83004 (628/671) ===
# NSE calibration   : 0.783
# NSE validation    : 0.706
#
# === Station 83006 (629/671) ===
# NSE calibration   : 0.762
# NSE validation    : 0.677
#
# === Station 83007 (630/671) ===
# NSE calibration   : 0.828
# NSE validation    : 0.762
#
# === Station 83009 (631/671) ===
# NSE calibration   : 0.755
# NSE validation    : 0.686
#
# === Station 83010 (632/671) ===
# NSE calibration   : 0.844
# NSE validation    : 0.819
#
# === Station 83013 (633/671) ===
# NSE calibration   : 0.768
# NSE validation    : 0.762
#
# === Station 84001 (634/671) ===
# NSE calibration   : 0.831
# NSE validation    : 0.789
#
# === Station 84004 (635/671) ===
# NSE calibration   : 0.796
# NSE validation    : 0.760
#
# === Station 84005 (636/671) ===
# NSE calibration   : 0.835
# NSE validation    : 0.795
#
# === Station 84008 (637/671) ===
# NSE calibration   : 0.802
# NSE validation    : 0.761
#
# === Station 84009 (638/671) ===
# NSE calibration   : 0.813
# NSE validation    : 0.757
#
# === Station 84012 (639/671) ===
# NSE calibration   : 0.832
# NSE validation    : 0.777
#
# === Station 84013 (640/671) ===
# NSE calibration   : 0.825
# NSE validation    : 0.798
#
# === Station 84014 (641/671) ===
# NSE calibration   : 0.812
# NSE validation    : 0.772
#
# === Station 84016 (642/671) ===
# NSE calibration   : 0.792
# NSE validation    : 0.788
#
# === Station 84017 (643/671) ===
# NSE calibration   : 0.865
# NSE validation    : 0.831
#
# === Station 84018 (644/671) ===
# NSE calibration   : 0.789
# NSE validation    : 0.726
#
# === Station 84019 (645/671) ===
# NSE calibration   : 0.781
# NSE validation    : 0.742
#
# === Station 84020 (646/671) ===
# NSE calibration   : 0.814
# NSE validation    : 0.758
#
# === Station 84022 (647/671) ===
# NSE calibration   : 0.745
# NSE validation    : 0.719
#
# === Station 84026 (648/671) ===
# NSE calibration   : 0.824
# NSE validation    : 0.777
#
# === Station 84030 (649/671) ===
# NSE calibration   : 0.850
# NSE validation    : 0.803
#
# === Station 85001 (650/671) ===
# NSE calibration   : 0.922
# NSE validation    : 0.905
#
# === Station 85002 (651/671) ===
# NSE calibration   : 0.812
# NSE validation    : 0.713
#
# === Station 85003 (652/671) ===
# NSE calibration   : 0.783
# NSE validation    : 0.746
#
# === Station 85004 (653/671) ===
# NSE calibration   : 0.778
# NSE validation    : 0.751
#
# === Station 88001 (654/671) ===
#
# === Station 89002 (655/671) ===
# NSE calibration   : 0.734
# NSE validation    : 0.716
#
# === Station 89003 (656/671) ===
# NSE calibration   : 0.755
# NSE validation    : 0.749
#
# === Station 89005 (657/671) ===
# NSE calibration   : 0.572
# NSE validation    : 0.577
#
# === Station 89007 (658/671) ===
# NSE calibration   : 0.661
# NSE validation    : 0.612
#
# === Station 90003 (659/671) ===
# NSE calibration   : 0.765
# NSE validation    : 0.732
#
# === Station 9002 (660/671) ===
# NSE calibration   : 0.726
# NSE validation    : 0.507
#
# === Station 9003 (661/671) ===
# NSE calibration   : 0.741
# NSE validation    : 0.576
#
# === Station 9004 (662/671) ===
# NSE calibration   : 0.803
# NSE validation    : 0.589
#
# === Station 9005 (663/671) ===
# NSE calibration   : 0.594
# NSE validation    : 0.388
#
# === Station 92001 (664/671) ===
#
# === Station 93001 (665/671) ===
# NSE calibration   : 0.780
# NSE validation    : 0.772
#
# === Station 94001 (666/671) ===
# NSE calibration   : 0.915
# NSE validation    : 0.921
#
# === Station 95001 (667/671) ===
# NSE calibration   : 0.862
# NSE validation    : 0.816
#
# === Station 96001 (668/671) ===
# NSE calibration   : 0.704
# NSE validation    : 0.613
#
# === Station 96002 (669/671) ===
# NSE calibration   : 0.821
# NSE validation    : 0.737
#
# === Station 96004 (670/671) ===
# NSE calibration   : 0.747
# NSE validation    : 0.697
#
# === Station 97002 (671/671) ===
# NSE calibration   : 0.680
# NSE validation    : 0.542
#
# ✅ Finished : 623 calibrated basins
# Total time: 6262.00 s
# Total time: 104.37 min
# Total time: 1.74 h

# %%
# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — CALIBRATION
# =============================================================
nse_cal = [res['NSE_cal'] for res in results_HBV.values() if not np.isnan(res['NSE_cal'])]
rmse_cal = [res['RMSE_cal'] for res in results_HBV.values() if not np.isnan(res['RMSE_cal'])]

print("\n================= CALIBRATION =================\n")

# ----- NSE -----
if nse_cal:
    print(f"NSE Calibration -> Median: {np.percentile(nse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_cal, 95):.4f}")
    print("MEAN NSE_CAL:", np.mean(nse_cal))
    print("MIN NSE_CAL:", np.min(nse_cal))
    print("MAX NSE_CAL:", np.max(nse_cal))
else:
    print("No NSE available for calibration.")

# ----- RMSE -----
print("\n--- RMSE Calibration ---")
if rmse_cal:
    print(f"RMSE Calibration -> Median: {np.percentile(rmse_cal, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_cal, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_cal, 95):.4f}")
    print("MEAN RMSE_CAL:", np.mean(rmse_cal))
    print("MIN RMSE_CAL:", np.min(rmse_cal))
    print("MAX RMSE_CAL:", np.max(rmse_cal))
else:
    print("No RMSE available for calibration.")


# =============================================================
# 📌 EXTRACTION OF NSE & RMSE — VALIDATION
# =============================================================
print("\n\n================= VALIDATION =================\n")

nse_val = [res['NSE_val'] for res in results_HBV.values() if not np.isnan(res['NSE_val'])]
rmse_val = [res['RMSE_val'] for res in results_HBV.values() if not np.isnan(res['RMSE_val'])]

# ----- NSE -----
if nse_val:
    print(f"NSE Validation -> Median: {np.percentile(nse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(nse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(nse_val, 95):.4f}")
    print("MEAN NSE_VAL:", np.mean(nse_val))
    print("MIN NSE_VAL:", np.min(nse_val))
    print("MAX NSE_VAL:", np.max(nse_val))
else:
    print("No valid station for validation.")

# ----- RMSE -----
print("\n--- RMSE Validation ---")
if rmse_val:
    print(f"RMSE Validation -> Median: {np.percentile(rmse_val, 50):.3f}, "
          f"5th percentile: {np.percentile(rmse_val, 5):.4f}, "
          f"95th percentile: {np.percentile(rmse_val, 95):.4f}")
    print("MEAN RMSE_VAL:", np.mean(rmse_val))
    print("MIN RMSE_VAL:", np.min(rmse_val))
    print("MAX RMSE_VAL:", np.max(rmse_val))
else:
    print("No valid station for RMSE in validation.")
# Out:
# ================= CALIBRATION =================
#
# NSE Calibration -> Median: 0.800, 5th percentile: 0.6036, 95th percentile: 0.9002
# MEAN NSE_CAL: 0.7725328054385868
# MIN NSE_CAL: -3.447807221879847
# MAX NSE_CAL: 0.9325791809293669
#
# --- RMSE Calibration ---
# RMSE Calibration -> Median: 0.817, 5th percentile: 0.1733, 95th percentile: 2.8321
# MEAN RMSE_CAL: 1.1114939896616236
# MIN RMSE_CAL: 0.04552008312855641
# MAX RMSE_CAL: 11.270362337036808
#
#
# ================= VALIDATION =================
#
# NSE Validation -> Median: 0.745, 5th percentile: 0.3972, 95th percentile: 0.8720
# MEAN NSE_VAL: 0.6919879710927853
# MIN NSE_VAL: -1.93217546028034
# MAX NSE_VAL: 0.9264208679489333
#
# --- RMSE Validation ---
# RMSE Validation -> Median: 1.010, 5th percentile: 0.2272, 95th percentile: 3.0277
# MEAN RMSE_VAL: 1.2825234862607102
# MIN RMSE_VAL: 0.08054866929574574
# MAX RMSE_VAL: 10.43881874381692

# %% [markdown]
# #Recession

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# =========================================================
# 0. LOAD ATTRIBUTES
# =========================================================

hydro = pd.read_csv(
    '/content/drive/MyDrive/CAMELS_GB/CAMELS_GB_hydrologic_attributes.csv',
    sep=','
)

hydro["gauge_id"] = hydro["gauge_id"].astype(str)

df = hydro[[
    "gauge_id",
    "baseflow_index",
    "slope_fdc",
    "runoff_ratio"
]].dropna()

# =========================================================
# 1. DEFINE BASIN GROUPS
# =========================================================

top_bfi = set(
    df.sort_values("baseflow_index", ascending=False)
      .head(40)["gauge_id"]
)

low_fdc = set(
    df.sort_values("slope_fdc", ascending=True)
      .head(40)["gauge_id"]
)

low_rr = set(
    df.sort_values("runoff_ratio", ascending=True)
      .head(40)["gauge_id"]
)

groups = {
    "Top BFI": top_bfi,
    "Low FDC slope": low_fdc,
    "Low runoff ratio": low_rr
}


# =========================================================
# 2. MODELS
# =========================================================

models = {
    "cGRHyMoLAP": results_cGRH_semi_exp,
    "GRHyMoLAP": results_GRH_semi_exp,
    "GR4J": results_GR4J,
    "HBV": results_HBV
}

model_names = list(models.keys())


# =========================================================
# 3. SEGMENTATION
# =========================================================

def extract_recession_segments(
    Q,
    eps=0.0,
    remove_first_days=0,
    min_length=7,
):

    Q = np.asarray(Q)

    dQ = Q[1:] - Q[:-1]

    recession = dQ <= eps

    segments_of_difference_indices = []

    current = []

    for i, flag in enumerate(recession):

        if flag:

            current.append(i )

        else:

            if len(current):

                seg = current[remove_first_days:]

                if len(seg) >= min_length:
                    segments_of_difference_indices.append(np.array(seg))

                current = []

    if len(current):

        seg = current[remove_first_days:]

        if len(seg) >= min_length:
            segments_of_difference_indices.append(np.array(seg))

    return segments_of_difference_indices



def extract_runoff_generation_segments(
    Q,
    eps=0.0,
):

    Q = np.asarray(Q)

    dQ = Q[1:] - Q[:-1]

    runoff = dQ > eps

    segments_of_difference_indices = []

    current = []

    for i, flag in enumerate(runoff):

        if flag:

            current.append(i )

        else:

            if len(current):

                segments_of_difference_indices.append(np.array(current))

                current = []

    if len(current):

        segments_of_difference_indices.append(np.array(current))

    return segments_of_difference_indices



# =========================================================
# 4. SIGN CONSISTENCY
# =========================================================

def sign_consistency(
    Q_mod,
    segments,
    regime,
):

    violations = 0
    total = 0

    dQsim = np.diff(Q_mod)

    for seg in segments:

        dq = dQsim[seg]

        total += len(dq)

        if regime == "recession":

            violations += np.sum(dq > 0)

        else:

            violations += np.sum(dq <= 0)

    if total == 0:
        return np.nan

    return 1 - violations / total


# =========================================================
# 4. COMPUTE METRICS FOR A GROUP
# =========================================================

def compute_group(basin_set):

    rec = {m: [] for m in model_names}
    rg = {m: [] for m in model_names}

    for sid in results_HBV.keys():

        sid = str(sid)

        if sid not in basin_set:
            continue

        try:
            Q_obs = np.asarray(results_HBV[sid]["Q_obs"], dtype=float)

            Q_models = {
                m: np.asarray(models[m][sid]["Qsim"], dtype=float)
                for m in model_names
            }

            rec_segs = extract_recession_segments(Q_obs)
            rg_segs = extract_runoff_generation_segments(Q_obs)

            for m in model_names:

                sr = sign_consistency(Q_models[m], rec_segs, "recession")
                sg = sign_consistency(Q_models[m], rg_segs, "runoff")

                if not np.isnan(sr):
                    rec[m].append(sr)
                if not np.isnan(sg):
                    rg[m].append(sg)

        except:
            continue

    return rec, rg


# =========================================================
# 5. COMPUTE ALL GROUPS
# =========================================================

rec_bfi, rg_bfi = compute_group(groups["Top BFI"])
rec_fdc, rg_fdc = compute_group(groups["Low FDC slope"])
rec_rr, rg_rr = compute_group(groups["Low runoff ratio"])


# =========================================================
# 6. PLOTTING FUNCTION
# =========================================================

def plot_box(ax, data_dict, title):

    colors = {
        "cGRHyMoLAP": "red",
        "GRHyMoLAP": "green",
        "GR4J": "blue",
        "HBV": "purple"
    }

    data = []
    means = []

    for m in model_names:
        vals = np.asarray(data_dict[m])
        vals = vals[~np.isnan(vals)]

        data.append(vals)
        means.append(np.mean(vals))

    bp = ax.boxplot(
        data,
        patch_artist=True,
        showmeans=True,
        meanprops=dict(
            marker='^',          # triangle
            markerfacecolor='black',
            markeredgecolor='black',
            markersize=8
        )
    )

    # =====================================================
    # box colors
    # =====================================================
    for patch, m in zip(bp["boxes"], model_names):
        patch.set_facecolor(colors[m])
        patch.set_alpha(0.5)

    # =====================================================
    # mean annotation (bigger + clean)
    # =====================================================
    for i, mean_val in enumerate(means, start=1):
        ax.text(
            i,
            mean_val + 0.03,
            f"{mean_val:.2f}",
            ha="center",
            fontsize=13,
            fontweight="bold",
            color="black"
        )

    # =====================================================
    # AXES styling (IMPORTANT)
    # =====================================================
    ax.set_xticks(np.arange(1, len(model_names) + 1))
    ax.set_xticklabels(model_names, rotation=20, fontsize=13)

    ax.set_ylabel("Sign consistency", fontsize=16)
    ax.set_xlabel("Models", fontsize=16)

    ax.set_title(title, fontsize=17)

    ax.tick_params(axis='y', labelsize=14)
    ax.grid(alpha=0.3)


# =========================================================
# 7. FIGURE 3x2
# =========================================================

fig, axes = plt.subplots(2, 3, figsize=(18, 9))

# row 1 = recession
plot_box(axes[0,0], rec_bfi, "Recession - 40 highest BFI")
plot_box(axes[0,1], rec_fdc, "Recession - 40 lowest FDC slope")
plot_box(axes[0,2], rec_rr, "Recession - 40 lowest runoff ratio")

# row 2 = runoff generation
plot_box(axes[1,0], rg_bfi, "Runoff gene - 40 highest BFI")
plot_box(axes[1,1], rg_fdc, "Runoff gene - 40 lowest FDC slope")
plot_box(axes[1,2], rg_rr, "Runoff gene - 40 lowest runoff ratio")

plt.tight_layout()

plt.savefig(
    "recession.jpeg",
    dpi=700,
    bbox_inches="tight"
)
files.download("recession.jpeg")

plt.show()

# %%
print("hydro example:", hydro["gauge_id"].iloc[0])
print("results example:", list(results_HBV.keys())[0])
# Out:
# hydro example: 10002
# results example: 10002
